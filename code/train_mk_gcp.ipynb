# %% [markdown]
# # Four mask

# %%
import tensorflow as tf
import os

from assets.four_mask.data_generator import DR_Generator
from assets.four_mask.models import SMD_Unet 
from assets.four_mask.trainer import Trainer
# Out:
# 2024-02-01 06:52:18.364704: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-01 06:52:18.928203: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-01 06:52:20.638038: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':None,
    'add_noise_std':None
}
 
tr_fgadr_gen = DR_Generator(start_end_index=(0, 1108), is_train=True, **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1108, 1660), is_train=False, **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1660, 1840), is_train=False, **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
# model.load_weights('../models/four_mask/SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025/24')
# Out:
# 2024-02-01 06:52:25.565024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20763 MB memory:  -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

trainer_args = {
    'model':model,
    'epochs':100,
    'optimizer':optimizer,
    'for_recons':False,
    'alpha':0.05,
    'beta':[0.7, 0.1, 0.1, 0.1],
    'first_epoch':1,
    'file_name':"history/four_mask/SMD_withoutCLAHE_lr00001_3channel_alpha005_beta07010101.txt",
    'save_model_path':"../models/four_mask/SMD_withoutCLAHE_lr00001_3channel_alpha005_beta07010101",
    'add_noise':False
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen
             )
# Out:
# Epoch 1/100
# 2024-02-01 06:53:39.558544: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2024-02-01 06:53:44.589824: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1108/1108 [==============================] - 653s 590ms/step - train_loss: 0.9358 - mask_loss: 0.9822 - loss_recons: 0.0548 - ex_loss: 0.9805 - he_loss: 0.9710 - ma_loss: 0.9922 - se_loss: 0.9950
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.9391 - mask_loss: 0.9855 - loss_recons: 0.0565 - ex_loss: 0.9834 - he_loss: 0.9814 - ma_loss: 0.9928 - se_loss: 0.9971
#
# Epoch 2/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9328 - mask_loss: 0.9800 - loss_recons: 0.0351 - ex_loss: 0.9780 - he_loss: 0.9687 - ma_loss: 0.9918 - se_loss: 0.9940
# 552/552 [==============================] - 122s 222ms/step - val_loss: 0.9298 - mask_loss: 0.9770 - loss_recons: 0.0330 - ex_loss: 0.9726 - he_loss: 0.9739 - ma_loss: 0.9919 - se_loss: 0.9954
#
# Epoch 3/100
# 1108/1108 [==============================] - 628s 567ms/step - train_loss: 0.9309 - mask_loss: 0.9785 - loss_recons: 0.0267 - ex_loss: 0.9761 - he_loss: 0.9673 - ma_loss: 0.9915 - se_loss: 0.9938
# 552/552 [==============================] - 122s 221ms/step - val_loss: 0.9260 - mask_loss: 0.9736 - loss_recons: 0.0221 - ex_loss: 0.9683 - he_loss: 0.9712 - ma_loss: 0.9911 - se_loss: 0.9951
#
# Epoch 4/100
# 1108/1108 [==============================] - 628s 567ms/step - train_loss: 0.9293 - mask_loss: 0.9771 - loss_recons: 0.0208 - ex_loss: 0.9744 - he_loss: 0.9658 - ma_loss: 0.9912 - se_loss: 0.9937
# 552/552 [==============================] - 122s 221ms/step - val_loss: 0.9259 - mask_loss: 0.9737 - loss_recons: 0.0171 - ex_loss: 0.9688 - he_loss: 0.9697 - ma_loss: 0.9909 - se_loss: 0.9954
#
# Epoch 5/100
# 1108/1108 [==============================] - 629s 567ms/step - train_loss: 0.9279 - mask_loss: 0.9758 - loss_recons: 0.0167 - ex_loss: 0.9729 - he_loss: 0.9641 - ma_loss: 0.9910 - se_loss: 0.9934
# 552/552 [==============================] - 122s 222ms/step - val_loss: 0.9244 - mask_loss: 0.9723 - loss_recons: 0.0146 - ex_loss: 0.9671 - he_loss: 0.9677 - ma_loss: 0.9906 - se_loss: 0.9949
#
# Epoch 6/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9265 - mask_loss: 0.9745 - loss_recons: 0.0139 - ex_loss: 0.9712 - he_loss: 0.9624 - ma_loss: 0.9906 - se_loss: 0.9933
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9229 - mask_loss: 0.9708 - loss_recons: 0.0116 - ex_loss: 0.9650 - he_loss: 0.9675 - ma_loss: 0.9908 - se_loss: 0.9951
#
# Epoch 7/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9252 - mask_loss: 0.9733 - loss_recons: 0.0120 - ex_loss: 0.9698 - he_loss: 0.9612 - ma_loss: 0.9903 - se_loss: 0.9931
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9219 - mask_loss: 0.9698 - loss_recons: 0.0107 - ex_loss: 0.9639 - he_loss: 0.9655 - ma_loss: 0.9905 - se_loss: 0.9950
#
# Epoch 8/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9237 - mask_loss: 0.9718 - loss_recons: 0.0108 - ex_loss: 0.9678 - he_loss: 0.9600 - ma_loss: 0.9898 - se_loss: 0.9930
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9228 - mask_loss: 0.9708 - loss_recons: 0.0090 - ex_loss: 0.9656 - he_loss: 0.9647 - ma_loss: 0.9895 - se_loss: 0.9949
#
# Epoch 9/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9223 - mask_loss: 0.9703 - loss_recons: 0.0099 - ex_loss: 0.9659 - he_loss: 0.9591 - ma_loss: 0.9894 - se_loss: 0.9928
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9250 - mask_loss: 0.9732 - loss_recons: 0.0083 - ex_loss: 0.9689 - he_loss: 0.9654 - ma_loss: 0.9900 - se_loss: 0.9949
#
# Epoch 10/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9208 - mask_loss: 0.9687 - loss_recons: 0.0094 - ex_loss: 0.9639 - he_loss: 0.9583 - ma_loss: 0.9890 - se_loss: 0.9926
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9202 - mask_loss: 0.9682 - loss_recons: 0.0080 - ex_loss: 0.9621 - he_loss: 0.9639 - ma_loss: 0.9888 - se_loss: 0.9947
#
# Epoch 11/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9192 - mask_loss: 0.9671 - loss_recons: 0.0089 - ex_loss: 0.9618 - he_loss: 0.9576 - ma_loss: 0.9884 - se_loss: 0.9925
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9227 - mask_loss: 0.9708 - loss_recons: 0.0077 - ex_loss: 0.9660 - he_loss: 0.9636 - ma_loss: 0.9881 - se_loss: 0.9946
#
# Epoch 12/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9177 - mask_loss: 0.9656 - loss_recons: 0.0085 - ex_loss: 0.9598 - he_loss: 0.9569 - ma_loss: 0.9879 - se_loss: 0.9923
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9192 - mask_loss: 0.9672 - loss_recons: 0.0072 - ex_loss: 0.9611 - he_loss: 0.9622 - ma_loss: 0.9878 - se_loss: 0.9946
#
# Epoch 13/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9164 - mask_loss: 0.9642 - loss_recons: 0.0082 - ex_loss: 0.9581 - he_loss: 0.9561 - ma_loss: 0.9873 - se_loss: 0.9922
# 552/552 [==============================] - 122s 222ms/step - val_loss: 0.9231 - mask_loss: 0.9713 - loss_recons: 0.0073 - ex_loss: 0.9661 - he_loss: 0.9667 - ma_loss: 0.9887 - se_loss: 0.9948
#
# Epoch 14/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9148 - mask_loss: 0.9625 - loss_recons: 0.0078 - ex_loss: 0.9557 - he_loss: 0.9557 - ma_loss: 0.9872 - se_loss: 0.9922
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9130 - mask_loss: 0.9606 - loss_recons: 0.0067 - ex_loss: 0.9521 - he_loss: 0.9610 - ma_loss: 0.9866 - se_loss: 0.9944
#
# Epoch 15/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.9128 - mask_loss: 0.9604 - loss_recons: 0.0073 - ex_loss: 0.9530 - he_loss: 0.9546 - ma_loss: 0.9863 - se_loss: 0.9920
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.9117 - mask_loss: 0.9594 - loss_recons: 0.0060 - ex_loss: 0.9503 - he_loss: 0.9606 - ma_loss: 0.9864 - se_loss: 0.9947
#
# Epoch 16/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9109 - mask_loss: 0.9585 - loss_recons: 0.0067 - ex_loss: 0.9505 - he_loss: 0.9540 - ma_loss: 0.9854 - se_loss: 0.9919
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9106 - mask_loss: 0.9582 - loss_recons: 0.0055 - ex_loss: 0.9488 - he_loss: 0.9607 - ma_loss: 0.9860 - se_loss: 0.9943
#
# Epoch 17/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.9090 - mask_loss: 0.9565 - loss_recons: 0.0061 - ex_loss: 0.9479 - he_loss: 0.9532 - ma_loss: 0.9850 - se_loss: 0.9917
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9112 - mask_loss: 0.9589 - loss_recons: 0.0052 - ex_loss: 0.9495 - he_loss: 0.9626 - ma_loss: 0.9861 - se_loss: 0.9942
#
# Epoch 18/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.9073 - mask_loss: 0.9547 - loss_recons: 0.0056 - ex_loss: 0.9455 - he_loss: 0.9528 - ma_loss: 0.9841 - se_loss: 0.9917
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9167 - mask_loss: 0.9647 - loss_recons: 0.0043 - ex_loss: 0.9576 - he_loss: 0.9618 - ma_loss: 0.9873 - se_loss: 0.9949
#
# Epoch 19/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9053 - mask_loss: 0.9526 - loss_recons: 0.0050 - ex_loss: 0.9427 - he_loss: 0.9523 - ma_loss: 0.9835 - se_loss: 0.9915
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9160 - mask_loss: 0.9640 - loss_recons: 0.0039 - ex_loss: 0.9570 - he_loss: 0.9596 - ma_loss: 0.9862 - se_loss: 0.9949
#
# Epoch 20/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9029 - mask_loss: 0.9502 - loss_recons: 0.0044 - ex_loss: 0.9395 - he_loss: 0.9512 - ma_loss: 0.9827 - se_loss: 0.9913
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9050 - mask_loss: 0.9525 - loss_recons: 0.0033 - ex_loss: 0.9405 - he_loss: 0.9620 - ma_loss: 0.9849 - se_loss: 0.9949
#
# Epoch 21/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.9005 - mask_loss: 0.9477 - loss_recons: 0.0040 - ex_loss: 0.9363 - he_loss: 0.9502 - ma_loss: 0.9817 - se_loss: 0.9913
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9048 - mask_loss: 0.9523 - loss_recons: 0.0030 - ex_loss: 0.9405 - he_loss: 0.9595 - ma_loss: 0.9841 - se_loss: 0.9955
#
# Epoch 22/100
# 1108/1108 [==============================] - 631s 570ms/step - train_loss: 0.8979 - mask_loss: 0.9450 - loss_recons: 0.0036 - ex_loss: 0.9326 - he_loss: 0.9495 - ma_loss: 0.9808 - se_loss: 0.9912
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.9085 - mask_loss: 0.9562 - loss_recons: 0.0025 - ex_loss: 0.9464 - he_loss: 0.9581 - ma_loss: 0.9849 - se_loss: 0.9943
#
# Epoch 23/100
# 1108/1108 [==============================] - 631s 570ms/step - train_loss: 0.8949 - mask_loss: 0.9419 - loss_recons: 0.0032 - ex_loss: 0.9285 - he_loss: 0.9484 - ma_loss: 0.9797 - se_loss: 0.9910
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.8990 - mask_loss: 0.9462 - loss_recons: 0.0023 - ex_loss: 0.9322 - he_loss: 0.9591 - ma_loss: 0.9830 - se_loss: 0.9945
#
# Epoch 24/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8924 - mask_loss: 0.9392 - loss_recons: 0.0030 - ex_loss: 0.9250 - he_loss: 0.9478 - ma_loss: 0.9787 - se_loss: 0.9909
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8986 - mask_loss: 0.9458 - loss_recons: 0.0020 - ex_loss: 0.9308 - he_loss: 0.9604 - ma_loss: 0.9872 - se_loss: 0.9953
#
# Epoch 25/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8896 - mask_loss: 0.9362 - loss_recons: 0.0029 - ex_loss: 0.9210 - he_loss: 0.9467 - ma_loss: 0.9777 - se_loss: 0.9908
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8943 - mask_loss: 0.9412 - loss_recons: 0.0019 - ex_loss: 0.9254 - he_loss: 0.9571 - ma_loss: 0.9828 - se_loss: 0.9947
#
# Epoch 26/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8866 - mask_loss: 0.9331 - loss_recons: 0.0027 - ex_loss: 0.9168 - he_loss: 0.9460 - ma_loss: 0.9773 - se_loss: 0.9906
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.9100 - mask_loss: 0.9578 - loss_recons: 0.0020 - ex_loss: 0.9466 - he_loss: 0.9690 - ma_loss: 0.9871 - se_loss: 0.9952
#
# Epoch 27/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.8835 - mask_loss: 0.9298 - loss_recons: 0.0026 - ex_loss: 0.9124 - he_loss: 0.9452 - ma_loss: 0.9762 - se_loss: 0.9906
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8892 - mask_loss: 0.9359 - loss_recons: 0.0019 - ex_loss: 0.9183 - he_loss: 0.9557 - ma_loss: 0.9806 - se_loss: 0.9944
#
# Epoch 28/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.8793 - mask_loss: 0.9255 - loss_recons: 0.0024 - ex_loss: 0.9065 - he_loss: 0.9441 - ma_loss: 0.9748 - se_loss: 0.9905
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8843 - mask_loss: 0.9307 - loss_recons: 0.0014 - ex_loss: 0.9107 - he_loss: 0.9566 - ma_loss: 0.9820 - se_loss: 0.9940
#
# Epoch 29/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.8751 - mask_loss: 0.9210 - loss_recons: 0.0023 - ex_loss: 0.9005 - he_loss: 0.9427 - ma_loss: 0.9735 - se_loss: 0.9903
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8848 - mask_loss: 0.9313 - loss_recons: 0.0016 - ex_loss: 0.9121 - he_loss: 0.9539 - ma_loss: 0.9797 - se_loss: 0.9944
#
# Epoch 30/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8710 - mask_loss: 0.9167 - loss_recons: 0.0022 - ex_loss: 0.8947 - he_loss: 0.9416 - ma_loss: 0.9724 - se_loss: 0.9901
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8832 - mask_loss: 0.9296 - loss_recons: 0.0013 - ex_loss: 0.9094 - he_loss: 0.9541 - ma_loss: 0.9818 - se_loss: 0.9944
#
# Epoch 31/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.8669 - mask_loss: 0.9125 - loss_recons: 0.0021 - ex_loss: 0.8889 - he_loss: 0.9407 - ma_loss: 0.9714 - se_loss: 0.9900
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8836 - mask_loss: 0.9301 - loss_recons: 0.0012 - ex_loss: 0.9102 - he_loss: 0.9550 - ma_loss: 0.9800 - se_loss: 0.9940
#
# Epoch 32/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8622 - mask_loss: 0.9075 - loss_recons: 0.0021 - ex_loss: 0.8820 - he_loss: 0.9410 - ma_loss: 0.9701 - se_loss: 0.9899
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8743 - mask_loss: 0.9202 - loss_recons: 0.0013 - ex_loss: 0.8961 - he_loss: 0.9547 - ma_loss: 0.9807 - se_loss: 0.9945
#
# Epoch 33/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.8570 - mask_loss: 0.9020 - loss_recons: 0.0020 - ex_loss: 0.8746 - he_loss: 0.9390 - ma_loss: 0.9686 - se_loss: 0.9898
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8767 - mask_loss: 0.9227 - loss_recons: 0.0012 - ex_loss: 0.9000 - he_loss: 0.9539 - ma_loss: 0.9790 - se_loss: 0.9942
#
# Epoch 34/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8516 - mask_loss: 0.8963 - loss_recons: 0.0021 - ex_loss: 0.8668 - he_loss: 0.9380 - ma_loss: 0.9673 - se_loss: 0.9896
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8744 - mask_loss: 0.9204 - loss_recons: 0.0012 - ex_loss: 0.8971 - he_loss: 0.9526 - ma_loss: 0.9779 - se_loss: 0.9938
#
# Epoch 35/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.8460 - mask_loss: 0.8904 - loss_recons: 0.0019 - ex_loss: 0.8589 - he_loss: 0.9373 - ma_loss: 0.9655 - se_loss: 0.9895
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8654 - mask_loss: 0.9109 - loss_recons: 0.0012 - ex_loss: 0.8835 - he_loss: 0.9530 - ma_loss: 0.9776 - se_loss: 0.9941
#
# Epoch 36/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8399 - mask_loss: 0.8840 - loss_recons: 0.0019 - ex_loss: 0.8501 - he_loss: 0.9360 - ma_loss: 0.9641 - se_loss: 0.9895
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8570 - mask_loss: 0.9020 - loss_recons: 0.0010 - ex_loss: 0.8705 - he_loss: 0.9509 - ma_loss: 0.9818 - se_loss: 0.9938
#
# Epoch 37/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.8335 - mask_loss: 0.8773 - loss_recons: 0.0019 - ex_loss: 0.8409 - he_loss: 0.9351 - ma_loss: 0.9623 - se_loss: 0.9893
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8624 - mask_loss: 0.9077 - loss_recons: 0.0012 - ex_loss: 0.8787 - he_loss: 0.9549 - ma_loss: 0.9776 - se_loss: 0.9934
#
# Epoch 38/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.8266 - mask_loss: 0.8700 - loss_recons: 0.0019 - ex_loss: 0.8309 - he_loss: 0.9339 - ma_loss: 0.9605 - se_loss: 0.9891
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8545 - mask_loss: 0.8994 - loss_recons: 0.0010 - ex_loss: 0.8672 - he_loss: 0.9514 - ma_loss: 0.9773 - se_loss: 0.9943
#
# Epoch 39/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.8193 - mask_loss: 0.8623 - loss_recons: 0.0019 - ex_loss: 0.8203 - he_loss: 0.9330 - ma_loss: 0.9587 - se_loss: 0.9890
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8493 - mask_loss: 0.8940 - loss_recons: 0.0010 - ex_loss: 0.8598 - he_loss: 0.9516 - ma_loss: 0.9759 - se_loss: 0.9935
#
# Epoch 40/100
# 1108/1108 [==============================] - 629s 567ms/step - train_loss: 0.8130 - mask_loss: 0.8557 - loss_recons: 0.0018 - ex_loss: 0.8113 - he_loss: 0.9324 - ma_loss: 0.9571 - se_loss: 0.9889
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8490 - mask_loss: 0.8936 - loss_recons: 0.0016 - ex_loss: 0.8594 - he_loss: 0.9502 - ma_loss: 0.9758 - se_loss: 0.9941
#
# Epoch 41/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.8044 - mask_loss: 0.8466 - loss_recons: 0.0018 - ex_loss: 0.7986 - he_loss: 0.9317 - ma_loss: 0.9553 - se_loss: 0.9888
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8359 - mask_loss: 0.8798 - loss_recons: 0.0011 - ex_loss: 0.8389 - he_loss: 0.9565 - ma_loss: 0.9762 - se_loss: 0.9929
#
# Epoch 42/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.7957 - mask_loss: 0.8375 - loss_recons: 0.0018 - ex_loss: 0.7862 - he_loss: 0.9301 - ma_loss: 0.9527 - se_loss: 0.9887
# 552/552 [==============================] - 122s 222ms/step - val_loss: 0.8298 - mask_loss: 0.8735 - loss_recons: 0.0012 - ex_loss: 0.8304 - he_loss: 0.9515 - ma_loss: 0.9770 - se_loss: 0.9930
#
# Epoch 43/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.7866 - mask_loss: 0.8279 - loss_recons: 0.0017 - ex_loss: 0.7730 - he_loss: 0.9292 - ma_loss: 0.9509 - se_loss: 0.9886
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8236 - mask_loss: 0.8669 - loss_recons: 9.9457e-04 - ex_loss: 0.8219 - he_loss: 0.9506 - ma_loss: 0.9709 - se_loss: 0.9943
#
# Epoch 44/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.7770 - mask_loss: 0.8178 - loss_recons: 0.0017 - ex_loss: 0.7591 - he_loss: 0.9279 - ma_loss: 0.9479 - se_loss: 0.9883
# 552/552 [==============================] - 123s 224ms/step - val_loss: 0.8192 - mask_loss: 0.8623 - loss_recons: 9.3862e-04 - ex_loss: 0.8146 - he_loss: 0.9521 - ma_loss: 0.9746 - se_loss: 0.9935
#
# Epoch 45/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.7667 - mask_loss: 0.8069 - loss_recons: 0.0017 - ex_loss: 0.7442 - he_loss: 0.9266 - ma_loss: 0.9451 - se_loss: 0.9882
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.8137 - mask_loss: 0.8565 - loss_recons: 9.9189e-04 - ex_loss: 0.8065 - he_loss: 0.9500 - ma_loss: 0.9766 - se_loss: 0.9929
#
# Epoch 46/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.7565 - mask_loss: 0.7963 - loss_recons: 0.0018 - ex_loss: 0.7296 - he_loss: 0.9255 - ma_loss: 0.9422 - se_loss: 0.9880
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8201 - mask_loss: 0.8632 - loss_recons: 9.4216e-04 - ex_loss: 0.8161 - he_loss: 0.9508 - ma_loss: 0.9751 - se_loss: 0.9936
#
# Epoch 47/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.7453 - mask_loss: 0.7844 - loss_recons: 0.0017 - ex_loss: 0.7132 - he_loss: 0.9246 - ma_loss: 0.9390 - se_loss: 0.9879
# 552/552 [==============================] - 123s 224ms/step - val_loss: 0.8123 - mask_loss: 0.8550 - loss_recons: 0.0010 - ex_loss: 0.8040 - he_loss: 0.9524 - ma_loss: 0.9760 - se_loss: 0.9932
#
# Epoch 48/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.7332 - mask_loss: 0.7718 - loss_recons: 0.0017 - ex_loss: 0.6958 - he_loss: 0.9232 - ma_loss: 0.9357 - se_loss: 0.9877
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.8075 - mask_loss: 0.8499 - loss_recons: 9.7413e-04 - ex_loss: 0.7983 - he_loss: 0.9459 - ma_loss: 0.9728 - se_loss: 0.9928
#
# Epoch 49/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.7230 - mask_loss: 0.7609 - loss_recons: 0.0017 - ex_loss: 0.6809 - he_loss: 0.9223 - ma_loss: 0.9330 - se_loss: 0.9876
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7943 - mask_loss: 0.8361 - loss_recons: 0.0010 - ex_loss: 0.7783 - he_loss: 0.9464 - ma_loss: 0.9719 - se_loss: 0.9941
#
# Epoch 50/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.7106 - mask_loss: 0.7480 - loss_recons: 0.0017 - ex_loss: 0.6633 - he_loss: 0.9209 - ma_loss: 0.9285 - se_loss: 0.9874
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7910 - mask_loss: 0.8326 - loss_recons: 9.0889e-04 - ex_loss: 0.7734 - he_loss: 0.9454 - ma_loss: 0.9739 - se_loss: 0.9929
#
# Epoch 51/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6970 - mask_loss: 0.7336 - loss_recons: 0.0017 - ex_loss: 0.6435 - he_loss: 0.9197 - ma_loss: 0.9244 - se_loss: 0.9873
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7764 - mask_loss: 0.8173 - loss_recons: 0.0012 - ex_loss: 0.7517 - he_loss: 0.9478 - ma_loss: 0.9700 - se_loss: 0.9925
#
# Epoch 52/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6829 - mask_loss: 0.7188 - loss_recons: 0.0016 - ex_loss: 0.6232 - he_loss: 0.9182 - ma_loss: 0.9200 - se_loss: 0.9871
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7658 - mask_loss: 0.8061 - loss_recons: 8.9286e-04 - ex_loss: 0.7359 - he_loss: 0.9486 - ma_loss: 0.9687 - se_loss: 0.9927
#
# Epoch 53/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6693 - mask_loss: 0.7045 - loss_recons: 0.0016 - ex_loss: 0.6037 - he_loss: 0.9172 - ma_loss: 0.9145 - se_loss: 0.9869
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7692 - mask_loss: 0.8096 - loss_recons: 0.0012 - ex_loss: 0.7411 - he_loss: 0.9467 - ma_loss: 0.9686 - se_loss: 0.9925
#
# Epoch 54/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.6566 - mask_loss: 0.6911 - loss_recons: 0.0016 - ex_loss: 0.5854 - he_loss: 0.9157 - ma_loss: 0.9108 - se_loss: 0.9867
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7552 - mask_loss: 0.7950 - loss_recons: 8.6435e-04 - ex_loss: 0.7207 - he_loss: 0.9448 - ma_loss: 0.9669 - se_loss: 0.9929
#
# Epoch 55/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.6438 - mask_loss: 0.6776 - loss_recons: 0.0016 - ex_loss: 0.5671 - he_loss: 0.9146 - ma_loss: 0.9052 - se_loss: 0.9866
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.7593 - mask_loss: 0.7991 - loss_recons: 0.0012 - ex_loss: 0.7259 - he_loss: 0.9448 - ma_loss: 0.9725 - se_loss: 0.9928
#
# Epoch 56/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6311 - mask_loss: 0.6642 - loss_recons: 0.0016 - ex_loss: 0.5489 - he_loss: 0.9132 - ma_loss: 0.8998 - se_loss: 0.9864
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7596 - mask_loss: 0.7995 - loss_recons: 0.0013 - ex_loss: 0.7262 - he_loss: 0.9494 - ma_loss: 0.9681 - se_loss: 0.9936
#
# Epoch 57/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6169 - mask_loss: 0.6493 - loss_recons: 0.0016 - ex_loss: 0.5287 - he_loss: 0.9120 - ma_loss: 0.8937 - se_loss: 0.9862
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7310 - mask_loss: 0.7694 - loss_recons: 9.9306e-04 - ex_loss: 0.6845 - he_loss: 0.9401 - ma_loss: 0.9703 - se_loss: 0.9922
#
# Epoch 58/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.6009 - mask_loss: 0.6324 - loss_recons: 0.0015 - ex_loss: 0.5060 - he_loss: 0.9100 - ma_loss: 0.8865 - se_loss: 0.9860
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7188 - mask_loss: 0.7565 - loss_recons: 9.4324e-04 - ex_loss: 0.6667 - he_loss: 0.9405 - ma_loss: 0.9657 - se_loss: 0.9921
#
# Epoch 59/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.5877 - mask_loss: 0.6185 - loss_recons: 0.0015 - ex_loss: 0.4874 - he_loss: 0.9087 - ma_loss: 0.8790 - se_loss: 0.9859
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7254 - mask_loss: 0.7635 - loss_recons: 0.0014 - ex_loss: 0.6756 - he_loss: 0.9450 - ma_loss: 0.9683 - se_loss: 0.9925
#
# Epoch 60/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.5741 - mask_loss: 0.6042 - loss_recons: 0.0016 - ex_loss: 0.4681 - he_loss: 0.9075 - ma_loss: 0.8722 - se_loss: 0.9857
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7237 - mask_loss: 0.7617 - loss_recons: 9.5672e-04 - ex_loss: 0.6750 - he_loss: 0.9393 - ma_loss: 0.9597 - se_loss: 0.9931
#
# Epoch 61/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.5613 - mask_loss: 0.5907 - loss_recons: 0.0015 - ex_loss: 0.4500 - he_loss: 0.9061 - ma_loss: 0.8657 - se_loss: 0.9856
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7186 - mask_loss: 0.7564 - loss_recons: 8.7569e-04 - ex_loss: 0.6652 - he_loss: 0.9447 - ma_loss: 0.9714 - se_loss: 0.9920
#
# Epoch 62/100
# 1108/1108 [==============================] - 631s 570ms/step - train_loss: 0.5494 - mask_loss: 0.5782 - loss_recons: 0.0015 - ex_loss: 0.4336 - he_loss: 0.9047 - ma_loss: 0.8567 - se_loss: 0.9854
# 552/552 [==============================] - 124s 225ms/step - val_loss: 0.6966 - mask_loss: 0.7332 - loss_recons: 8.9522e-04 - ex_loss: 0.6336 - he_loss: 0.9400 - ma_loss: 0.9641 - se_loss: 0.9925
#
# Epoch 63/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.5368 - mask_loss: 0.5650 - loss_recons: 0.0015 - ex_loss: 0.4163 - he_loss: 0.9031 - ma_loss: 0.8479 - se_loss: 0.9851
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6921 - mask_loss: 0.7285 - loss_recons: 8.7503e-04 - ex_loss: 0.6271 - he_loss: 0.9388 - ma_loss: 0.9637 - se_loss: 0.9928
#
# Epoch 64/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.5248 - mask_loss: 0.5523 - loss_recons: 0.0016 - ex_loss: 0.3998 - he_loss: 0.9017 - ma_loss: 0.8379 - se_loss: 0.9849
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.7015 - mask_loss: 0.7384 - loss_recons: 0.0011 - ex_loss: 0.6420 - he_loss: 0.9360 - ma_loss: 0.9615 - se_loss: 0.9924
#
# Epoch 65/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.5125 - mask_loss: 0.5394 - loss_recons: 0.0015 - ex_loss: 0.3830 - he_loss: 0.8997 - ma_loss: 0.8281 - se_loss: 0.9847
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.7122 - mask_loss: 0.7496 - loss_recons: 0.0018 - ex_loss: 0.6563 - he_loss: 0.9422 - ma_loss: 0.9676 - se_loss: 0.9919
#
# Epoch 66/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.5002 - mask_loss: 0.5264 - loss_recons: 0.0015 - ex_loss: 0.3663 - he_loss: 0.8984 - ma_loss: 0.8174 - se_loss: 0.9844
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6961 - mask_loss: 0.7327 - loss_recons: 8.5659e-04 - ex_loss: 0.6347 - he_loss: 0.9383 - ma_loss: 0.9537 - se_loss: 0.9919
#
# Epoch 67/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4882 - mask_loss: 0.5138 - loss_recons: 0.0015 - ex_loss: 0.3503 - he_loss: 0.8966 - ma_loss: 0.8047 - se_loss: 0.9842
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6818 - mask_loss: 0.7176 - loss_recons: 0.0013 - ex_loss: 0.6121 - he_loss: 0.9423 - ma_loss: 0.9573 - se_loss: 0.9916
#
# Epoch 68/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4778 - mask_loss: 0.5029 - loss_recons: 0.0014 - ex_loss: 0.3368 - he_loss: 0.8949 - ma_loss: 0.7926 - se_loss: 0.9840
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6602 - mask_loss: 0.6949 - loss_recons: 8.7925e-04 - ex_loss: 0.5816 - he_loss: 0.9387 - ma_loss: 0.9481 - se_loss: 0.9915
#
# Epoch 69/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4671 - mask_loss: 0.4916 - loss_recons: 0.0014 - ex_loss: 0.3228 - he_loss: 0.8930 - ma_loss: 0.7797 - se_loss: 0.9838
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6630 - mask_loss: 0.6979 - loss_recons: 0.0016 - ex_loss: 0.5835 - he_loss: 0.9445 - ma_loss: 0.9574 - se_loss: 0.9922
#
# Epoch 70/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4586 - mask_loss: 0.4826 - loss_recons: 0.0015 - ex_loss: 0.3119 - he_loss: 0.8916 - ma_loss: 0.7679 - se_loss: 0.9836
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6656 - mask_loss: 0.7006 - loss_recons: 8.7293e-04 - ex_loss: 0.5890 - he_loss: 0.9369 - ma_loss: 0.9555 - se_loss: 0.9912
#
# Epoch 71/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4517 - mask_loss: 0.4754 - loss_recons: 0.0015 - ex_loss: 0.3032 - he_loss: 0.8903 - ma_loss: 0.7575 - se_loss: 0.9835
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6638 - mask_loss: 0.6987 - loss_recons: 8.7244e-04 - ex_loss: 0.5895 - he_loss: 0.9304 - ma_loss: 0.9396 - se_loss: 0.9908
#
# Epoch 72/100
# 1108/1108 [==============================] - 631s 570ms/step - train_loss: 0.4401 - mask_loss: 0.4632 - loss_recons: 0.0014 - ex_loss: 0.2888 - he_loss: 0.8881 - ma_loss: 0.7390 - se_loss: 0.9832
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6791 - mask_loss: 0.7148 - loss_recons: 8.8761e-04 - ex_loss: 0.6080 - he_loss: 0.9323 - ma_loss: 0.9673 - se_loss: 0.9922
#
# Epoch 73/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.4297 - mask_loss: 0.4523 - loss_recons: 0.0014 - ex_loss: 0.2759 - he_loss: 0.8864 - ma_loss: 0.7221 - se_loss: 0.9829
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6850 - mask_loss: 0.7210 - loss_recons: 8.9108e-04 - ex_loss: 0.6164 - he_loss: 0.9302 - ma_loss: 0.9746 - se_loss: 0.9906
#
# Epoch 74/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.4178 - mask_loss: 0.4397 - loss_recons: 0.0014 - ex_loss: 0.2606 - he_loss: 0.8840 - ma_loss: 0.7057 - se_loss: 0.9826
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6789 - mask_loss: 0.7146 - loss_recons: 8.9326e-04 - ex_loss: 0.6076 - he_loss: 0.9369 - ma_loss: 0.9656 - se_loss: 0.9905
#
# Epoch 75/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.4097 - mask_loss: 0.4312 - loss_recons: 0.0014 - ex_loss: 0.2509 - he_loss: 0.8819 - ma_loss: 0.6918 - se_loss: 0.9824
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6840 - mask_loss: 0.7200 - loss_recons: 8.8717e-04 - ex_loss: 0.6157 - he_loss: 0.9359 - ma_loss: 0.9623 - se_loss: 0.9913
#
# Epoch 76/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.4022 - mask_loss: 0.4233 - loss_recons: 0.0013 - ex_loss: 0.2428 - he_loss: 0.8797 - ma_loss: 0.6719 - se_loss: 0.9821
# 552/552 [==============================] - 124s 225ms/step - val_loss: 0.6745 - mask_loss: 0.7100 - loss_recons: 8.2234e-04 - ex_loss: 0.6042 - he_loss: 0.9282 - ma_loss: 0.9514 - se_loss: 0.9906
#
# Epoch 77/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.3978 - mask_loss: 0.4187 - loss_recons: 0.0014 - ex_loss: 0.2383 - he_loss: 0.8782 - ma_loss: 0.6584 - se_loss: 0.9819
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6863 - mask_loss: 0.7224 - loss_recons: 0.0010 - ex_loss: 0.6203 - he_loss: 0.9254 - ma_loss: 0.9650 - se_loss: 0.9913
#
# Epoch 78/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.3894 - mask_loss: 0.4098 - loss_recons: 0.0014 - ex_loss: 0.2287 - he_loss: 0.8762 - ma_loss: 0.6393 - se_loss: 0.9816
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6925 - mask_loss: 0.7289 - loss_recons: 8.6550e-04 - ex_loss: 0.6289 - he_loss: 0.9327 - ma_loss: 0.9618 - se_loss: 0.9920
#
# Epoch 79/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.3809 - mask_loss: 0.4009 - loss_recons: 0.0013 - ex_loss: 0.2198 - he_loss: 0.8739 - ma_loss: 0.6157 - se_loss: 0.9814
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6703 - mask_loss: 0.7055 - loss_recons: 8.6974e-04 - ex_loss: 0.5968 - he_loss: 0.9316 - ma_loss: 0.9547 - se_loss: 0.9911
#
# Epoch 80/100
# 1108/1108 [==============================] - 630s 568ms/step - train_loss: 0.3754 - mask_loss: 0.3951 - loss_recons: 0.0014 - ex_loss: 0.2147 - he_loss: 0.8719 - ma_loss: 0.5949 - se_loss: 0.9811
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6749 - mask_loss: 0.7103 - loss_recons: 9.0302e-04 - ex_loss: 0.6010 - he_loss: 0.9302 - ma_loss: 0.9758 - se_loss: 0.9907
#
# Epoch 81/100
# 1108/1108 [==============================] - 634s 572ms/step - train_loss: 0.3672 - mask_loss: 0.3865 - loss_recons: 0.0013 - ex_loss: 0.2054 - he_loss: 0.8697 - ma_loss: 0.5764 - se_loss: 0.9808
# 552/552 [==============================] - 125s 227ms/step - val_loss: 0.6690 - mask_loss: 0.7041 - loss_recons: 9.8557e-04 - ex_loss: 0.5968 - he_loss: 0.9201 - ma_loss: 0.9528 - se_loss: 0.9912
#
# Epoch 82/100
# 1108/1108 [==============================] - 630s 569ms/step - train_loss: 0.3616 - mask_loss: 0.3805 - loss_recons: 0.0013 - ex_loss: 0.2008 - he_loss: 0.8675 - ma_loss: 0.5514 - se_loss: 0.9805
# 552/552 [==============================] - 123s 224ms/step - val_loss: 0.6648 - mask_loss: 0.6998 - loss_recons: 0.0011 - ex_loss: 0.5943 - he_loss: 0.9251 - ma_loss: 0.9214 - se_loss: 0.9910
#
# Epoch 83/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.3768 - mask_loss: 0.3965 - loss_recons: 0.0016 - ex_loss: 0.2248 - he_loss: 0.8688 - ma_loss: 0.5424 - se_loss: 0.9806
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6659 - mask_loss: 0.7009 - loss_recons: 0.0013 - ex_loss: 0.5892 - he_loss: 0.9329 - ma_loss: 0.9601 - se_loss: 0.9911
#
# Epoch 84/100
# 1108/1108 [==============================] - 632s 570ms/step - train_loss: 0.3531 - mask_loss: 0.3717 - loss_recons: 0.0013 - ex_loss: 0.1934 - he_loss: 0.8639 - ma_loss: 0.5188 - se_loss: 0.9801
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6782 - mask_loss: 0.7139 - loss_recons: 8.9589e-04 - ex_loss: 0.6155 - he_loss: 0.9270 - ma_loss: 0.9137 - se_loss: 0.9898
#
# Epoch 85/100
# 1108/1108 [==============================] - 631s 569ms/step - train_loss: 0.3442 - mask_loss: 0.3622 - loss_recons: 0.0012 - ex_loss: 0.1836 - he_loss: 0.8607 - ma_loss: 0.4964 - se_loss: 0.9798
# 552/552 [==============================] - 123s 224ms/step - val_loss: 0.6469 - mask_loss: 0.6809 - loss_recons: 8.9519e-04 - ex_loss: 0.5668 - he_loss: 0.9227 - ma_loss: 0.9283 - se_loss: 0.9904
#
# Epoch 86/100
# 1108/1108 [==============================] - 632s 571ms/step - train_loss: 0.3384 - mask_loss: 0.3561 - loss_recons: 0.0012 - ex_loss: 0.1780 - he_loss: 0.8580 - ma_loss: 0.4780 - se_loss: 0.9794
# 416/552 [=====================>........] - ETA: 30s - val_loss: 0.6774 - mask_loss: 0.7129 - loss_recons: 0.0013 - ex_loss: 0.6332 - he_loss: 0.7930 - ma_loss: 0.9043 - se_loss: 0.9998

# %% [markdown]
# ## history 그려보기

# %%
from assets.four_mask.utils import parse_history_text
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import os

# %%
os.listdir('history/four_mask')
# Out:
# ['SMD_withoutCLAHE_lr00001_3channel_alpha005_beta07010101.txt',
#  'SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025.txt',
#  'test.txt']

# %%
history = parse_history_text('history/four_mask/SMD_withoutCLAHE_lr00001_3channel_alpha005_beta07010101.txt')


plt.figure(figsize=(10, 5))
plt.title('with reconstruction')
plt.plot(history['epoch'], history['train_mask_loss'], label='train_mask_loss')
plt.plot(history['epoch'], history['val_mask_loss'], label='val_mask_loss')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))
plt.legend()

plt.show()

plt.figure(figsize=(20, 10))

plt.subplot(2, 2, 1)
plt.title('EX (Hard Execute)')
plt.plot(history['epoch'], history['tr_ex_loss'], label='tr_ex_loss')
plt.plot(history['epoch'], history['val_ex_loss'], label='val_ex_loss')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))
plt.legend()


plt.subplot(2, 2, 2)
plt.title('HE (Hemorrhege)')
plt.plot(history['epoch'], history['tr_he_loss'], label='tr_he_loss')
plt.plot(history['epoch'], history['val_he_loss'], label='val_he_loss')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))
plt.legend()


plt.subplot(2, 2, 3)
plt.title("MA (Microaneurysm)")
plt.plot(history['epoch'], history['tr_ma_loss'], label='tr_ma_loss')
plt.plot(history['epoch'], history['val_ma_loss'], label='val_ma_loss')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))
plt.legend()



plt.subplot(2, 2, 4)
plt.title("SE (Soft Execute)")
plt.plot(history['epoch'], history['tr_se_loss'], label='tr_se_loss')
plt.plot(history['epoch'], history['val_se_loss'], label='val_se_loss')
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))
plt.legend()

plt.show()

# %% [markdown]
# # Pretraining

# %%
import tensorflow as tf
import os

from assets.one_mask.data_generator import DR_Generator
from assets.one_mask.models import SMD_Unet 
from assets.one_mask.trainer import Trainer

# %%
generator_args = {
    'dir_path':'../data/preprocessed/',
    'mask_path':None,
    'use_mask':False,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'EyePacks', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':None,
    'add_noise_std':0.2
}
 
    
tr_eyepacks_gen = DR_Generator(start_end_index=(33000, 34000), **generator_args)
val_eyepacks_gen = DR_Generator(start_end_index=(30000, 33000), **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
# model.load_weights("../models/one_mask/withoutCLAHE_withRecons_alpha01_lr0001_3channel/21")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':True,
    'alpha':1.0,
    'beta':None,
    'first_epoch':1,
    'file_name':"history/one_mask/pretraning_lr00001_3channel.txt",
    'save_model_path':"../models/one_mask/pretraning_lr00001_3channel",
    'add_noise':True
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_eyepacks_gen,
              val_dataset=val_eyepacks_gen
             )
# Out:
# Epoch 1/50
# 816/816 [==============================] - 210s 258ms/step - train_loss: 0.0070 - loss_recons: 0.0070
# 3000/3000 [==============================] - 398s 133ms/step - val_loss: 0.0057 - loss_recons: 0.0057
#
# Epoch 2/50
#  20/816 [..............................] - ETA: 3:05 - train_loss: 0.0060 - loss_recons: 0.0060
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2625/1947736279.py in <module>
#      15 trainer = Trainer(**trainer_args)
#      16
# ---> 17 trainer.train(train_dataset=tr_eyepacks_gen,
#      18               val_dataset=val_eyepacks_gen
#      19              )
#
# ~/aiffel/Visuworks/code/assets/one_mask/trainer.py in train(self, train_dataset, val_dataset)
#     144             total_batch_loss = []
#     145
# --> 146             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#     147                 if not self.for_recons:
#     148                     loss_recons, train_loss, mask_loss = self.train_on_batch(x_batch_train, y_batch_train)
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in __iter__(self)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in <genexpr>(.0)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# ~/aiffel/Visuworks/code/assets/one_mask/data_generator.py in __getitem__(self, index)
#     184         if self.dataset == "EyePacks":
#     185             if self.add_noise_std != None:
# --> 186                 return [tf.cast(inputs, dtype=tf.float32), tf.cast(noisy_inputs, dtype=tf.float32)], None
#     187
#     188             return [tf.cast(inputs, dtype=tf.float32)], None
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     986       # allows some conversions that cast() can't do, e.g. casting numbers to
#     987       # strings.
# --> 988       x = ops.convert_to_tensor(x, name="x")
#     989       if x.dtype.base_dtype != base_type:
#     990         x = gen_math_ops.cast(x, base_type, name=name)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# KeyboardInterrupt:

# %% [markdown]
# # Functional API로 해보기

# %%
from assets.test.data_generator import DR_Generator
import os
from assets.one_mask.functional_models import Unet 
# from assets.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

# %%
unet = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
unet = Unet(filters=[64, 128, 256, 512, 1024], img_size=(512, 512))

# %%
unet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss=dice_coef_loss)

# %%
unet.fit(tr_fgadr_gen, 
         validation_data=val_fgadr_gen, 
         epochs=50)
# Out:
# Epoch 1/50
# 323/323 [==============================] - 283s 843ms/step - loss: 0.9407 - val_loss: 0.9566
# Epoch 2/50
# 323/323 [==============================] - 270s 835ms/step - loss: 0.9254 - val_loss: 0.9424
# Epoch 3/50
# 323/323 [==============================] - 270s 834ms/step - loss: 0.8758 - val_loss: 0.9287
# Epoch 4/50
# 323/323 [==============================] - 271s 837ms/step - loss: 0.7606 - val_loss: 0.7711
# Epoch 5/50
# 323/323 [==============================] - 271s 839ms/step - loss: 0.6844 - val_loss: 0.6974
# Epoch 6/50
#  79/323 [======>.......................] - ETA: 3:09 - loss: 0.6341
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1574/4028299692.py in <module>
# ----> 1 unet.fit(tr_fgadr_gen,
#       2          validation_data=val_fgadr_gen,
#       3          epochs=50)
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# trainer에 문제가 있는 거구나

# %% [markdown]
# # mask만 학습시켜보기

# %%
from assets.test.data_generator import DR_Generator
import os
# from assets.one_mask.functional_models import Unet 
from assets.test.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':False,
    'alpha':0.0,
    'beta':None,
    'first_epoch':1,
#     'file_name':"history/withoutCLAHE_withoutRecons_lr0001.txt",
#     'save_model_path':"../models/withoutCLAHE_withoutRecons_lr0001",
    'add_noise':False
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen,
             )
# Out:
# Epoch 1/50
# 1292/1292 [==============================] - 343s 265ms/step - train_loss: 0.9356 - mask_loss: 0.9356
# 184/184 [==============================] - 33s 180ms/step - val_loss: 0.9531 - mask_loss: 0.9717
#
# Epoch 2/50
# 1292/1292 [==============================] - 326s 252ms/step - train_loss: 0.8702 - mask_loss: 0.8702
# 184/184 [==============================] - 34s 186ms/step - val_loss: 0.9529 - mask_loss: 0.9652
#
# Epoch 3/50
# 1292/1292 [==============================] - 326s 253ms/step - train_loss: 0.7498 - mask_loss: 0.7498
# 184/184 [==============================] - 33s 180ms/step - val_loss: 0.7754 - mask_loss: 0.8144
#
# Epoch 4/50
#   24/1292 [..............................] - ETA: 5:07 - train_loss: 0.7680 - mask_loss: 0.7680
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1847/681877319.py in <module>
#      15 trainer = Trainer(**trainer_args)
#      16
# ---> 17 trainer.train(train_dataset=tr_fgadr_gen,
#      18               val_dataset=val_fgadr_gen,
#      19              )
#
# ~/aiffel/Visuworks/code/assets/test/trainer.py in train(self, train_dataset, val_dataset)
#      91
#      92             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
# ---> 93                 train_loss, mask_loss = self.train_on_batch(x_batch_train, y_batch_train)
#      94                 values = [('train_loss', train_loss), ('mask_loss', mask_loss)]
#      95
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     860     if self._run_functions_eagerly:
#     861       with trace.Trace(self._name, tf_function_call="eager"):
# --> 862         return self._python_function(*args, **kwds)
#     863
#     864     # Only count the statistics the fitst time, before initialization took
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in bound_method_wrapper(*args, **kwargs)
#    3983       if tf_inspect.ismethod(wrapped_fn):
#    3984         wrapped_fn = six.get_unbound_function(wrapped_fn)
# -> 3985       return wrapped_fn(weak_instance(), *args, **kwargs)
#    3986
#    3987     # If __wrapped__ was replaced, then it is always an unbound function.
#
# ~/aiffel/Visuworks/code/assets/test/trainer.py in train_on_batch(self, x_batch_train, y_batch_train)
#      66             mask_loss = self.dice_loss(y_batch_train, mask_hat)
#      67             train_loss = mask_loss
# ---> 68             return_loss = (train_loss.numpy(), mask_loss.numpy())
#      69
#      70
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# 여전히 잘 안됨.
# custom trainer랑 model.fit이랑 차이가 도대체 뭘까?

# %% [markdown]
# ```python
# # for training
# logits = model(x_batch_train, training=True)
# # for validation
# logits = model(x_batch_val, training=False)
# ```

# %% [markdown]
# # 학습만 따로 시켜보기

# %%
from tensorflow.keras.utils import Progbar
from assets.test.data_generator import DR_Generator
import os
# from assets.one_mask.functional_models import Unet 
from assets.test.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
epochs = 50
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    
    tr_progBar = Progbar(target=len(tr_fgadr_gen) * tr_fgadr_gen.batch_size, 
                                 stateful_metrics=['mask_loss', 'train_loss'])
    
    mask_batch_loss = []
    # Iterate over the batches of the dataset.
    for step_train, (x_batch_train, y_batch_train) in enumerate(tr_fgadr_gen):
        # Open a GradientTape to record the operations run
        # during the forward pass, which enables auto-differentiation.
        with tf.GradientTape() as tape:
            # Run the forward pass of the layer.
            # The operations that the layer applies
            # to its inputs are going to be recorded
            # on the GradientTape.
            mask_hat = model(x_batch_train, training=True)  # Logits for this minibatch

            # Compute the loss value for this minibatch.
            mask_loss = dice_coef_loss(y_batch_train, mask_hat)

        # Use the gradient tape to automatically retrieve
        # the gradients of the trainable variables with respect to the loss.
        grads = tape.gradient(mask_loss, model.trainable_weights)

        # Run one step of gradient descent by updating
        # the value of the variables to minimize the loss.
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        
        values = [('mask_loss', mask_loss.numpy())]
        
        mask_batch_loss.append(mask_loss.numpy())
        
        if (step_train + 1) == len(tr_fgadr_gen):
            values = [('mask_loss', np.mean(mask_batch_loss))]
                
        tr_progBar.update((step_train + 1) * tr_fgadr_gen.batch_size, values=values)
# Out:
# Start of epoch 0
# 1292/1292 [==============================] - 475s 367ms/step - mask_loss: 0.9285
#
# Start of epoch 1
# 1292/1292 [==============================] - 457s 354ms/step - mask_loss: 0.8629
#
# Start of epoch 2
#  276/1292 [=====>........................] - ETA: 5:57 - mask_loss: 0.7421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1790/1537037008.py in <module>
#      29         optimizer.apply_gradients(zip(grads, model.trainable_weights))
#      30
# ---> 31         values = [('mask_loss', mask_loss.numpy())]
#      32
#      33         mask_batch_loss.append(mask_loss.numpy())
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# # Classification

# %%
from tensorflow.keras.utils import Progbar
from assets.classification.data_generator import DR_Generator
import os
from assets.classification.models import SnC_Unet
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None,
    'label_path':'../data/FGADR-Seg-set_Release/Seg-set/DR_Seg_Grading_Label.csv'
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 36
#      21 mask_paths = [os.path.join(mask_dir, mask) for mask in masks]
#      23 generator_args = {
#      24     'dir_path':'../data/Seg-set/Original_Images/',
#      25     'mask_path':mask_paths,
#    (...)
#      33     'label_path':'../data/FGADR-Seg-set_Release/Seg-set/DR_Seg_Grading_Label.csv'
#      34 }
# ---> 36 tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
#      37 val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
#      38 ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)
#
# File c:\Users\Hi\Desktop\VISUWORKS\code\assets\classification\data_generator.py:68, in DR_Generator.__init__(self, dir_path, mask_path, use_mask, batch_size, img_size, dataset, start_end_index, is_train, use_3channel, CLAHE_args, add_noise_std, label_path)
#      65     self.withCls = False
#      67 # load_dataset()을 통해서 directory path에서 라벨과 이미지를 확인
# ---> 68 self.data_paths = self.load_dataset()
#
# File c:\Users\Hi\Desktop\VISUWORKS\code\assets\classification\data_generator.py:85, in DR_Generator.load_dataset(self)
#      76 '''
#      77 path 불러오는 함수
#      78 tr : val : ts = 70 : 10 : 20
#      79 1290: 184: 368
#      80 '''
#      81 # 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수
#      82 # is_train, is_valid, is_test로 분리함
#      83
#      84 # 이미지 path 지정
# ---> 85 file_list = os.listdir(self.dir_path)
#      86 input_images_paths = [os.path.join(self.dir_path, file) for file in file_list]
#      87 input_images_paths.sort()
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '../data/Seg-set/Original_Images/'

# %%
import os

os.listdir("../data/FGADR-Seg-set_Release/Seg-set/")
# Out:
# ['.DS_Store',
#  'DR_Seg_Grading_Label.csv',
#  'HardExudate_Masks',
#  'Hemohedge_Masks',
#  'IRMA_Masks',
#  'Microaneurysms_Masks',
#  'Neovascularization_Masks',
#  'Original_Images',
#  'SoftExudate_Masks']

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
epochs = 50
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    
    tr_progBar = Progbar(target=len(tr_fgadr_gen) * tr_fgadr_gen.batch_size, 
                                 stateful_metrics=['mask_loss', 'train_loss'])
    
    mask_batch_loss = []
    # Iterate over the batches of the dataset.
    for step_train, (x_batch_train, y_batch_train) in enumerate(tr_fgadr_gen):
        # Open a GradientTape to record the operations run
        # during the forward pass, which enables auto-differentiation.
        with tf.GradientTape() as tape:
            # Run the forward pass of the layer.
            # The operations that the layer applies
            # to its inputs are going to be recorded
            # on the GradientTape.
            mask_hat = model(x_batch_train, training=True)  # Logits for this minibatch

            # Compute the loss value for this minibatch.
            mask_loss = dice_coef_loss(y_batch_train, mask_hat)

        # Use the gradient tape to automatically retrieve
        # the gradients of the trainable variables with respect to the loss.
        grads = tape.gradient(mask_loss, model.trainable_weights)

        # Run one step of gradient descent by updating
        # the value of the variables to minimize the loss.
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        
        values = [('mask_loss', mask_loss.numpy())]
        
        mask_batch_loss.append(mask_loss.numpy())
        
        if (step_train + 1) == len(tr_fgadr_gen):
            values = [('mask_loss', np.mean(mask_batch_loss))]
                
        tr_progBar.update((step_train + 1) * tr_fgadr_gen.batch_size, values=values)

# %% [markdown]
# # 결과 시각화하기

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
generator_args = {
  'dir_path':'../data/train',
  'mask_path':None,
  'use_mask':False,
  'img_size':(512, 512),  
  'batch_size':4, # 8로 하면 바로 OOM 뜸
  'dataset':'EyePacks', # FGADR or EyePacks
  'is_train':True
}

tr_eyepacks_gen = DR_Generator(start_end_index=(0, 10000), **generator_args)
val_eyepacks_gen = DR_Generator(start_end_index=(10000, 11000), **generator_args)

# %%
for inputs, _, in val_eyepacks_gen:
    break
    
inputs.shape
# Out:
# (4, 512, 512, 1)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

trainer_args = {
    'model':model,
    'epochs':3,
    'optimizer':optimizer,
    'for_recons':True,
    'alpha':0.1,
    'beta':[0.25, 0.25, 0.25, 0.25]
}
trainer = Trainer(**trainer_args)

history = trainer.train(train_dataset=tr_eyepacks_gen,
                        val_dataset=val_eyepacks_gen,
                       )
# Out:
# Epoch 1/3
# 10000/10000 [==============================] - 2651s 265ms/step - train_loss: 9.8279e-06
# 1000/1000 [==============================] - 178s 178ms/step - val_loss: 9.8469e-06
#
# Epoch 2/3
# 10000/10000 [==============================] - 2654s 265ms/step - train_loss: 4.4916e-06
# 1000/1000 [==============================] - 178s 178ms/step - val_loss: 4.5066e-06
#
# Epoch 3/3
# 10000/10000 [==============================] - 2726s 273ms/step - train_loss: 2.4261e-06
# 1000/1000 [==============================] - 194s 194ms/step - val_loss: 2.4240e-06

# %%
preds = model(inputs)[0].numpy()

for input, pred in zip(inputs, preds):
    plt.subplot(1, 2, 1)
    plt.imshow(np.int_(input * 255), cmap='gray')
    plt.subplot(1, 2, 2)
    plt.imshow(np.int_(pred * 255), cmap='gray')
    plt.show()
