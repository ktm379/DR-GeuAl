# %% [markdown]
# # Four mask

# %%
import tensorflow as tf
import os

from assets.four_mask.data_generator import DR_Generator
from assets.four_mask.models import SMD_Unet 
from assets.four_mask.trainer import Trainer
# Out:
# 2024-01-31 17:39:01.242554: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-31 17:39:01.300366: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-31 17:39:02.204520: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':None,
    'add_noise_std':None
}
 
tr_fgadr_gen = DR_Generator(start_end_index=(0, 1108), is_train=True, **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1108, 1660), is_train=False, **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1660, 1840), is_train=False, **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
model.load_weights('../models/four_mask/SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025/24')

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 

trainer_args = {
    'model':model,
    'epochs':100,
    'optimizer':optimizer,
    'for_recons':False,
    'alpha':0.1,
    'beta':[0.25, 0.25, 0.25, 0.25],
    'first_epoch':25,
    'file_name':"history/four_mask/SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025.txt",
    'save_model_path':"../models/four_mask/SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025",
    'add_noise':False
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen
             )
# Out:
# Epoch 25/100
# 2024-01-31 17:39:33.823664: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2024-01-31 17:39:38.395437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1108/1108 [==============================] - 646s 583ms/step - train_loss: 0.5783 - mask_loss: 0.6423 - loss_recons: 0.0025 - ex_loss: 0.4736 - he_loss: 0.4760 - ma_loss: 0.7732 - se_loss: 0.8465
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6237 - mask_loss: 0.6928 - loss_recons: 0.0014 - ex_loss: 0.5220 - he_loss: 0.6414 - ma_loss: 0.8335 - se_loss: 0.7743
#
# Epoch 26/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.5756 - mask_loss: 0.6393 - loss_recons: 0.0025 - ex_loss: 0.4635 - he_loss: 0.4758 - ma_loss: 0.7717 - se_loss: 0.8461
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6194 - mask_loss: 0.6881 - loss_recons: 0.0013 - ex_loss: 0.5416 - he_loss: 0.5975 - ma_loss: 0.8390 - se_loss: 0.7742
#
# Epoch 27/100
# 1108/1108 [==============================] - 629s 568ms/step - train_loss: 0.5781 - mask_loss: 0.6421 - loss_recons: 0.0024 - ex_loss: 0.4668 - he_loss: 0.4787 - ma_loss: 0.7769 - se_loss: 0.8461
# 552/552 [==============================] - 123s 223ms/step - val_loss: 0.6346 - mask_loss: 0.7050 - loss_recons: 0.0018 - ex_loss: 0.5863 - he_loss: 0.6216 - ma_loss: 0.8378 - se_loss: 0.7741
#
# Epoch 28/100
# 1108/1108 [==============================] - 629s 567ms/step - train_loss: 0.5702 - mask_loss: 0.6333 - loss_recons: 0.0022 - ex_loss: 0.4564 - he_loss: 0.4702 - ma_loss: 0.7603 - se_loss: 0.8460
# 552/552 [==============================] - 124s 224ms/step - val_loss: 0.6422 - mask_loss: 0.7134 - loss_recons: 0.0021 - ex_loss: 0.5510 - he_loss: 0.6911 - ma_loss: 0.8372 - se_loss: 0.7741
#
# Epoch 29/100
# 1108/1108 [==============================] - 628s 566ms/step - train_loss: 0.5653 - mask_loss: 0.6279 - loss_recons: 0.0022 - ex_loss: 0.4536 - he_loss: 0.4575 - ma_loss: 0.7545 - se_loss: 0.8460
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6371 - mask_loss: 0.7077 - loss_recons: 0.0019 - ex_loss: 0.6052 - he_loss: 0.6000 - ma_loss: 0.8514 - se_loss: 0.7741
#
# Epoch 30/100
# 1108/1108 [==============================] - 627s 566ms/step - train_loss: 0.
- se_loss: 0.8460
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6045 - mask_loss: 0.6716 - loss_recons: 0.0010 - ex_loss: 0.5109 - he_loss: 0.5662 - ma_loss: 0.8352 - se_loss: 0.7740
#
# Epoch 57/100
# 1108/1108 [==============================] - 628s 567ms/step - train_loss: 0.4994 - mask_loss: 0.5547 - loss_recons: 0.0014 - ex_loss: 0.3744 - he_loss: 0.3758 - ma_loss: 0.6227 - se_loss: 0.8460
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6431 - mask_loss: 0.7144 - loss_recons: 0.0017 - ex_loss: 0.6425 - he_loss: 0.5829 - ma_loss: 0.8580 - se_loss: 0.7740
#
# Epoch 58/100
# 1108/1108 [==============================] - 628s 567ms/step - train_loss: 0.4960 - mask_loss: 0.5510 - loss_recons: 0.0014 - ex_loss: 0.3618 - he_loss: 0.3743 - ma_loss: 0.6218 - se_loss: 0.8460
# 552/552 [==============================] - 123s 222ms/step - val_loss: 0.6246 - mask_loss: 0.6938 - loss_recons: 0.0015 - ex_loss: 0.5250 - he_loss: 0.6174 - ma_loss: 0.8587 - se_loss: 0.7740
#
# Epoch 59/100
#   20/1108 [..............................] - ETA: 10:09 - train_loss: 0.4702 - mask_loss: 0.5224 - loss_recons: 5.4286e-04 - ex_loss: 0.4344 - he_loss: 0.2607 - ma_loss: 0.3971 - se_loss: 0.9974
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4614/3568856909.py in ?()
#      13     'add_noise':False
#      14 }
#      15 trainer = Trainer(**trainer_args)
#      16
# ---> 17 trainer.train(train_dataset=tr_fgadr_gen,
#      18               val_dataset=val_fgadr_gen
#      19              )
#
# ~/Visuworks/code/assets/four_mask/trainer.py in ?(self, train_dataset, val_dataset)
#     145             se_batch_loss = []
#     146
#     147             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#     148                 if not self.for_recons:
# --> 149                     loss_recons, train_loss, mask_loss, ex_loss, he_loss, ma_loss, se_loss = self.train_on_batch(x_batch_train, y_batch_train)
#     150
#     151                     values = [('train_loss', train_loss), ('mask_loss', mask_loss), ('loss_recons', loss_recons), ('ex_loss', ex_loss), ('he_loss', he_loss), ('ma_loss', ma_loss), ('se_loss', se_loss)]
#     152
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in ?(self, *args, **kwds)
#     867   def __call__(self, *args, **kwds):
#     868     # Implements GenericFunction.__call__.
#     869     if self._run_functions_eagerly:
#     870       with trace.Trace(self._name, tf_function_call="eager"):
# --> 871         return self._python_function(*args, **kwds)
#     872
#     873     # Only count the statistics the first time, before initialization took
#     874     # place.
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in ?(*args, **kwargs)
#     475     if wrapped_fn is strong_bound_method_wrapper.__original_wrapped__:
#     476       # If __wrapped__ was not replaced, then call original_function.
#     477       # TODO(mdan): For better consistency, use the wrapper's call().
#     478       wrapped_fn = original_function.python_function
# --> 479       return wrapped_fn(weak_instance(), *args, **kwargs)
#     480
#     481     # If __wrapped__ was replaced, then it is always an unbound function.
#     482     # However, the replacer is still responsible for attaching self properly.
#
# ~/Visuworks/code/assets/four_mask/trainer.py in ?(self, x_batch_train, y_batch_train)
#     118                 train_loss = loss_recons
#     119                 return_loss = (loss_recons.numpy(), train_loss.numpy())
#     120
#     121         grads = tape.gradient(train_loss, self.model.trainable_weights)  # gradient 계산
# --> 122         self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))  # Otimizer에게 처리된 그라데이션 적용을 요청
#     123
#     124         del preds
#     125
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1170             "experimental_aggregate_gradients", True
#    1171         )
#    1172         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1173             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1174         return super().apply_gradients(grads_and_vars, name=name)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, grads_and_vars, name)
#     646         grads = self._clip_gradients(grads)
#     647         grads = self._deduplicate_sparse_grad(grads)
#     648         self._apply_weight_decay(trainable_variables)
#     649         grads_and_vars = list(zip(grads, trainable_variables))
# --> 650         iteration = self._internal_apply_gradients(grads_and_vars)
#     651
#     652         # Apply variable constraints after applying gradients.
#     653         for variable in trainable_variables:
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, grads_and_vars)
#    1199     def _internal_apply_gradients(self, grads_and_vars):
# -> 1200         return tf.__internal__.distribute.interim.maybe_merge_call(
#    1201             self._distributed_apply_gradients_fn,
#    1202             self._distribution_strategy,
#    1203             grads_and_vars,
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/distribute/merge_call_interim.py in ?(fn, strategy, *args, **kwargs)
#      47   Returns:
#      48     The return value of the `fn` call.
#      49   """
#      50   if strategy_supports_no_merge_call():
# ---> 51     return fn(strategy, *args, **kwargs)
#      52   else:
#      53     return distribution_strategy_context.get_replica_context().merge_call(
#      54         fn, args=args, kwargs=kwargs)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, distribution, grads_and_vars, **kwargs)
#    1246             else:
#    1247                 return self._update_step(grad, var)
#    1248
#    1249         for grad, var in grads_and_vars:
# -> 1250             distribution.extended.update(
#    1251                 var, apply_grad_to_update_var, args=(grad,), group=False
#    1252             )
#    1253
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, var, fn, args, kwargs, group)
#    2633         distribution_strategy_context._get_default_replica_context()):
#    2634       fn = autograph.tf_convert(
#    2635           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2636       with self._container_strategy().scope():
# -> 2637         return self._update(var, fn, args, kwargs, group)
#    2638     else:
#    2639       return self._replica_ctx_update(
#    2640           var, fn, args=args, kwargs=kwargs, group=group)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, var, fn, args, kwargs, group)
#    3707   def _update(self, var, fn, args, kwargs, group):
#    3708     # The implementations of _update() and _update_non_slot() are identical
#    3709     # except _update() passes `var` as the first argument to `fn()`.
# -> 3710     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, colocate_with, fn, args, kwargs, should_group)
#    3712   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3713     # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3714     # once that value is used for something.
#    3715     with UpdateContext(colocate_with):
# -> 3716       result = fn(*args, **kwargs)
#    3717       if should_group:
#    3718         return result
#    3719       else:
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     593   def wrapper(*args, **kwargs):
#     594     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595       return func(*args, **kwargs)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(var, grad)
#    1243         def apply_grad_to_update_var(var, grad):
#    1244             if self.jit_compile:
# -> 1245                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1246             else:
#    1247                 return self._update_step(grad, var)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in ?(self, *args, **kwds)
#     867   def __call__(self, *args, **kwds):
#     868     # Implements GenericFunction.__call__.
#     869     if self._run_functions_eagerly:
#     870       with trace.Trace(self._name, tf_function_call="eager"):
# --> 871         return self._python_function(*args, **kwds)
#     872
#     873     # Only count the statistics the first time, before initialization took
#     874     # place.
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in ?(*args, **kwargs)
#     475     if wrapped_fn is strong_bound_method_wrapper.__original_wrapped__:
#     476       # If __wrapped__ was not replaced, then call original_function.
#     477       # TODO(mdan): For better consistency, use the wrapper's call().
#     478       wrapped_fn = original_function.python_function
# --> 479       return wrapped_fn(weak_instance(), *args, **kwargs)
#     480
#     481     # If __wrapped__ was replaced, then it is always an unbound function.
#     482     # However, the replacer is still responsible for attaching self properly.
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, gradient, variable, key)
#     220
#     221         Returns:
#     222           An `Operation` that applies the specified gradients.
#     223         """
# --> 224         return self._update_step(gradient, variable)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/optimizer.py in ?(self, gradient, variable)
#     236                 "`optimizer.build(variables)` with the full list of trainable "
#     237                 "variables before the training loop or use legacy optimizer "
#     238                 f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     239             )
# --> 240         self.update_step(gradient, variable)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/keras/optimizers/adam.py in ?(self, gradient, variable)
#     166         var_key = self._var_key(variable)
#     167         m = self._momentums[self._index_dict[var_key]]
#     168         v = self._velocities[self._index_dict[var_key]]
#     169
# --> 170         alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     171
#     172         if isinstance(gradient, tf.IndexedSlices):
#     173             # Sparse gradients.
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(y, x)
#    1490     with ops.name_scope(None, op_name, [x, y]) as name:
#    1491       # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1492       #   r_binary_op_wrapper use different force_same_dtype values.
#    1493       y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1494       return func(x, y, name=name)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#     545 @tf_export("math.subtract", "subtract")
#     546 @dispatch.register_binary_elementwise_api
#     547 @dispatch.add_dispatch_support
#     548 def subtract(x, y, name=None):
# --> 549   return gen_math_ops.sub(x, y, name)
#
# ~/anaconda3/envs/DRGR_test/lib/python3.10/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#   11343         _ctx, "Sub", name, x, y)
#   11344       return _result
#   11345     except _core._NotOkStatusException as e:
#   11346       _ops.raise_from_not_ok_status(e, name)
# > 11347     except _core._FallbackException:
#   11348       pass
#   11349     try:
#   11350       return sub_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# ## history 그려보기

# %%
from assets.four_mask.utils import parse_history_text
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import os

# %%
os.listdir('history/four_mask')
# Out:
# ['SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025.txt', 'test.txt']

# %%
history.keys()
# Out:
# dict_keys(['epoch', 'train_loss', 'train_mask_loss', 'tr_recons_loss', 'tr_ex_loss', 'tr_he_loss', 'tr_ma_loss', 'tr_se_loss', 'val_loss', 'val_mask_loss', 'val_recons_loss', 'val_ex_loss', 'val_he_loss', 'val_ma_loss', 'val_se_loss'])

# %%
history = parse_history_text('history/four_mask/SMD_withoutCLAHE_lr0001_3channel_alpha01_beta025025025025.txt')


plt.figure(figsize=(20, 10))
plt.plot(history['epoch'], history['train_mask_loss'], label='train_mask_loss')
plt.plot(history['epoch'], history['val_mask_loss'], label='val_mask_loss')

plt.plot(history['epoch'], history['tr_ex_loss'], label='tr_ex_loss')
plt.plot(history['epoch'], history['tr_he_loss'], label='tr_he_loss')
plt.plot(history['epoch'], history['tr_ma_loss'], label='tr_ma_loss')
plt.plot(history['epoch'], history['tr_se_loss'], label='tr_se_loss')

plt.plot(history['epoch'], history['val_ex_loss'], label='val_ex_loss')
plt.plot(history['epoch'], history['val_he_loss'], label='val_he_loss')
plt.plot(history['epoch'], history['val_ma_loss'], label='val_ma_loss')
plt.plot(history['epoch'], history['val_se_loss'], label='val_se_loss')


plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))


plt.title('with reconstruction')
plt.legend()
plt.show()

# %% [markdown]
# # Pretraining

# %%
import tensorflow as tf
import os

from assets.one_mask.data_generator import DR_Generator
from assets.one_mask.models import SMD_Unet 
from assets.one_mask.trainer import Trainer

# %%
generator_args = {
    'dir_path':'../data/preprocessed/',
    'mask_path':None,
    'use_mask':False,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'EyePacks', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':None,
    'add_noise_std':0.2
}
 
    
tr_eyepacks_gen = DR_Generator(start_end_index=(33000, 34000), **generator_args)
val_eyepacks_gen = DR_Generator(start_end_index=(30000, 33000), **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
# model.load_weights("../models/one_mask/withoutCLAHE_withRecons_alpha01_lr0001_3channel/21")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':True,
    'alpha':1.0,
    'beta':None,
    'first_epoch':1,
    'file_name':"history/one_mask/pretraning_lr00001_3channel.txt",
    'save_model_path':"../models/one_mask/pretraning_lr00001_3channel",
    'add_noise':True
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_eyepacks_gen,
              val_dataset=val_eyepacks_gen
             )
# Out:
# Epoch 1/50
# 816/816 [==============================] - 210s 258ms/step - train_loss: 0.0070 - loss_recons: 0.0070
# 3000/3000 [==============================] - 398s 133ms/step - val_loss: 0.0057 - loss_recons: 0.0057
#
# Epoch 2/50
#  20/816 [..............................] - ETA: 3:05 - train_loss: 0.0060 - loss_recons: 0.0060
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2625/1947736279.py in <module>
#      15 trainer = Trainer(**trainer_args)
#      16
# ---> 17 trainer.train(train_dataset=tr_eyepacks_gen,
#      18               val_dataset=val_eyepacks_gen
#      19              )
#
# ~/aiffel/Visuworks/code/assets/one_mask/trainer.py in train(self, train_dataset, val_dataset)
#     144             total_batch_loss = []
#     145
# --> 146             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#     147                 if not self.for_recons:
#     148                     loss_recons, train_loss, mask_loss = self.train_on_batch(x_batch_train, y_batch_train)
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in __iter__(self)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in <genexpr>(.0)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# ~/aiffel/Visuworks/code/assets/one_mask/data_generator.py in __getitem__(self, index)
#     184         if self.dataset == "EyePacks":
#     185             if self.add_noise_std != None:
# --> 186                 return [tf.cast(inputs, dtype=tf.float32), tf.cast(noisy_inputs, dtype=tf.float32)], None
#     187
#     188             return [tf.cast(inputs, dtype=tf.float32)], None
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     986       # allows some conversions that cast() can't do, e.g. casting numbers to
#     987       # strings.
# --> 988       x = ops.convert_to_tensor(x, name="x")
#     989       if x.dtype.base_dtype != base_type:
#     990         x = gen_math_ops.cast(x, base_type, name=name)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# KeyboardInterrupt:

# %% [markdown]
# # Functional API로 해보기

# %%
from assets.test.data_generator import DR_Generator
import os
from assets.one_mask.functional_models import Unet 
# from assets.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

# %%
unet = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
unet = Unet(filters=[64, 128, 256, 512, 1024], img_size=(512, 512))

# %%
unet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss=dice_coef_loss)

# %%
unet.fit(tr_fgadr_gen, 
         validation_data=val_fgadr_gen, 
         epochs=50)
# Out:
# Epoch 1/50
# 323/323 [==============================] - 283s 843ms/step - loss: 0.9407 - val_loss: 0.9566
# Epoch 2/50
# 323/323 [==============================] - 270s 835ms/step - loss: 0.9254 - val_loss: 0.9424
# Epoch 3/50
# 323/323 [==============================] - 270s 834ms/step - loss: 0.8758 - val_loss: 0.9287
# Epoch 4/50
# 323/323 [==============================] - 271s 837ms/step - loss: 0.7606 - val_loss: 0.7711
# Epoch 5/50
# 323/323 [==============================] - 271s 839ms/step - loss: 0.6844 - val_loss: 0.6974
# Epoch 6/50
#  79/323 [======>.......................] - ETA: 3:09 - loss: 0.6341
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1574/4028299692.py in <module>
# ----> 1 unet.fit(tr_fgadr_gen,
#       2          validation_data=val_fgadr_gen,
#       3          epochs=50)
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# /opt/conda/lib/python3.9/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# trainer에 문제가 있는 거구나

# %% [markdown]
# # mask만 학습시켜보기

# %%
from assets.test.data_generator import DR_Generator
import os
# from assets.one_mask.functional_models import Unet 
from assets.test.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':False,
    'alpha':0.0,
    'beta':None,
    'first_epoch':1,
#     'file_name':"history/withoutCLAHE_withoutRecons_lr0001.txt",
#     'save_model_path':"../models/withoutCLAHE_withoutRecons_lr0001",
    'add_noise':False
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen,
             )
# Out:
# Epoch 1/50
# 1292/1292 [==============================] - 343s 265ms/step - train_loss: 0.9356 - mask_loss: 0.9356
# 184/184 [==============================] - 33s 180ms/step - val_loss: 0.9531 - mask_loss: 0.9717
#
# Epoch 2/50
# 1292/1292 [==============================] - 326s 252ms/step - train_loss: 0.8702 - mask_loss: 0.8702
# 184/184 [==============================] - 34s 186ms/step - val_loss: 0.9529 - mask_loss: 0.9652
#
# Epoch 3/50
# 1292/1292 [==============================] - 326s 253ms/step - train_loss: 0.7498 - mask_loss: 0.7498
# 184/184 [==============================] - 33s 180ms/step - val_loss: 0.7754 - mask_loss: 0.8144
#
# Epoch 4/50
#   24/1292 [..............................] - ETA: 5:07 - train_loss: 0.7680 - mask_loss: 0.7680
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1847/681877319.py in <module>
#      15 trainer = Trainer(**trainer_args)
#      16
# ---> 17 trainer.train(train_dataset=tr_fgadr_gen,
#      18               val_dataset=val_fgadr_gen,
#      19              )
#
# ~/aiffel/Visuworks/code/assets/test/trainer.py in train(self, train_dataset, val_dataset)
#      91
#      92             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
# ---> 93                 train_loss, mask_loss = self.train_on_batch(x_batch_train, y_batch_train)
#      94                 values = [('train_loss', train_loss), ('mask_loss', mask_loss)]
#      95
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     860     if self._run_functions_eagerly:
#     861       with trace.Trace(self._name, tf_function_call="eager"):
# --> 862         return self._python_function(*args, **kwds)
#     863
#     864     # Only count the statistics the fitst time, before initialization took
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in bound_method_wrapper(*args, **kwargs)
#    3983       if tf_inspect.ismethod(wrapped_fn):
#    3984         wrapped_fn = six.get_unbound_function(wrapped_fn)
# -> 3985       return wrapped_fn(weak_instance(), *args, **kwargs)
#    3986
#    3987     # If __wrapped__ was replaced, then it is always an unbound function.
#
# ~/aiffel/Visuworks/code/assets/test/trainer.py in train_on_batch(self, x_batch_train, y_batch_train)
#      66             mask_loss = self.dice_loss(y_batch_train, mask_hat)
#      67             train_loss = mask_loss
# ---> 68             return_loss = (train_loss.numpy(), mask_loss.numpy())
#      69
#      70
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# 여전히 잘 안됨.
# custom trainer랑 model.fit이랑 차이가 도대체 뭘까?

# %% [markdown]
# ```python
# # for training
# logits = model(x_batch_train, training=True)
# # for validation
# logits = model(x_batch_val, training=False)
# ```

# %% [markdown]
# # 학습만 따로 시켜보기

# %%
from tensorflow.keras.utils import Progbar
from assets.test.data_generator import DR_Generator
import os
# from assets.one_mask.functional_models import Unet 
from assets.test.trainer import Trainer
from assets.test.models import SMD_Unet
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
epochs = 50
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    
    tr_progBar = Progbar(target=len(tr_fgadr_gen) * tr_fgadr_gen.batch_size, 
                                 stateful_metrics=['mask_loss', 'train_loss'])
    
    mask_batch_loss = []
    # Iterate over the batches of the dataset.
    for step_train, (x_batch_train, y_batch_train) in enumerate(tr_fgadr_gen):
        # Open a GradientTape to record the operations run
        # during the forward pass, which enables auto-differentiation.
        with tf.GradientTape() as tape:
            # Run the forward pass of the layer.
            # The operations that the layer applies
            # to its inputs are going to be recorded
            # on the GradientTape.
            mask_hat = model(x_batch_train, training=True)  # Logits for this minibatch

            # Compute the loss value for this minibatch.
            mask_loss = dice_coef_loss(y_batch_train, mask_hat)

        # Use the gradient tape to automatically retrieve
        # the gradients of the trainable variables with respect to the loss.
        grads = tape.gradient(mask_loss, model.trainable_weights)

        # Run one step of gradient descent by updating
        # the value of the variables to minimize the loss.
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        
        values = [('mask_loss', mask_loss.numpy())]
        
        mask_batch_loss.append(mask_loss.numpy())
        
        if (step_train + 1) == len(tr_fgadr_gen):
            values = [('mask_loss', np.mean(mask_batch_loss))]
                
        tr_progBar.update((step_train + 1) * tr_fgadr_gen.batch_size, values=values)
# Out:
# Start of epoch 0
# 1292/1292 [==============================] - 475s 367ms/step - mask_loss: 0.9285
#
# Start of epoch 1
# 1292/1292 [==============================] - 457s 354ms/step - mask_loss: 0.8629
#
# Start of epoch 2
#  276/1292 [=====>........................] - ETA: 5:57 - mask_loss: 0.7421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1790/1537037008.py in <module>
#      29         optimizer.apply_gradients(zip(grads, model.trainable_weights))
#      30
# ---> 31         values = [('mask_loss', mask_loss.numpy())]
#      32
#      33         mask_batch_loss.append(mask_loss.numpy())
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# # Classification

# %%
from tensorflow.keras.utils import Progbar
from assets.classification.data_generator import DR_Generator
import os
from assets.classification.models import SnC_Unet
import tensorflow as tf
from tensorflow.keras import backend as K
import numpy as np

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'is_train':True,
    'use_3channel':False,
    'CLAHE_args':None,
    'label_path':'../data/FGADR-Seg-set_Release/Seg-set/DR_Seg_Grading_Label.csv'
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 36
#      21 mask_paths = [os.path.join(mask_dir, mask) for mask in masks]
#      23 generator_args = {
#      24     'dir_path':'../data/Seg-set/Original_Images/',
#      25     'mask_path':mask_paths,
#    (...)
#      33     'label_path':'../data/FGADR-Seg-set_Release/Seg-set/DR_Seg_Grading_Label.csv'
#      34 }
# ---> 36 tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), **generator_args)
#      37 val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), **generator_args)
#      38 ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), **generator_args)
#
# File c:\Users\Hi\Desktop\VISUWORKS\code\assets\classification\data_generator.py:68, in DR_Generator.__init__(self, dir_path, mask_path, use_mask, batch_size, img_size, dataset, start_end_index, is_train, use_3channel, CLAHE_args, add_noise_std, label_path)
#      65     self.withCls = False
#      67 # load_dataset()을 통해서 directory path에서 라벨과 이미지를 확인
# ---> 68 self.data_paths = self.load_dataset()
#
# File c:\Users\Hi\Desktop\VISUWORKS\code\assets\classification\data_generator.py:85, in DR_Generator.load_dataset(self)
#      76 '''
#      77 path 불러오는 함수
#      78 tr : val : ts = 70 : 10 : 20
#      79 1290: 184: 368
#      80 '''
#      81 # 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수
#      82 # is_train, is_valid, is_test로 분리함
#      83
#      84 # 이미지 path 지정
# ---> 85 file_list = os.listdir(self.dir_path)
#      86 input_images_paths = [os.path.join(self.dir_path, file) for file in file_list]
#      87 input_images_paths.sort()
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '../data/Seg-set/Original_Images/'

# %%
import os

os.listdir("../data/FGADR-Seg-set_Release/Seg-set/")
# Out:
# ['.DS_Store',
#  'DR_Seg_Grading_Label.csv',
#  'HardExudate_Masks',
#  'Hemohedge_Masks',
#  'IRMA_Masks',
#  'Microaneurysms_Masks',
#  'Neovascularization_Masks',
#  'Original_Images',
#  'SoftExudate_Masks']

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=1)

# %%
epochs = 50
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    
    tr_progBar = Progbar(target=len(tr_fgadr_gen) * tr_fgadr_gen.batch_size, 
                                 stateful_metrics=['mask_loss', 'train_loss'])
    
    mask_batch_loss = []
    # Iterate over the batches of the dataset.
    for step_train, (x_batch_train, y_batch_train) in enumerate(tr_fgadr_gen):
        # Open a GradientTape to record the operations run
        # during the forward pass, which enables auto-differentiation.
        with tf.GradientTape() as tape:
            # Run the forward pass of the layer.
            # The operations that the layer applies
            # to its inputs are going to be recorded
            # on the GradientTape.
            mask_hat = model(x_batch_train, training=True)  # Logits for this minibatch

            # Compute the loss value for this minibatch.
            mask_loss = dice_coef_loss(y_batch_train, mask_hat)

        # Use the gradient tape to automatically retrieve
        # the gradients of the trainable variables with respect to the loss.
        grads = tape.gradient(mask_loss, model.trainable_weights)

        # Run one step of gradient descent by updating
        # the value of the variables to minimize the loss.
        optimizer.apply_gradients(zip(grads, model.trainable_weights))
        
        values = [('mask_loss', mask_loss.numpy())]
        
        mask_batch_loss.append(mask_loss.numpy())
        
        if (step_train + 1) == len(tr_fgadr_gen):
            values = [('mask_loss', np.mean(mask_batch_loss))]
                
        tr_progBar.update((step_train + 1) * tr_fgadr_gen.batch_size, values=values)

# %% [markdown]
# # 결과 시각화하기

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
generator_args = {
  'dir_path':'../data/train',
  'mask_path':None,
  'use_mask':False,
  'img_size':(512, 512),  
  'batch_size':4, # 8로 하면 바로 OOM 뜸
  'dataset':'EyePacks', # FGADR or EyePacks
  'is_train':True
}

tr_eyepacks_gen = DR_Generator(start_end_index=(0, 10000), **generator_args)
val_eyepacks_gen = DR_Generator(start_end_index=(10000, 11000), **generator_args)

# %%
for inputs, _, in val_eyepacks_gen:
    break
    
inputs.shape
# Out:
# (4, 512, 512, 1)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

trainer_args = {
    'model':model,
    'epochs':3,
    'optimizer':optimizer,
    'for_recons':True,
    'alpha':0.1,
    'beta':[0.25, 0.25, 0.25, 0.25]
}
trainer = Trainer(**trainer_args)

history = trainer.train(train_dataset=tr_eyepacks_gen,
                        val_dataset=val_eyepacks_gen,
                       )
# Out:
# Epoch 1/3
# 10000/10000 [==============================] - 2651s 265ms/step - train_loss: 9.8279e-06
# 1000/1000 [==============================] - 178s 178ms/step - val_loss: 9.8469e-06
#
# Epoch 2/3
# 10000/10000 [==============================] - 2654s 265ms/step - train_loss: 4.4916e-06
# 1000/1000 [==============================] - 178s 178ms/step - val_loss: 4.5066e-06
#
# Epoch 3/3
# 10000/10000 [==============================] - 2726s 273ms/step - train_loss: 2.4261e-06
# 1000/1000 [==============================] - 194s 194ms/step - val_loss: 2.4240e-06

# %%
preds = model(inputs)[0].numpy()

for input, pred in zip(inputs, preds):
    plt.subplot(1, 2, 1)
    plt.imshow(np.int_(input * 255), cmap='gray')
    plt.subplot(1, 2, 2)
    plt.imshow(np.int_(pred * 255), cmap='gray')
    plt.show()
