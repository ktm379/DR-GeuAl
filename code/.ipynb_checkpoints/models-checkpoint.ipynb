# %%
from tensorflow import keras
import tensorflow as tf

# %%
def ConvBlock(x, n_filters):
    x = keras.layers.Conv2D(n_filters, 3, padding='same', activation='relu', kernel_initializer='he_normal')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)

    return x

def Encoder(x, filters):
    skips = []

    for f in filters:
        x = ConvBlock(x, f)
        x = ConvBlock(x, f)
        # 맨 마지막 층을 제외하고는 skip connection, downsampling을 진행
        if f != 1024:
            skips.append(x)
            x = keras.layers.MaxPooling2D(2)(x)
        
    return x, skips

def Decoder(x, filters, skips):
    for f, skip in zip(filters, skips):
        x = keras.layers.Conv2DTranspose(f, (2, 2), strides=2, padding='same')(x)
        x = ConvBlock(x, f)
        x = keras.layers.Concatenate()([x, skip]) 
        x = ConvBlock(x, f)
      
    x = ConvBlock(x, 2)
    x = keras.layers.Conv2D(filters=1, kernel_size=1, padding='same', activation='linear')(x)

    return x

def Unet(img_size):
    inputs = keras.Input(shape=img_size + (1,))

    # 축소 경로
    filters = [64, 128, 256, 512, 1024]

    x, skips = Encoder(inputs, filters)

    # 확장 경로
    x = Decoder(x, filters[::-1][1:], skips[::-1])

    model = keras.Model(inputs, x)

    return model

# %%
# Encoder만 정의하기
# filters = [64, 128, 256, 512, 1024]
# inputs = keras.Input(shape=(512, 512) + (1,))
# x = Encoder(inputs, filters)
# model = keras.Model(inputs, x)
# model.summary()

# %%
# model = Unet((512, 512))
# model.summary()

# %%
[(1, 2) for _ in range(3)][0][0]
# Out:
# 1

# %%
def SMD_Unet(img_size):
    inputs = keras.Input(shape=img_size + (1,))

    # 축소 경로
    filters = [64, 128, 256, 512, 1024]

    x, skips = Encoder(inputs, filters)

    # 확장 경로
    # mask : HardExudate, Hemohedge, Microane, SoftExudates
    input_hat = Decoder(x, filters[::-1][1:], skips[::-1]) # 원본 이미지 추정
    ex = Decoder(x, filters[::-1][1:], skips[::-1])
    he = Decoder(x, filters[::-1][1:], skips[::-1])
    ma = Decoder(x, filters[::-1][1:], skips[::-1])
    se = Decoder(x, filters[::-1][1:], skips[::-1])

    model = keras.Model(inputs, outputs=[input_hat, ex, he, ma, se])

    return model

# %%
model = SMD_Unet((512, 512))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  spose)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  spose)
#
#  conv2d_transpose_12 (Conv2DTra  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  nspose)
#
#  conv2d_transpose_16 (Conv2DTra  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  nspose)
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_transpose_4[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_transpose_8[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_transpose_12[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_transpose_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_19[0][0]']
#
#  activation_28 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_28[0][0]']
#
#  activation_37 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_37[0][0]']
#
#  activation_46 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_46[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 1024  0           ['activation_19[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 1024  0           ['activation_28[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 1024  0           ['activation_37[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 1024  0           ['activation_46[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_8[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_12[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_16[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_20[0][0]']
#
#  activation_29 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_29[0][0]']
#
#  activation_38 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_38[0][0]']
#
#  activation_47 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_20[0][0]']
#  spose)                         6)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_29[0][0]']
#  spose)                         6)
#
#  conv2d_transpose_13 (Conv2DTra  (None, 128, 128, 25  524544     ['activation_38[0][0]']
#  nspose)                        6)
#
#  conv2d_transpose_17 (Conv2DTra  (None, 128, 128, 25  524544     ['activation_47[0][0]']
#  nspose)                        6)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_transpose_5[0][0]']
#                                 6)
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_transpose_9[0][0]']
#                                 6)
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_transpose_13[0][0]']
#                                 6)
#
#  conv2d_52 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_transpose_17[0][0]']
#                                 6)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 25  1024       ['conv2d_22[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_30 (BatchN  (None, 128, 128, 25  1024       ['conv2d_32[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_39 (BatchN  (None, 128, 128, 25  1024       ['conv2d_42[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 25  1024       ['conv2d_52[0][0]']
#  ormalization)                  6)
#
#  activation_21 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_21[0][0]']
#                                 6)
#
#  activation_30 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_30[0][0]']
#                                 6)
#
#  activation_39 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_39[0][0]']
#                                 6)
#
#  activation_48 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_48[0][0]']
#                                 6)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 51  0           ['activation_21[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 51  0           ['activation_30[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 128, 128, 51  0           ['activation_39[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 51  0           ['activation_48[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_5[0][0]']
#                                 6)
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_9[0][0]']
#                                 6)
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_13[0][0]']
#                                 6)
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_17[0][0]']
#                                 6)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 25  1024       ['conv2d_23[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_31 (BatchN  (None, 128, 128, 25  1024       ['conv2d_33[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_40 (BatchN  (None, 128, 128, 25  1024       ['conv2d_43[0][0]']
#  ormalization)                  6)
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 25  1024       ['conv2d_53[0][0]']
#  ormalization)                  6)
#
#  activation_22 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_22[0][0]']
#                                 6)
#
#  activation_31 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_31[0][0]']
#                                 6)
#
#  activation_40 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_40[0][0]']
#                                 6)
#
#  activation_49 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_49[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_22[0][0]']
#  spose)                         8)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_31[0][0]']
#  nspose)                        8)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_40[0][0]']
#  nspose)                        8)
#
#  conv2d_transpose_18 (Conv2DTra  (None, 256, 256, 12  131200     ['activation_49[0][0]']
#  nspose)                        8)
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_transpose_6[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_transpose_10[0][0]']
#                                 8)
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_transpose_14[0][0]']
#                                 8)
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_transpose_18[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 256, 256, 12  512        ['conv2d_24[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_41 (BatchN  (None, 256, 256, 12  512        ['conv2d_44[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_50 (BatchN  (None, 256, 256, 12  512        ['conv2d_54[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_23[0][0]']
#                                 8)
#
#  activation_32 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_32[0][0]']
#                                 8)
#
#  activation_41 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_41[0][0]']
#                                 8)
#
#  activation_50 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_50[0][0]']
#                                 8)
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 25  0           ['activation_23[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 256, 256, 25  0           ['activation_32[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 256, 256, 25  0           ['activation_41[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 256, 256, 25  0           ['activation_50[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_10[0][0]']
#                                 8)
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_14[0][0]']
#                                 8)
#
#  conv2d_55 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_18[0][0]']
#                                 8)
#
#  batch_normalization_24 (BatchN  (None, 256, 256, 12  512        ['conv2d_25[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_42 (BatchN  (None, 256, 256, 12  512        ['conv2d_45[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_51 (BatchN  (None, 256, 256, 12  512        ['conv2d_55[0][0]']
#  ormalization)                  8)
#
#  activation_24 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_24[0][0]']
#                                 8)
#
#  activation_33 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_33[0][0]']
#                                 8)
#
#  activation_42 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_42[0][0]']
#                                 8)
#
#  activation_51 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_51[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_24[0][0]']
#  spose)                         )
#
#  conv2d_transpose_11 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_33[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_15 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_42[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_19 (Conv2DTra  (None, 512, 512, 64  32832      ['activation_51[0][0]']
#  nspose)                        )
#
#  conv2d_26 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_transpose_7[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_transpose_11[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_transpose_15[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_transpose_19[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 512, 512, 64  256        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  batch_normalization_34 (BatchN  (None, 512, 512, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  batch_normalization_43 (BatchN  (None, 512, 512, 64  256        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  batch_normalization_52 (BatchN  (None, 512, 512, 64  256        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  activation_34 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  activation_52 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 12  0           ['activation_25[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 12  0           ['activation_34[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 512, 512, 12  0           ['activation_43[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 512, 512, 12  0           ['activation_52[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_15[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_19[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 512, 512, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  batch_normalization_35 (BatchN  (None, 512, 512, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  batch_normalization_44 (BatchN  (None, 512, 512, 64  256        ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  batch_normalization_53 (BatchN  (None, 512, 512, 64  256        ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  activation_35 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  activation_44 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  activation_53 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 512, 512, 2)  1154        ['activation_26[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 512, 512, 2)  1154        ['activation_35[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 512, 512, 2)  1154        ['activation_44[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 512, 512, 2)  1154        ['activation_53[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 512, 512, 2)  8          ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 512, 512, 2)  8          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 512, 512, 2)  8          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 512, 512, 2)  8          ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 512, 512, 2)  0           ['batch_normalization_27[0][0]']
#
#  activation_36 (Activation)     (None, 512, 512, 2)  0           ['batch_normalization_36[0][0]']
#
#  activation_45 (Activation)     (None, 512, 512, 2)  0           ['batch_normalization_45[0][0]']
#
#  activation_54 (Activation)     (None, 512, 512, 2)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 512, 512, 1)  3           ['activation_27[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 512, 512, 1)  3           ['activation_36[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 512, 512, 1)  3           ['activation_45[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 512, 512, 1)  3           ['activation_54[0][0]']
#
# ==================================================================================================
# Total params: 67,647,220
# Trainable params: 67,623,908
# Non-trainable params: 23,312
# __________________________________________________________________________________________________

# %% [markdown]
# fit 함수 정의해서 사용해야돼서 class api로 변경

# %%
import tensorflow as tf
from tensorflow import keras

class ConvBlock(tf.keras.layers.Layer):
    def __init__(self, n_filters):
        super(ConvBlock, self).__init__()
        self.filters = n_filters
        self.conv = keras.layers.Conv2D(n_filters, 3, padding='same', activation='relu', kernel_initializer='he_normal')
        self.bn = keras.layers.BatchNormalization()
        self.relu = keras.layers.Activation('relu')
    
    def call(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        
        return x

    
class UpsampleBlock(tf.keras.layers.Layer):
    def __init__(self, n_filters):
    super(UpsampleBlock, self).__init__()
    self.filters = n_filters
    self.conv_T = keras.layers.Conv2DTranspose(n_filters, (2, 2), strides=2, padding='same')
    self.conv_block_1 = ConvBlock(n_filters)
    self.concat = keras.layers.Concatenate()
    self.conv_block_2 = ConvBlock(n_filters)
  
  def call(self, x, skip):
    x = self.conv_T(x)
    x = self.conv_block_1(x)
    x = self.concat([x, skip])
    x = self.conv_block_2(x)
    
    return x   

class EncoderBlock(tf.keras.layers.Layer):
    def __init__(self, filters):
        super(EncoderBlock, self).__init__()
        self.filters = filters # filters = [n_filters]
        self.conv_blocks = [(ConvBlock(f), ConvBlock(f)) for f in self.filters]
        self.max_poolings = [keras.layers.MaxPooling2D(2) for _ in range(len(self.filters)-1)]
        # conv_block, max_pooling 리스트 길이 맞춰주기 위한 트릭
        self.max_poolings += [0]

    def call(self, x):
        skips = []
        for conv_block, max_pooling in zip(self.conv_blocks, self.max_poolings):
            x = conv_block[0](x)
            x = conv_block[1](x)

            # 맨 마지막 층을 제외하고는 skip connection, downsampling을 진행
            if conv_block[0].filters != 1024:
                skips.append(x)
                x = max_pooling(x)
        return x, skips

class DecoderBlock(tf.keras.layers.Layer):
    def __init__(self, filters):
        super(DecoderBlock, self).__init__()
        self.filters = filters # filters = [n_filters]
        self.upsample_blocks = [UpsampleBlock(f) for f in self.filters]
        self.last_block = tf.keras.Sequential([ConvBlock(2), 
                                               keras.layers.Conv2D(filters=1, kernel_size=1, padding='same', activation='linear')])

    def call(self, x, skips):
        for skip, upsample_block in zip(skips, self.upsample_blocks):
            x = upsample_block(x, skip)
        
        x = self.last_block(x)
        
        return x
      
class SMD_Unet(tf.keras.Model):
    def __init__(self):
        super(SMD_Unet, self).__init__()

        self.filters = [64, 128, 256, 512, 1024]

        # Encoder
        self.encoder = EncoderBlock(self.filters)

        # Decoder
        # 5종류의 decoder가 있음
        # reconstruction
        # HardExudate, Hemohedge, Microane, SoftExudates
        self.reconstruction = DecoderBlock(self.filters[::-1][1:])
        self.HardExudate = DecoderBlock(self.filters[::-1][1:])
        self.Hemohedge = DecoderBlock(self.filters[::-1][1:])
        self.Microane = DecoderBlock(self.filters[::-1][1:])
        self.SoftExudates = DecoderBlock(self.filters[::-1][1:])


    def call(self, inputs, only_recons=False):
        # Encoder
        x, skips = self.encoder(inputs)
        # Decoder
        input_hat = self.reconstruction(x, skips[::-1])
        # reconstruction만 학습할 때 구분
        if only_recons:     
            return [input_hat]
        else:
            ex = self.HardExudate(x, skips[::-1])
            he = self.Hemohedge(x, skips[::-1])
            ma = self.Microane(x, skips[::-1])
            se = self.SoftExudates(x, skips[::-1])
            
            return [input_hat, ex, he, ma, se]

# %%
from data_generator import DR_Generator

# %%
import os

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/FGADR-Seg-set_Release/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
  'dir_path':'../data/FGADR-Seg-set_Release/Seg-set/Original_Images/',
  'mask_path':mask_paths,
  'use_mask':True,
  'img_size':(512, 512),  
  'batch_size':4, # 8로 하면 바로 OOM 뜸
  'dataset':'FGADR', # FGADR or EyePacks
  'is_train':True
}

tr_eyepacks_gen = DR_Generator(start_end_index=(0, 500), **generator_args)

# %%
1290 + 184
# Out:
# 1474

# %%
a = os.listdir('../data/FGADR-Seg-set_Release/Seg-set/HardExudate_Masks/')
a.sort()
len(a[:1474])
# Out:
# 1474

# %%
len(tr_eyepacks_gen.data_paths)
# Out:
# 500

# %%
for input, outputs in tr_eyepacks_gen:
    break

# %%
print(input.shape)
print(outputs[0].shape)
print(outputs[1].shape)
print(outputs[2].shape)
print(outputs[3].shape)
# Out:
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)

# %%
preds = model(input)
# 이미지 4개 예측하는데 23초나 걸리네...? , CPU라서 그런가보다

print(len(preds))
print(preds[0].shape)
print(preds[1].shape)
print(preds[2].shape)
print(preds[3].shape)
print(preds[4].shape)
# Out:
# 5
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)
# (4, 512, 512, 1)

# %%
preds = model(input, only_recons=True)

print(len(preds))
print(preds[0].shape)
# Out:
# 1
# (4, 512, 512, 1)

# %%
import numpy as np

def dice_loss(inputs, targets, smooth = 1.):
    inputs = np.array(inputs)
    targets = np.array(targets)
    
    dice_losses = []
    for input, target in zip(inputs, targets): 
        input_flat = input.flatten()
        target_flat = target.flatten()
        
        intersection = np.sum(input_flat * target_flat)
        dice_coef = (2. * intersection + smooth) / (np.sum(input_flat) + np.sum(target_flat) + smooth)

        dice_losses.append(1. - dice_coef)
        
    return np.mean(dice_losses)
    
def mean_square_error(input_hats, inputs):
    mses = []
    for input_hat, input in zip(input_hats, inputs):
        mses.append(tf.reduce_mean(tf.square(input_hat - input)).numpy())
    return np.mean(mses)

# %%
dice_loss(preds[1], outputs[1])
# Out:
# 0.9938407298426654

# %%
mean_square_error(preds[1], outputs[1])
# Out:
# 0.43095237
