# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# from assets.Preprocessing import preprocess_image
from sklearn.preprocessing import MultiLabelBinarizer

masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]


ex_file_list = os.listdir(mask_paths[0])
ex_paths = [os.path.join(mask_paths[0], file) for file in ex_file_list]
ex_paths.sort()

he_file_list = os.listdir(mask_paths[1])
he_paths = [os.path.join(mask_paths[1], file) for file in he_file_list]
he_paths.sort()

me_file_list = os.listdir(mask_paths[2])
me_paths = [os.path.join(mask_paths[2], file) for file in me_file_list]
me_paths.sort()

se_file_list = os.listdir(mask_paths[3])
se_paths = [os.path.join(mask_paths[3], file) for file in se_file_list]
se_paths.sort()

mask_images_paths = [list(_) for _ in zip(ex_paths, he_paths, me_paths, se_paths)]
        
image_dir = '../data/Seg-set/Original_Images'
image_paths = [os.path.join(image_dir, file) for file in os.listdir(image_dir)]
image_paths.sort()

tr_image_paths = image_paths[:1290]
tr_mask_paths = mask_images_paths[:1290]

mlb = MultiLabelBinarizer()
tr_labels_encoded = mlb.fit_transform(tr_mask_paths)

val_image_paths = image_paths[1290:1474]
val_mask_paths = mask_images_paths[1290:1474]

mlb = MultiLabelBinarizer()
val_labels_encoded = mlb.fit_transform(val_mask_paths)

# %%
IMAGE_SIZE = (512, 512)
BATCH_SIZE = 16

# %%
def crop_and_resize_image(image, img_size):
    resized_image = tf.image.resize(image, img_size)

    diameter = tf.minimum(tf.shape(resized_image)[0], tf.shape(resized_image)[1])
    center_x, center_y = tf.shape(resized_image)[1] // 2, tf.shape(resized_image)[0] // 2
    crop_size = tf.minimum(tf.minimum(center_x, center_y), diameter // 2)

    cropped_image = resized_image[
        center_y - crop_size:center_y + crop_size,
        center_x - crop_size:center_x + crop_size
    ]

    return cropped_image

def preprocess_image(image_path, img_size=(512, 512), use_hist=True):
    original_image = tf.io.read_file(image_path)
    original_image = tf.image.decode_jpeg(original_image, channels=3)

    if use_hist:
        seed = tf.constant([1, 2], dtype=tf.int32)
        clahe = tf.image.stateless_random_hue(original_image, max_delta=0.5, seed=seed)
        contrast_enhanced_image = tf.image.adjust_contrast(clahe, contrast_factor=2.0)
        cropped_image = crop_and_resize_image(contrast_enhanced_image, img_size)

        return cropped_image
    else:
        cropped_image = crop_and_resize_image(original_image, img_size)

        return cropped_image
    
def decode_image(img, channels=3):
    img = tf.image.decode_png(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    
    return img

def decode_label(label):
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    label -= 1
    
    return label

def load_and_preprocess_data(input_path, output_paths):
    image_path 

    ex_path = output_paths[0]
    
    
    # Read and preprocess the image
    image = tf.io.read_file(image_path)
    image = decode_image(image)
    image /= 255.0  # Normalize to [0, 1]

    # Read and preprocess the label
    ex = tf.io.read_file(ex_path)
    ex = decode_image(ex)
    # Convert to binary mask [0, 1] 
    ex = tf.cast(ex != 0, dtype=tf.float32)
    
    he = tf.io.read_file(he_path)
    he = decode_image(he)
    # Convert to binary mask [0, 1] 
    he = tf.cast(he != 0, dtype=tf.float32)
    
    me = tf.io.read_file(me_path)
    me = decode_image(me)
    # Convert to binary mask [0, 1] 
    me = tf.cast(me != 0, dtype=tf.float32)
    
    se = tf.io.read_file(se_path)
    se = decode_image(se)
    # Convert to binary mask [0, 1] 
    se = tf.cast(se != 0, dtype=tf.float32)
    
    return image, [ex, he, me, se]

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    ds = ds.repeat()
    
    return ds

tr_ds = tf.data.Dataset.from_tensor_slices((tr_image_paths, tr_labels_encoded))
tr_ds = tr_ds.map(load_and_preprocess_data, num_parallel_calls=tf.data.AUTOTUNE)
tr_ds = prepare_for_training(tr_ds)

val_ds = tf.data.Dataset.from_tensor_slices((tr_image_paths, val_labels_encoded))
val_ds = val_ds.map(load_and_preprocess_data, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = prepare_for_training(val_ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_334/3786558064.py in <module>
#      85
#      86 tr_ds = tf.data.Dataset.from_tensor_slices((tr_image_paths, tr_labels_encoded))
# ---> 87 tr_ds = tr_ds.map(load_and_preprocess_data, num_parallel_calls=tf.data.AUTOTUNE)
#      88 tr_ds = prepare_for_training(tr_ds)
#      89
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1861       return MapDataset(self, map_func, preserve_cardinality=True)
#    1862     else:
# -> 1863       return ParallelMapDataset(
#    1864           self,
#    1865           map_func,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    5018     self._input_dataset = input_dataset
#    5019     self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5020     self._map_func = StructuredFunctionWrapper(
#    5021         map_func,
#    5022         self._transformation_name(),
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4216         fn_factory = trace_tf_function(defun_kwargs)
#    4217
# -> 4218     self._function = fn_factory()
#    4219     # There is no graph to add in eager mode.
#    4220     add_to_graph &= not context.executing_eagerly()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3148          or `tf.Tensor` or `tf.TensorSpec`.
#    3149     """
# -> 3150     graph_function = self._get_concrete_function_garbage_collected(
#    3151         *args, **kwargs)
#    3152     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3114       args, kwargs = None, None
#    3115     with self._lock:
# -> 3116       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3117       seen_names = set()
#    3118       captured = object_identity.ObjectIdentitySet(
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapped_fn(*args)
#    4193           attributes=defun_kwargs)
#    4194       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4195         ret = wrapper_helper(*args)
#    4196         ret = structure.to_tensor_list(self._output_structure, ret)
#    4197         return [ops.convert_to_tensor(t) for t in ret]
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_helper(*args)
#    4123       if not _should_unpack(nested_args):
#    4124         nested_args = (nested_args,)
# -> 4125       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4126       if _should_pack(ret):
#    4127         ret = tuple(ret)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
# --> 695           raise e.ag_error_metadata.to_exception(e)
#     696         else:
#     697           raise
#
# TypeError: in user code:
#
#     /tmp/ipykernel_334/3786558064.py:56 load_and_preprocess_data  *
#         ex = tf.io.read_file(ex_path)
#     /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/io_ops.py:139 read_file  **
#         return gen_io_ops.read_file(filename, name)
#     /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py:560 read_file
#         _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py:544 _apply_op_helper
#         raise TypeError("%s expected type of %s." %
#
#     TypeError: Input 'filename' of 'ReadFile' Op has type int64 that does not match expected type of string.

# %%
tmp
# Out:
# [['../data/Seg-set/Original_Images/0000_1.png',
#   '../data/Seg-set/HardExudate_Masks/0000_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0000_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0000_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0000_1.png'],
#  ['../data/Seg-set/Original_Images/0001_2.png',
#   '../data/Seg-set/HardExudate_Masks/0001_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0001_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0001_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0001_2.png'],
#  ['../data/Seg-set/Original_Images/0002_1.png',
#   '../data/Seg-set/HardExudate_Masks/0002_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0002_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0002_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0002_1.png'],
#  ['../data/Seg-set/Original_Images/0003_3.png',
#   '../data/Seg-set/HardExudate_Masks/0003_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0003_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0003_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0003_3.png'],
#  ['../data/Seg-set/Original_Images/0004_1.png',
#   '../data/Seg-set/HardExudate_Masks/0004_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0004_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0004_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0004_1.png'],
#  ['../data/Seg-set/Original_Images/0005_1.png',
#   '../data/Seg-set/HardExudate_Masks/0005_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0005_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0005_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0005_1.png'],
#  ['../data/Seg-set/Original_Images/0006_1.png',
#   '../data/Seg-set/HardExudate_Masks/0006_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0006_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0006_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0006_1.png'],
#  ['../data/Seg-set/Original_Images/0007_2.png',
#   '../data/Seg-set/HardExudate_Masks/0007_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0007_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0007_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0007_2.png'],
#  ['../data/Seg-set/Original_Images/0008_2.png',
#   '../data/Seg-set/HardExudate_Masks/0008_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0008_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0008_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0008_2.png'],
#  ['../data/Seg-set/Original_Images/0009_1.png',
#   '../data/Seg-set/HardExudate_Masks/0009_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0009_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0009_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0009_1.png'],
#  ['../data/Seg-set/Original_Images/0010_1.png',
#   '../data/Seg-set/HardExudate_Masks/0010_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0010_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0010_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0010_1.png'],
#  ['../data/Seg-set/Original_Images/0011_3.png',
#   '../data/Seg-set/HardExudate_Masks/0011_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0011_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0011_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0011_3.png'],
#  ['../data/Seg-set/Original_Images/0012_2.png',
#   '../data/Seg-set/HardExudate_Masks/0012_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0012_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0012_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0012_2.png'],
#  ['../data/Seg-set/Original_Images/0013_1.png',
#   '../data/Seg-set/HardExudate_Masks/0013_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0013_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0013_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0013_1.png'],
#  ['../data/Seg-set/Original_Images/0014_3.png',
#   '../data/Seg-set/HardExudate_Masks/0014_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0014_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0014_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0014_3.png'],
#  ['../data/Seg-set/Original_Images/0015_2.png',
#   '../data/Seg-set/HardExudate_Masks/0015_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0015_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0015_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0015_2.png'],
#  ['../data/Seg-set/Original_Images/0016_3.png',
#   '../data/Seg-set/HardExudate_Masks/0016_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0016_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0016_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0016_3.png'],
#  ['../data/Seg-set/Original_Images/0017_2.png',
#   '../data/Seg-set/HardExudate_Masks/0017_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0017_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0017_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0017_2.png'],
#  ['../data/Seg-set/Original_Images/0018_3.png',
#   '../data/Seg-set/HardExudate_Masks/0018_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0018_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0018_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0018_3.png'],
#  ['../data/Seg-set/Original_Images/0019_1.png',
#   '../data/Seg-set/HardExudate_Masks/0019_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0019_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0019_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0019_1.png'],
#  ['../data/Seg-set/Original_Images/0020_1.png',
#   '../data/Seg-set/HardExudate_Masks/0020_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0020_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0020_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0020_1.png'],
#  ['../data/Seg-set/Original_Images/0021_1.png',
#   '../data/Seg-set/HardExudate_Masks/0021_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0021_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0021_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0021_1.png'],
#  ['../data/Seg-set/Original_Images/0022_3.png',
#   '../data/Seg-set/HardExudate_Masks/0022_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0022_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0022_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0022_3.png'],
#  ['../data/Seg-set/Original_Images/0023_1.png',
#   '../data/Seg-set/HardExudate_Masks/0023_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0023_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0023_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0023_1.png'],
#  ['../data/Seg-set/Original_Images/0024_2.png',
#   '../data/Seg-set/HardExudate_Masks/0024_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0024_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0024_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0024_2.png'],
#  ['../data/Seg-set/Original_Images/0025_3.png',
#   '../data/Seg-set/HardExudate_Masks/0025_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0025_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0025_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0025_3.png'],
#  ['../data/Seg-set/Original_Images/0026_2.png',
#   '../data/Seg-set/HardExudate_Masks/0026_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0026_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0026_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0026_2.png'],
#  ['../data/Seg-set/Original_Images/0027_3.png',
#   '../data/Seg-set/HardExudate_Masks/0027_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0027_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0027_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0027_3.png'],
#  ['../data/Seg-set/Original_Images/0028_1.png',
#   '../data/Seg-set/HardExudate_Masks/0028_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0028_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0028_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0028_1.png'],
#  ['../data/Seg-set/Original_Images/0029_1.png',
#   '../data/Seg-set/HardExudate_Masks/0029_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0029_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0029_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0029_1.png'],
#  ['../data/Seg-set/Original_Images/0030_1.png',
#   '../data/Seg-set/HardExudate_Masks/0030_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0030_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0030_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0030_1.png'],
#  ['../data/Seg-set/Original_Images/0031_2.png',
#   '../data/Seg-set/HardExudate_Masks/0031_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0031_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0031_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0031_2.png'],
#  ['../data/Seg-set/Original_Images/0032_3.png',
#   '../data/Seg-set/HardExudate_Masks/0032_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0032_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0032_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0032_3.png'],
#  ['../data/Seg-set/Original_Images/0033_3.png',
#   '../data/Seg-set/HardExudate_Masks/0033_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0033_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0033_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0033_3.png'],
#  ['../data/Seg-set/Original_Images/0034_1.png',
#   '../data/Seg-set/HardExudate_Masks/0034_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0034_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0034_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0034_1.png'],
#  ['../data/Seg-set/Original_Images/0035_1.png',
#   '../data/Seg-set/HardExudate_Masks/0035_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0035_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0035_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0035_1.png'],
#  ['../data/Seg-set/Original_Images/0036_1.png',
#   '../data/Seg-set/HardExudate_Masks/0036_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0036_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0036_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0036_1.png'],
#  ['../data/Seg-set/Original_Images/0037_1.png',
#   '../data/Seg-set/HardExudate_Masks/0037_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0037_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0037_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0037_1.png'],
#  ['../data/Seg-set/Original_Images/0038_2.png',
#   '../data/Seg-set/HardExudate_Masks/0038_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0038_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0038_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0038_2.png'],
#  ['../data/Seg-set/Original_Images/0039_2.png',
#   '../data/Seg-set/HardExudate_Masks/0039_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0039_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0039_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0039_2.png'],
#  ['../data/Seg-set/Original_Images/0040_2.png',
#   '../data/Seg-set/HardExudate_Masks/0040_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0040_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0040_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0040_2.png'],
#  ['../data/Seg-set/Original_Images/0041_1.png',
#   '../data/Seg-set/HardExudate_Masks/0041_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0041_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0041_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0041_1.png'],
#  ['../data/Seg-set/Original_Images/0042_1.png',
#   '../data/Seg-set/HardExudate_Masks/0042_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0042_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0042_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0042_1.png'],
#  ['../data/Seg-set/Original_Images/0043_3.png',
#   '../data/Seg-set/HardExudate_Masks/0043_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0043_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0043_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0043_3.png'],
#  ['../data/Seg-set/Original_Images/0044_3.png',
#   '../data/Seg-set/HardExudate_Masks/0044_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0044_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0044_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0044_3.png'],
#  ['../data/Seg-set/Original_Images/0045_3.png',
#   '../data/Seg-set/HardExudate_Masks/0045_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0045_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0045_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0045_3.png'],
#  ['../data/Seg-set/Original_Images/0046_1.png',
#   '../data/Seg-set/HardExudate_Masks/0046_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0046_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0046_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0046_1.png'],
#  ['../data/Seg-set/Original_Images/0047_1.png',
#   '../data/Seg-set/HardExudate_Masks/0047_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0047_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0047_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0047_1.png'],
#  ['../data/Seg-set/Original_Images/0048_3.png',
#   '../data/Seg-set/HardExudate_Masks/0048_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0048_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0048_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0048_3.png'],
#  ['../data/Seg-set/Original_Images/0049_3.png',
#   '../data/Seg-set/HardExudate_Masks/0049_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0049_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0049_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0049_3.png'],
#  ['../data/Seg-set/Original_Images/0050_3.png',
#   '../data/Seg-set/HardExudate_Masks/0050_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0050_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0050_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0050_3.png'],
#  ['../data/Seg-set/Original_Images/0051_3.png',
#   '../data/Seg-set/HardExudate_Masks/0051_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0051_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0051_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0051_3.png'],
#  ['../data/Seg-set/Original_Images/0052_2.png',
#   '../data/Seg-set/HardExudate_Masks/0052_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0052_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0052_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0052_2.png'],
#  ['../data/Seg-set/Original_Images/0053_2.png',
#   '../data/Seg-set/HardExudate_Masks/0053_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0053_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0053_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0053_2.png'],
#  ['../data/Seg-set/Original_Images/0054_3.png',
#   '../data/Seg-set/HardExudate_Masks/0054_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0054_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0054_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0054_3.png'],
#  ['../data/Seg-set/Original_Images/0055_3.png',
#   '../data/Seg-set/HardExudate_Masks/0055_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0055_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0055_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0055_3.png'],
#  ['../data/Seg-set/Original_Images/0056_1.png',
#   '../data/Seg-set/HardExudate_Masks/0056_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0056_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0056_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0056_1.png'],
#  ['../data/Seg-set/Original_Images/0057_3.png',
#   '../data/Seg-set/HardExudate_Masks/0057_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0057_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0057_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0057_3.png'],
#  ['../data/Seg-set/Original_Images/0058_1.png',
#   '../data/Seg-set/HardExudate_Masks/0058_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0058_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0058_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0058_1.png'],
#  ['../data/Seg-set/Original_Images/0059_3.png',
#   '../data/Seg-set/HardExudate_Masks/0059_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0059_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0059_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0059_3.png'],
#  ['../data/Seg-set/Original_Images/0060_1.png',
#   '../data/Seg-set/HardExudate_Masks/0060_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0060_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0060_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0060_1.png'],
#  ['../data/Seg-set/Original_Images/0061_3.png',
#   '../data/Seg-set/HardExudate_Masks/0061_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0061_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0061_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0061_3.png'],
#  ['../data/Seg-set/Original_Images/0062_1.png',
#   '../data/Seg-set/HardExudate_Masks/0062_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0062_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0062_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0062_1.png'],
#  ['../data/Seg-set/Original_Images/0063_3.png',
#   '../data/Seg-set/HardExudate_Masks/0063_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0063_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0063_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0063_3.png'],
#  ['../data/Seg-set/Original_Images/0064_1.png',
#   '../data/Seg-set/HardExudate_Masks/0064_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0064_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0064_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0064_1.png'],
#  ['../data/Seg-set/Original_Images/0065_1.png',
#   '../data/Seg-set/HardExudate_Masks/0065_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0065_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0065_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0065_1.png'],
#  ['../data/Seg-set/Original_Images/0066_1.png',
#   '../data/Seg-set/HardExudate_Masks/0066_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0066_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0066_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0066_1.png'],
#  ['../data/Seg-set/Original_Images/0067_2.png',
#   '../data/Seg-set/HardExudate_Masks/0067_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0067_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0067_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0067_2.png'],
#  ['../data/Seg-set/Original_Images/0068_1.png',
#   '../data/Seg-set/HardExudate_Masks/0068_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0068_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0068_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0068_1.png'],
#  ['../data/Seg-set/Original_Images/0069_3.png',
#   '../data/Seg-set/HardExudate_Masks/0069_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0069_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0069_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0069_3.png'],
#  ['../data/Seg-set/Original_Images/0070_3.png',
#   '../data/Seg-set/HardExudate_Masks/0070_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0070_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0070_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0070_3.png'],
#  ['../data/Seg-set/Original_Images/0071_1.png',
#   '../data/Seg-set/HardExudate_Masks/0071_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0071_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0071_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0071_1.png'],
#  ['../data/Seg-set/Original_Images/0072_2.png',
#   '../data/Seg-set/HardExudate_Masks/0072_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0072_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0072_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0072_2.png'],
#  ['../data/Seg-set/Original_Images/0073_3.png',
#   '../data/Seg-set/HardExudate_Masks/0073_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0073_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0073_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0073_3.png'],
#  ['../data/Seg-set/Original_Images/0074_2.png',
#   '../data/Seg-set/HardExudate_Masks/0074_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0074_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0074_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0074_2.png'],
#  ['../data/Seg-set/Original_Images/0075_1.png',
#   '../data/Seg-set/HardExudate_Masks/0075_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0075_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0075_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0075_1.png'],
#  ['../data/Seg-set/Original_Images/0076_3.png',
#   '../data/Seg-set/HardExudate_Masks/0076_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0076_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0076_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0076_3.png'],
#  ['../data/Seg-set/Original_Images/0077_1.png',
#   '../data/Seg-set/HardExudate_Masks/0077_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0077_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0077_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0077_1.png'],
#  ['../data/Seg-set/Original_Images/0078_1.png',
#   '../data/Seg-set/HardExudate_Masks/0078_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0078_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0078_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0078_1.png'],
#  ['../data/Seg-set/Original_Images/0079_1.png',
#   '../data/Seg-set/HardExudate_Masks/0079_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0079_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0079_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0079_1.png'],
#  ['../data/Seg-set/Original_Images/0080_2.png',
#   '../data/Seg-set/HardExudate_Masks/0080_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0080_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0080_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0080_2.png'],
#  ['../data/Seg-set/Original_Images/0081_3.png',
#   '../data/Seg-set/HardExudate_Masks/0081_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0081_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0081_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0081_3.png'],
#  ['../data/Seg-set/Original_Images/0082_1.png',
#   '../data/Seg-set/HardExudate_Masks/0082_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0082_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0082_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0082_1.png'],
#  ['../data/Seg-set/Original_Images/0083_3.png',
#   '../data/Seg-set/HardExudate_Masks/0083_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0083_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0083_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0083_3.png'],
#  ['../data/Seg-set/Original_Images/0084_3.png',
#   '../data/Seg-set/HardExudate_Masks/0084_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0084_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0084_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0084_3.png'],
#  ['../data/Seg-set/Original_Images/0085_1.png',
#   '../data/Seg-set/HardExudate_Masks/0085_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0085_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0085_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0085_1.png'],
#  ['../data/Seg-set/Original_Images/0086_1.png',
#   '../data/Seg-set/HardExudate_Masks/0086_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0086_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0086_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0086_1.png'],
#  ['../data/Seg-set/Original_Images/0087_3.png',
#   '../data/Seg-set/HardExudate_Masks/0087_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0087_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0087_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0087_3.png'],
#  ['../data/Seg-set/Original_Images/0088_3.png',
#   '../data/Seg-set/HardExudate_Masks/0088_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0088_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0088_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0088_3.png'],
#  ['../data/Seg-set/Original_Images/0089_2.png',
#   '../data/Seg-set/HardExudate_Masks/0089_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0089_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0089_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0089_2.png'],
#  ['../data/Seg-set/Original_Images/0090_3.png',
#   '../data/Seg-set/HardExudate_Masks/0090_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0090_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0090_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0090_3.png'],
#  ['../data/Seg-set/Original_Images/0091_3.png',
#   '../data/Seg-set/HardExudate_Masks/0091_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0091_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0091_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0091_3.png'],
#  ['../data/Seg-set/Original_Images/0092_1.png',
#   '../data/Seg-set/HardExudate_Masks/0092_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0092_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0092_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0092_1.png'],
#  ['../data/Seg-set/Original_Images/0093_1.png',
#   '../data/Seg-set/HardExudate_Masks/0093_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0093_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0093_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0093_1.png'],
#  ['../data/Seg-set/Original_Images/0094_3.png',
#   '../data/Seg-set/HardExudate_Masks/0094_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0094_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0094_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0094_3.png'],
#  ['../data/Seg-set/Original_Images/0095_1.png',
#   '../data/Seg-set/HardExudate_Masks/0095_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0095_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0095_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0095_1.png'],
#  ['../data/Seg-set/Original_Images/0096_1.png',
#   '../data/Seg-set/HardExudate_Masks/0096_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0096_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0096_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0096_1.png'],
#  ['../data/Seg-set/Original_Images/0097_2.png',
#   '../data/Seg-set/HardExudate_Masks/0097_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0097_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0097_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0097_2.png'],
#  ['../data/Seg-set/Original_Images/0098_3.png',
#   '../data/Seg-set/HardExudate_Masks/0098_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0098_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0098_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0098_3.png'],
#  ['../data/Seg-set/Original_Images/0099_1.png',
#   '../data/Seg-set/HardExudate_Masks/0099_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0099_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0099_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0099_1.png'],
#  ['../data/Seg-set/Original_Images/0100_3.png',
#   '../data/Seg-set/HardExudate_Masks/0100_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0100_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0100_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0100_3.png'],
#  ['../data/Seg-set/Original_Images/0101_2.png',
#   '../data/Seg-set/HardExudate_Masks/0101_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0101_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0101_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0101_2.png'],
#  ['../data/Seg-set/Original_Images/0102_3.png',
#   '../data/Seg-set/HardExudate_Masks/0102_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0102_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0102_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0102_3.png'],
#  ['../data/Seg-set/Original_Images/0103_3.png',
#   '../data/Seg-set/HardExudate_Masks/0103_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0103_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0103_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0103_3.png'],
#  ['../data/Seg-set/Original_Images/0104_1.png',
#   '../data/Seg-set/HardExudate_Masks/0104_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0104_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0104_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0104_1.png'],
#  ['../data/Seg-set/Original_Images/0105_3.png',
#   '../data/Seg-set/HardExudate_Masks/0105_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0105_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0105_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0105_3.png'],
#  ['../data/Seg-set/Original_Images/0106_1.png',
#   '../data/Seg-set/HardExudate_Masks/0106_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0106_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0106_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0106_1.png'],
#  ['../data/Seg-set/Original_Images/0107_3.png',
#   '../data/Seg-set/HardExudate_Masks/0107_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0107_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0107_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0107_3.png'],
#  ['../data/Seg-set/Original_Images/0108_1.png',
#   '../data/Seg-set/HardExudate_Masks/0108_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0108_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0108_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0108_1.png'],
#  ['../data/Seg-set/Original_Images/0109_1.png',
#   '../data/Seg-set/HardExudate_Masks/0109_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0109_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0109_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0109_1.png'],
#  ['../data/Seg-set/Original_Images/0110_3.png',
#   '../data/Seg-set/HardExudate_Masks/0110_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0110_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0110_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0110_3.png'],
#  ['../data/Seg-set/Original_Images/0111_3.png',
#   '../data/Seg-set/HardExudate_Masks/0111_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0111_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0111_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0111_3.png'],
#  ['../data/Seg-set/Original_Images/0112_1.png',
#   '../data/Seg-set/HardExudate_Masks/0112_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0112_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0112_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0112_1.png'],
#  ['../data/Seg-set/Original_Images/0113_3.png',
#   '../data/Seg-set/HardExudate_Masks/0113_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0113_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0113_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0113_3.png'],
#  ['../data/Seg-set/Original_Images/0114_1.png',
#   '../data/Seg-set/HardExudate_Masks/0114_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0114_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0114_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0114_1.png'],
#  ['../data/Seg-set/Original_Images/0115_1.png',
#   '../data/Seg-set/HardExudate_Masks/0115_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0115_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0115_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0115_1.png'],
#  ['../data/Seg-set/Original_Images/0116_1.png',
#   '../data/Seg-set/HardExudate_Masks/0116_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0116_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0116_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0116_1.png'],
#  ['../data/Seg-set/Original_Images/0117_1.png',
#   '../data/Seg-set/HardExudate_Masks/0117_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0117_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0117_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0117_1.png'],
#  ['../data/Seg-set/Original_Images/0118_3.png',
#   '../data/Seg-set/HardExudate_Masks/0118_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0118_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0118_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0118_3.png'],
#  ['../data/Seg-set/Original_Images/0119_1.png',
#   '../data/Seg-set/HardExudate_Masks/0119_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0119_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0119_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0119_1.png'],
#  ['../data/Seg-set/Original_Images/0120_3.png',
#   '../data/Seg-set/HardExudate_Masks/0120_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0120_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0120_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0120_3.png'],
#  ['../data/Seg-set/Original_Images/0121_2.png',
#   '../data/Seg-set/HardExudate_Masks/0121_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0121_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0121_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0121_2.png'],
#  ['../data/Seg-set/Original_Images/0122_1.png',
#   '../data/Seg-set/HardExudate_Masks/0122_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0122_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0122_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0122_1.png'],
#  ['../data/Seg-set/Original_Images/0123_3.png',
#   '../data/Seg-set/HardExudate_Masks/0123_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0123_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0123_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0123_3.png'],
#  ['../data/Seg-set/Original_Images/0124_2.png',
#   '../data/Seg-set/HardExudate_Masks/0124_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0124_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0124_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0124_2.png'],
#  ['../data/Seg-set/Original_Images/0125_1.png',
#   '../data/Seg-set/HardExudate_Masks/0125_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0125_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0125_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0125_1.png'],
#  ['../data/Seg-set/Original_Images/0126_2.png',
#   '../data/Seg-set/HardExudate_Masks/0126_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0126_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0126_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0126_2.png'],
#  ['../data/Seg-set/Original_Images/0127_2.png',
#   '../data/Seg-set/HardExudate_Masks/0127_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0127_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0127_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0127_2.png'],
#  ['../data/Seg-set/Original_Images/0128_3.png',
#   '../data/Seg-set/HardExudate_Masks/0128_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0128_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0128_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0128_3.png'],
#  ['../data/Seg-set/Original_Images/0129_1.png',
#   '../data/Seg-set/HardExudate_Masks/0129_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0129_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0129_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0129_1.png'],
#  ['../data/Seg-set/Original_Images/0130_1.png',
#   '../data/Seg-set/HardExudate_Masks/0130_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0130_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0130_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0130_1.png'],
#  ['../data/Seg-set/Original_Images/0131_3.png',
#   '../data/Seg-set/HardExudate_Masks/0131_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0131_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0131_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0131_3.png'],
#  ['../data/Seg-set/Original_Images/0132_1.png',
#   '../data/Seg-set/HardExudate_Masks/0132_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0132_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0132_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0132_1.png'],
#  ['../data/Seg-set/Original_Images/0133_3.png',
#   '../data/Seg-set/HardExudate_Masks/0133_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0133_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0133_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0133_3.png'],
#  ['../data/Seg-set/Original_Images/0134_1.png',
#   '../data/Seg-set/HardExudate_Masks/0134_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0134_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0134_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0134_1.png'],
#  ['../data/Seg-set/Original_Images/0135_1.png',
#   '../data/Seg-set/HardExudate_Masks/0135_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0135_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0135_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0135_1.png'],
#  ['../data/Seg-set/Original_Images/0136_1.png',
#   '../data/Seg-set/HardExudate_Masks/0136_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0136_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0136_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0136_1.png'],
#  ['../data/Seg-set/Original_Images/0137_3.png',
#   '../data/Seg-set/HardExudate_Masks/0137_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0137_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0137_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0137_3.png'],
#  ['../data/Seg-set/Original_Images/0138_1.png',
#   '../data/Seg-set/HardExudate_Masks/0138_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0138_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0138_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0138_1.png'],
#  ['../data/Seg-set/Original_Images/0139_1.png',
#   '../data/Seg-set/HardExudate_Masks/0139_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0139_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0139_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0139_1.png'],
#  ['../data/Seg-set/Original_Images/0140_2.png',
#   '../data/Seg-set/HardExudate_Masks/0140_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0140_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0140_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0140_2.png'],
#  ['../data/Seg-set/Original_Images/0141_3.png',
#   '../data/Seg-set/HardExudate_Masks/0141_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0141_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0141_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0141_3.png'],
#  ['../data/Seg-set/Original_Images/0142_1.png',
#   '../data/Seg-set/HardExudate_Masks/0142_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0142_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0142_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0142_1.png'],
#  ['../data/Seg-set/Original_Images/0143_3.png',
#   '../data/Seg-set/HardExudate_Masks/0143_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0143_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0143_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0143_3.png'],
#  ['../data/Seg-set/Original_Images/0144_1.png',
#   '../data/Seg-set/HardExudate_Masks/0144_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0144_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0144_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0144_1.png'],
#  ['../data/Seg-set/Original_Images/0145_1.png',
#   '../data/Seg-set/HardExudate_Masks/0145_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0145_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0145_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0145_1.png'],
#  ['../data/Seg-set/Original_Images/0146_3.png',
#   '../data/Seg-set/HardExudate_Masks/0146_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0146_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0146_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0146_3.png'],
#  ['../data/Seg-set/Original_Images/0147_3.png',
#   '../data/Seg-set/HardExudate_Masks/0147_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0147_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0147_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0147_3.png'],
#  ['../data/Seg-set/Original_Images/0148_1.png',
#   '../data/Seg-set/HardExudate_Masks/0148_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0148_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0148_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0148_1.png'],
#  ['../data/Seg-set/Original_Images/0149_3.png',
#   '../data/Seg-set/HardExudate_Masks/0149_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0149_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0149_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0149_3.png'],
#  ['../data/Seg-set/Original_Images/0150_3.png',
#   '../data/Seg-set/HardExudate_Masks/0150_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0150_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0150_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0150_3.png'],
#  ['../data/Seg-set/Original_Images/0151_3.png',
#   '../data/Seg-set/HardExudate_Masks/0151_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0151_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0151_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0151_3.png'],
#  ['../data/Seg-set/Original_Images/0152_1.png',
#   '../data/Seg-set/HardExudate_Masks/0152_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0152_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0152_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0152_1.png'],
#  ['../data/Seg-set/Original_Images/0153_2.png',
#   '../data/Seg-set/HardExudate_Masks/0153_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0153_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0153_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0153_2.png'],
#  ['../data/Seg-set/Original_Images/0154_1.png',
#   '../data/Seg-set/HardExudate_Masks/0154_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0154_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0154_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0154_1.png'],
#  ['../data/Seg-set/Original_Images/0155_1.png',
#   '../data/Seg-set/HardExudate_Masks/0155_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0155_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0155_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0155_1.png'],
#  ['../data/Seg-set/Original_Images/0156_1.png',
#   '../data/Seg-set/HardExudate_Masks/0156_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0156_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0156_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0156_1.png'],
#  ['../data/Seg-set/Original_Images/0157_1.png',
#   '../data/Seg-set/HardExudate_Masks/0157_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0157_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0157_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0157_1.png'],
#  ['../data/Seg-set/Original_Images/0158_1.png',
#   '../data/Seg-set/HardExudate_Masks/0158_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0158_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0158_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0158_1.png'],
#  ['../data/Seg-set/Original_Images/0159_1.png',
#   '../data/Seg-set/HardExudate_Masks/0159_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0159_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0159_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0159_1.png'],
#  ['../data/Seg-set/Original_Images/0160_2.png',
#   '../data/Seg-set/HardExudate_Masks/0160_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0160_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0160_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0160_2.png'],
#  ['../data/Seg-set/Original_Images/0161_3.png',
#   '../data/Seg-set/HardExudate_Masks/0161_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0161_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0161_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0161_3.png'],
#  ['../data/Seg-set/Original_Images/0162_1.png',
#   '../data/Seg-set/HardExudate_Masks/0162_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0162_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0162_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0162_1.png'],
#  ['../data/Seg-set/Original_Images/0163_3.png',
#   '../data/Seg-set/HardExudate_Masks/0163_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0163_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0163_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0163_3.png'],
#  ['../data/Seg-set/Original_Images/0164_3.png',
#   '../data/Seg-set/HardExudate_Masks/0164_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0164_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0164_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0164_3.png'],
#  ['../data/Seg-set/Original_Images/0165_1.png',
#   '../data/Seg-set/HardExudate_Masks/0165_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0165_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0165_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0165_1.png'],
#  ['../data/Seg-set/Original_Images/0166_1.png',
#   '../data/Seg-set/HardExudate_Masks/0166_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0166_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0166_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0166_1.png'],
#  ['../data/Seg-set/Original_Images/0167_2.png',
#   '../data/Seg-set/HardExudate_Masks/0167_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0167_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0167_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0167_2.png'],
#  ['../data/Seg-set/Original_Images/0168_2.png',
#   '../data/Seg-set/HardExudate_Masks/0168_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0168_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0168_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0168_2.png'],
#  ['../data/Seg-set/Original_Images/0169_1.png',
#   '../data/Seg-set/HardExudate_Masks/0169_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0169_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0169_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0169_1.png'],
#  ['../data/Seg-set/Original_Images/0170_2.png',
#   '../data/Seg-set/HardExudate_Masks/0170_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0170_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0170_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0170_2.png'],
#  ['../data/Seg-set/Original_Images/0171_1.png',
#   '../data/Seg-set/HardExudate_Masks/0171_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0171_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0171_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0171_1.png'],
#  ['../data/Seg-set/Original_Images/0172_1.png',
#   '../data/Seg-set/HardExudate_Masks/0172_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0172_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0172_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0172_1.png'],
#  ['../data/Seg-set/Original_Images/0173_1.png',
#   '../data/Seg-set/HardExudate_Masks/0173_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0173_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0173_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0173_1.png'],
#  ['../data/Seg-set/Original_Images/0174_2.png',
#   '../data/Seg-set/HardExudate_Masks/0174_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0174_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0174_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0174_2.png'],
#  ['../data/Seg-set/Original_Images/0175_1.png',
#   '../data/Seg-set/HardExudate_Masks/0175_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0175_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0175_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0175_1.png'],
#  ['../data/Seg-set/Original_Images/0176_3.png',
#   '../data/Seg-set/HardExudate_Masks/0176_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0176_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0176_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0176_3.png'],
#  ['../data/Seg-set/Original_Images/0177_2.png',
#   '../data/Seg-set/HardExudate_Masks/0177_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0177_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0177_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0177_2.png'],
#  ['../data/Seg-set/Original_Images/0178_1.png',
#   '../data/Seg-set/HardExudate_Masks/0178_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0178_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0178_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0178_1.png'],
#  ['../data/Seg-set/Original_Images/0179_1.png',
#   '../data/Seg-set/HardExudate_Masks/0179_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0179_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0179_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0179_1.png'],
#  ['../data/Seg-set/Original_Images/0180_2.png',
#   '../data/Seg-set/HardExudate_Masks/0180_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0180_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0180_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0180_2.png'],
#  ['../data/Seg-set/Original_Images/0181_1.png',
#   '../data/Seg-set/HardExudate_Masks/0181_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0181_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0181_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0181_1.png'],
#  ['../data/Seg-set/Original_Images/0182_2.png',
#   '../data/Seg-set/HardExudate_Masks/0182_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0182_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0182_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0182_2.png'],
#  ['../data/Seg-set/Original_Images/0183_1.png',
#   '../data/Seg-set/HardExudate_Masks/0183_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0183_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0183_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0183_1.png'],
#  ['../data/Seg-set/Original_Images/0184_3.png',
#   '../data/Seg-set/HardExudate_Masks/0184_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0184_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0184_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0184_3.png'],
#  ['../data/Seg-set/Original_Images/0185_3.png',
#   '../data/Seg-set/HardExudate_Masks/0185_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0185_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0185_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0185_3.png'],
#  ['../data/Seg-set/Original_Images/0186_3.png',
#   '../data/Seg-set/HardExudate_Masks/0186_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0186_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0186_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0186_3.png'],
#  ['../data/Seg-set/Original_Images/0187_1.png',
#   '../data/Seg-set/HardExudate_Masks/0187_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0187_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0187_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0187_1.png'],
#  ['../data/Seg-set/Original_Images/0188_1.png',
#   '../data/Seg-set/HardExudate_Masks/0188_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0188_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0188_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0188_1.png'],
#  ['../data/Seg-set/Original_Images/0189_1.png',
#   '../data/Seg-set/HardExudate_Masks/0189_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0189_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0189_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0189_1.png'],
#  ['../data/Seg-set/Original_Images/0190_1.png',
#   '../data/Seg-set/HardExudate_Masks/0190_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0190_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0190_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0190_1.png'],
#  ['../data/Seg-set/Original_Images/0191_3.png',
#   '../data/Seg-set/HardExudate_Masks/0191_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0191_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0191_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0191_3.png'],
# ...
#   '../data/Seg-set/HardExudate_Masks/0936_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0936_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0936_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0936_1.png'],
#  ['../data/Seg-set/Original_Images/0937_1.png',
#   '../data/Seg-set/HardExudate_Masks/0937_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0937_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0937_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0937_1.png'],
#  ['../data/Seg-set/Original_Images/0938_1.png',
#   '../data/Seg-set/HardExudate_Masks/0938_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0938_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0938_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0938_1.png'],
#  ['../data/Seg-set/Original_Images/0939_3.png',
#   '../data/Seg-set/HardExudate_Masks/0939_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0939_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0939_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0939_3.png'],
#  ['../data/Seg-set/Original_Images/0940_3.png',
#   '../data/Seg-set/HardExudate_Masks/0940_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0940_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0940_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0940_3.png'],
#  ['../data/Seg-set/Original_Images/0941_3.png',
#   '../data/Seg-set/HardExudate_Masks/0941_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0941_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0941_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0941_3.png'],
#  ['../data/Seg-set/Original_Images/0942_1.png',
#   '../data/Seg-set/HardExudate_Masks/0942_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0942_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0942_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0942_1.png'],
#  ['../data/Seg-set/Original_Images/0943_2.png',
#   '../data/Seg-set/HardExudate_Masks/0943_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0943_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0943_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0943_2.png'],
#  ['../data/Seg-set/Original_Images/0944_2.png',
#   '../data/Seg-set/HardExudate_Masks/0944_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0944_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0944_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0944_2.png'],
#  ['../data/Seg-set/Original_Images/0945_1.png',
#   '../data/Seg-set/HardExudate_Masks/0945_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0945_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0945_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0945_1.png'],
#  ['../data/Seg-set/Original_Images/0946_1.png',
#   '../data/Seg-set/HardExudate_Masks/0946_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0946_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0946_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0946_1.png'],
#  ['../data/Seg-set/Original_Images/0947_1.png',
#   '../data/Seg-set/HardExudate_Masks/0947_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0947_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0947_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0947_1.png'],
#  ['../data/Seg-set/Original_Images/0948_3.png',
#   '../data/Seg-set/HardExudate_Masks/0948_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0948_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0948_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0948_3.png'],
#  ['../data/Seg-set/Original_Images/0949_3.png',
#   '../data/Seg-set/HardExudate_Masks/0949_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0949_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0949_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0949_3.png'],
#  ['../data/Seg-set/Original_Images/0950_2.png',
#   '../data/Seg-set/HardExudate_Masks/0950_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0950_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0950_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0950_2.png'],
#  ['../data/Seg-set/Original_Images/0951_1.png',
#   '../data/Seg-set/HardExudate_Masks/0951_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0951_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0951_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0951_1.png'],
#  ['../data/Seg-set/Original_Images/0952_3.png',
#   '../data/Seg-set/HardExudate_Masks/0952_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0952_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0952_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0952_3.png'],
#  ['../data/Seg-set/Original_Images/0953_3.png',
#   '../data/Seg-set/HardExudate_Masks/0953_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0953_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0953_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0953_3.png'],
#  ['../data/Seg-set/Original_Images/0954_1.png',
#   '../data/Seg-set/HardExudate_Masks/0954_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0954_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0954_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0954_1.png'],
#  ['../data/Seg-set/Original_Images/0955_1.png',
#   '../data/Seg-set/HardExudate_Masks/0955_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0955_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0955_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0955_1.png'],
#  ['../data/Seg-set/Original_Images/0956_1.png',
#   '../data/Seg-set/HardExudate_Masks/0956_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0956_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0956_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0956_1.png'],
#  ['../data/Seg-set/Original_Images/0957_1.png',
#   '../data/Seg-set/HardExudate_Masks/0957_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0957_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0957_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0957_1.png'],
#  ['../data/Seg-set/Original_Images/0958_3.png',
#   '../data/Seg-set/HardExudate_Masks/0958_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0958_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0958_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0958_3.png'],
#  ['../data/Seg-set/Original_Images/0959_1.png',
#   '../data/Seg-set/HardExudate_Masks/0959_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0959_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0959_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0959_1.png'],
#  ['../data/Seg-set/Original_Images/0960_3.png',
#   '../data/Seg-set/HardExudate_Masks/0960_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0960_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0960_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0960_3.png'],
#  ['../data/Seg-set/Original_Images/0961_3.png',
#   '../data/Seg-set/HardExudate_Masks/0961_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0961_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0961_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0961_3.png'],
#  ['../data/Seg-set/Original_Images/0962_1.png',
#   '../data/Seg-set/HardExudate_Masks/0962_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0962_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0962_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0962_1.png'],
#  ['../data/Seg-set/Original_Images/0963_1.png',
#   '../data/Seg-set/HardExudate_Masks/0963_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0963_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0963_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0963_1.png'],
#  ['../data/Seg-set/Original_Images/0964_1.png',
#   '../data/Seg-set/HardExudate_Masks/0964_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0964_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0964_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0964_1.png'],
#  ['../data/Seg-set/Original_Images/0965_2.png',
#   '../data/Seg-set/HardExudate_Masks/0965_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0965_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0965_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0965_2.png'],
#  ['../data/Seg-set/Original_Images/0966_2.png',
#   '../data/Seg-set/HardExudate_Masks/0966_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0966_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0966_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0966_2.png'],
#  ['../data/Seg-set/Original_Images/0967_1.png',
#   '../data/Seg-set/HardExudate_Masks/0967_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0967_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0967_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0967_1.png'],
#  ['../data/Seg-set/Original_Images/0968_1.png',
#   '../data/Seg-set/HardExudate_Masks/0968_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0968_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0968_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0968_1.png'],
#  ['../data/Seg-set/Original_Images/0969_3.png',
#   '../data/Seg-set/HardExudate_Masks/0969_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0969_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0969_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0969_3.png'],
#  ['../data/Seg-set/Original_Images/0970_1.png',
#   '../data/Seg-set/HardExudate_Masks/0970_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0970_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0970_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0970_1.png'],
#  ['../data/Seg-set/Original_Images/0971_3.png',
#   '../data/Seg-set/HardExudate_Masks/0971_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0971_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0971_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0971_3.png'],
#  ['../data/Seg-set/Original_Images/0972_3.png',
#   '../data/Seg-set/HardExudate_Masks/0972_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0972_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0972_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0972_3.png'],
#  ['../data/Seg-set/Original_Images/0973_3.png',
#   '../data/Seg-set/HardExudate_Masks/0973_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0973_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0973_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0973_3.png'],
#  ['../data/Seg-set/Original_Images/0974_1.png',
#   '../data/Seg-set/HardExudate_Masks/0974_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0974_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0974_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0974_1.png'],
#  ['../data/Seg-set/Original_Images/0975_1.png',
#   '../data/Seg-set/HardExudate_Masks/0975_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0975_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0975_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0975_1.png'],
#  ['../data/Seg-set/Original_Images/0976_1.png',
#   '../data/Seg-set/HardExudate_Masks/0976_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0976_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0976_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0976_1.png'],
#  ['../data/Seg-set/Original_Images/0977_3.png',
#   '../data/Seg-set/HardExudate_Masks/0977_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0977_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0977_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0977_3.png'],
#  ['../data/Seg-set/Original_Images/0978_3.png',
#   '../data/Seg-set/HardExudate_Masks/0978_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0978_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0978_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0978_3.png'],
#  ['../data/Seg-set/Original_Images/0979_2.png',
#   '../data/Seg-set/HardExudate_Masks/0979_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0979_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0979_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0979_2.png'],
#  ['../data/Seg-set/Original_Images/0980_3.png',
#   '../data/Seg-set/HardExudate_Masks/0980_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0980_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0980_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0980_3.png'],
#  ['../data/Seg-set/Original_Images/0981_1.png',
#   '../data/Seg-set/HardExudate_Masks/0981_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0981_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0981_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0981_1.png'],
#  ['../data/Seg-set/Original_Images/0982_3.png',
#   '../data/Seg-set/HardExudate_Masks/0982_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0982_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0982_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0982_3.png'],
#  ['../data/Seg-set/Original_Images/0983_1.png',
#   '../data/Seg-set/HardExudate_Masks/0983_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0983_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0983_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0983_1.png'],
#  ['../data/Seg-set/Original_Images/0984_1.png',
#   '../data/Seg-set/HardExudate_Masks/0984_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0984_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0984_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0984_1.png'],
#  ['../data/Seg-set/Original_Images/0985_2.png',
#   '../data/Seg-set/HardExudate_Masks/0985_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0985_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0985_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0985_2.png'],
#  ['../data/Seg-set/Original_Images/0986_1.png',
#   '../data/Seg-set/HardExudate_Masks/0986_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0986_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0986_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0986_1.png'],
#  ['../data/Seg-set/Original_Images/0987_2.png',
#   '../data/Seg-set/HardExudate_Masks/0987_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0987_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0987_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0987_2.png'],
#  ['../data/Seg-set/Original_Images/0988_1.png',
#   '../data/Seg-set/HardExudate_Masks/0988_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0988_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0988_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0988_1.png'],
#  ['../data/Seg-set/Original_Images/0989_2.png',
#   '../data/Seg-set/HardExudate_Masks/0989_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0989_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0989_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0989_2.png'],
#  ['../data/Seg-set/Original_Images/0990_1.png',
#   '../data/Seg-set/HardExudate_Masks/0990_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0990_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0990_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0990_1.png'],
#  ['../data/Seg-set/Original_Images/0991_1.png',
#   '../data/Seg-set/HardExudate_Masks/0991_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0991_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0991_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0991_1.png'],
#  ['../data/Seg-set/Original_Images/0992_2.png',
#   '../data/Seg-set/HardExudate_Masks/0992_2.png',
#   '../data/Seg-set/Hemohedge_Masks/0992_2.png',
#   '../data/Seg-set/Microaneurysms_Masks/0992_2.png',
#   '../data/Seg-set/SoftExudate_Masks/0992_2.png'],
#  ['../data/Seg-set/Original_Images/0993_1.png',
#   '../data/Seg-set/HardExudate_Masks/0993_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0993_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0993_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0993_1.png'],
#  ['../data/Seg-set/Original_Images/0994_3.png',
#   '../data/Seg-set/HardExudate_Masks/0994_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0994_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0994_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0994_3.png'],
#  ['../data/Seg-set/Original_Images/0995_1.png',
#   '../data/Seg-set/HardExudate_Masks/0995_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0995_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0995_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0995_1.png'],
#  ['../data/Seg-set/Original_Images/0996_1.png',
#   '../data/Seg-set/HardExudate_Masks/0996_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0996_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0996_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0996_1.png'],
#  ['../data/Seg-set/Original_Images/0997_3.png',
#   '../data/Seg-set/HardExudate_Masks/0997_3.png',
#   '../data/Seg-set/Hemohedge_Masks/0997_3.png',
#   '../data/Seg-set/Microaneurysms_Masks/0997_3.png',
#   '../data/Seg-set/SoftExudate_Masks/0997_3.png'],
#  ['../data/Seg-set/Original_Images/0998_1.png',
#   '../data/Seg-set/HardExudate_Masks/0998_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0998_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0998_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0998_1.png'],
#  ['../data/Seg-set/Original_Images/0999_1.png',
#   '../data/Seg-set/HardExudate_Masks/0999_1.png',
#   '../data/Seg-set/Hemohedge_Masks/0999_1.png',
#   '../data/Seg-set/Microaneurysms_Masks/0999_1.png',
#   '../data/Seg-set/SoftExudate_Masks/0999_1.png'],
#  ...]

# %%
# 결과 확인하기
for image, label in tr_ds.take(1):
    print(image.shape)
    print(label.shape)
    
plt.imshow(image[0]*255)
plt.show()
plt.imshow(label[0])
plt.show()

for image, label in val_ds.take(1):
    print(image.shape)
    print(label.shape)
    
plt.imshow(image[0]*255)
plt.show()
plt.imshow(label[0])
plt.show()
# Out:
# ()
# ()
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_334/1274460974.py in <module>
#       4     print(label.shape)
#       5
# ----> 6 plt.imshow(image[0]*255)
#       7 plt.show()
#       8 plt.imshow(label[0])
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#    1039       var_empty = constant([], dtype=dtypes.int32)
#    1040       packed_begin = packed_end = packed_strides = var_empty
# -> 1041     return strided_slice(
#    1042         tensor,
#    1043         packed_begin,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1212     strides = ones_like(begin)
#    1213
# -> 1214   op = gen_array_ops.strided_slice(
#    1215       input=input_,
#    1216       begin=begin,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10509       return _result
#   10510     except _core._NotOkStatusException as e:
# > 10511       _ops.raise_from_not_ok_status(e, name)
#   10512     except _core._FallbackException:
#   10513       pass
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# /opt/conda/lib/python3.9/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Index out of range using input dim 0; input has only 0 dims [Op:StridedSlice] name: strided_slice/

# %%
from tensorflow.keras import losses
from tensorflow.keras import backend as K
from tensorflow import keras

class DiceScoreLossK(losses.Loss):
    def call(self, y_true, y_pred):
        smooth = 1.0
        
        numerator = 2. * K.sum(y_true * y_pred)
        denominator = K.sum(y_true + y_pred)
        
        return K.mean(1 - numerator / (denominator + smooth))

# mymodel.compile(loss=DiceScoreLossK(smooth=1.), ...)

# %%
def ConvBlock(x, n_filters):
    x = keras.layers.Conv2D(n_filters, 3, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    
    x = keras.layers.Conv2D(n_filters, 3, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    
    return x

def EncoderBlock(x, n_filters):
    p = ConvBlock(x, n_filters)
    x = keras.layers.MaxPooling2D(2)(p)
    
    return x, p

def DecoderBlock(x, n_filters, skip):
    x = keras.layers.Conv2DTranspose(n_filters, (2, 2), strides=2, padding='same')(x)
    x = keras.layers.Concatenate()([x, skip])
    x = ConvBlock(x, n_filters)
    
    return x

# Unet
# U-net
def UNET(img_size):
    inputs = keras.Input(shape=img_size + (3,))
    
    # 축소 경로
    skips = []
    
    filters = [64, 128, 256, 512, 1024]
    for f in filters:
        if f == 64:
            x, p = EncoderBlock(inputs, f)
            skips.append(p)
        else:
            x, p = EncoderBlock(x, f)
            skips.append(p)

    # 확장 경로
    for skip, f in zip(skips[::-1], filters[::-1]):
        if f == 1024:
            x_ex = DecoderBlock(x, f, skip)
            x_he = DecoderBlock(x, f, skip)
            x_me = DecoderBlock(x, f, skip)
            x_se = DecoderBlock(x, f, skip)
        else:
            x_ex = DecoderBlock(x_ex, f, skip)
            x_he = DecoderBlock(x_he, f, skip)
            x_me = DecoderBlock(x_me, f, skip)
            x_se = DecoderBlock(x_se, f, skip)

    output_ex = keras.layers.Conv2D(1, 1, padding='same', activation='sigmoid', name='output_ex')(x_ex)
    output_he = keras.layers.Conv2D(1, 1, padding='same', activation='sigmoid', name='output_he')(x_he)
    output_me = keras.layers.Conv2D(1, 1, padding='same', activation='sigmoid', name='output_me')(x_me)
    output_se = keras.layers.Conv2D(1, 1, padding='same', activation='sigmoid', name='output_se')(x_se)
    
    model = keras.Model(inputs, outputs=[output_ex, output_he, output_me, output_se])
    
    return model

# %%
losses = {
    "output_ex":DiceScoreLossK(),
    "output_he":DiceScoreLossK(),
    "output_me":DiceScoreLossK(),
    "output_se":DiceScoreLossK()
}

model = UNET((512, 512))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) 

model.compile(loss=losses, optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_31 (InputLayer)           [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 512, 512, 64) 1792        input_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_342 (BatchN (None, 512, 512, 64) 256         conv2d_342[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 512, 512, 64) 0           batch_normalization_342[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 512, 512, 64) 36928       activation_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_343 (BatchN (None, 512, 512, 64) 256         conv2d_343[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_145 (MaxPooling2D (None, 256, 256, 64) 0           batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 256, 256, 128 73856       max_pooling2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_344 (BatchN (None, 256, 256, 128 512         conv2d_344[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 256, 256, 128 0           batch_normalization_344[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 256, 256, 128 147584      activation_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_345 (BatchN (None, 256, 256, 128 512         conv2d_345[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_146 (MaxPooling2D (None, 128, 128, 128 0           batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 128, 128, 256 295168      max_pooling2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_346 (BatchN (None, 128, 128, 256 1024        conv2d_346[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 128, 128, 256 0           batch_normalization_346[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 128, 128, 256 590080      activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_347 (BatchN (None, 128, 128, 256 1024        conv2d_347[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_147 (MaxPooling2D (None, 64, 64, 256)  0           batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 64, 64, 512)  1180160     max_pooling2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_348 (BatchN (None, 64, 64, 512)  2048        conv2d_348[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 64, 64, 512)  0           batch_normalization_348[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 64, 64, 512)  2359808     activation_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_349 (BatchN (None, 64, 64, 512)  2048        conv2d_349[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_148 (MaxPooling2D (None, 32, 32, 512)  0           batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 32, 32, 1024) 4719616     max_pooling2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_350 (BatchN (None, 32, 32, 1024) 4096        conv2d_350[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_350[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 32, 32, 1024) 9438208     activation_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_351 (BatchN (None, 32, 32, 1024) 4096        conv2d_351[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_149 (MaxPooling2D (None, 16, 16, 1024) 0           batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_47 (Conv2DTran (None, 32, 32, 1024) 4195328     max_pooling2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_48 (Conv2DTran (None, 32, 32, 1024) 4195328     max_pooling2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_49 (Conv2DTran (None, 32, 32, 1024) 4195328     max_pooling2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_50 (Conv2DTran (None, 32, 32, 1024) 4195328     max_pooling2d_149[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 32, 32, 2048) 0           conv2d_transpose_47[0][0]
#                                                                  batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 32, 32, 2048) 0           conv2d_transpose_48[0][0]
#                                                                  batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 32, 32, 2048) 0           conv2d_transpose_49[0][0]
#                                                                  batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 32, 32, 2048) 0           conv2d_transpose_50[0][0]
#                                                                  batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 32, 32, 1024) 18875392    concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 32, 32, 1024) 18875392    concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 32, 32, 1024) 18875392    concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 32, 32, 1024) 18875392    concatenate_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_352 (BatchN (None, 32, 32, 1024) 4096        conv2d_352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_354 (BatchN (None, 32, 32, 1024) 4096        conv2d_354[0][0]
# __________________________________________________________________________________________________
# batch_normalization_356 (BatchN (None, 32, 32, 1024) 4096        conv2d_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_358 (BatchN (None, 32, 32, 1024) 4096        conv2d_358[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_352[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_354[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_356[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_358[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 32, 32, 1024) 9438208     activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 32, 32, 1024) 9438208     activation_177[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 32, 32, 1024) 9438208     activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 32, 32, 1024) 9438208     activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_353 (BatchN (None, 32, 32, 1024) 4096        conv2d_353[0][0]
# __________________________________________________________________________________________________
# batch_normalization_355 (BatchN (None, 32, 32, 1024) 4096        conv2d_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_357 (BatchN (None, 32, 32, 1024) 4096        conv2d_357[0][0]
# __________________________________________________________________________________________________
# batch_normalization_359 (BatchN (None, 32, 32, 1024) 4096        conv2d_359[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_51 (Conv2DTran (None, 64, 64, 512)  2097664     batch_normalization_353[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_52 (Conv2DTran (None, 64, 64, 512)  2097664     batch_normalization_355[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_53 (Conv2DTran (None, 64, 64, 512)  2097664     batch_normalization_357[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_54 (Conv2DTran (None, 64, 64, 512)  2097664     batch_normalization_359[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 64, 64, 1024) 0           conv2d_transpose_51[0][0]
#                                                                  batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 64, 64, 1024) 0           conv2d_transpose_52[0][0]
#                                                                  batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 64, 64, 1024) 0           conv2d_transpose_53[0][0]
#                                                                  batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 64, 64, 1024) 0           conv2d_transpose_54[0][0]
#                                                                  batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 64, 64, 512)  4719104     concatenate_50[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 64, 64, 512)  4719104     concatenate_51[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 64, 64, 512)  4719104     concatenate_52[0][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, 64, 64, 512)  4719104     concatenate_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_360 (BatchN (None, 64, 64, 512)  2048        conv2d_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_362 (BatchN (None, 64, 64, 512)  2048        conv2d_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_364 (BatchN (None, 64, 64, 512)  2048        conv2d_364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_366 (BatchN (None, 64, 64, 512)  2048        conv2d_366[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 64, 64, 512)  0           batch_normalization_360[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 64, 64, 512)  0           batch_normalization_362[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 64, 64, 512)  0           batch_normalization_364[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 64, 64, 512)  0           batch_normalization_366[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 64, 64, 512)  2359808     activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 64, 64, 512)  2359808     activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, 64, 64, 512)  2359808     activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, 64, 64, 512)  2359808     activation_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_361 (BatchN (None, 64, 64, 512)  2048        conv2d_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_363 (BatchN (None, 64, 64, 512)  2048        conv2d_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_365 (BatchN (None, 64, 64, 512)  2048        conv2d_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_367 (BatchN (None, 64, 64, 512)  2048        conv2d_367[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_55 (Conv2DTran (None, 128, 128, 256 524544      batch_normalization_361[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_56 (Conv2DTran (None, 128, 128, 256 524544      batch_normalization_363[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_57 (Conv2DTran (None, 128, 128, 256 524544      batch_normalization_365[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_58 (Conv2DTran (None, 128, 128, 256 524544      batch_normalization_367[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 128, 128, 512 0           conv2d_transpose_55[0][0]
#                                                                  batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 128, 128, 512 0           conv2d_transpose_56[0][0]
#                                                                  batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 128, 128, 512 0           conv2d_transpose_57[0][0]
#                                                                  batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 128, 128, 512 0           conv2d_transpose_58[0][0]
#                                                                  batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# conv2d_368 (Conv2D)             (None, 128, 128, 256 1179904     concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_370 (Conv2D)             (None, 128, 128, 256 1179904     concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_372 (Conv2D)             (None, 128, 128, 256 1179904     concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_374 (Conv2D)             (None, 128, 128, 256 1179904     concatenate_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_368 (BatchN (None, 128, 128, 256 1024        conv2d_368[0][0]
# __________________________________________________________________________________________________
# batch_normalization_370 (BatchN (None, 128, 128, 256 1024        conv2d_370[0][0]
# __________________________________________________________________________________________________
# batch_normalization_372 (BatchN (None, 128, 128, 256 1024        conv2d_372[0][0]
# __________________________________________________________________________________________________
# batch_normalization_374 (BatchN (None, 128, 128, 256 1024        conv2d_374[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 128, 128, 256 0           batch_normalization_368[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 128, 128, 256 0           batch_normalization_370[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 128, 128, 256 0           batch_normalization_372[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 128, 128, 256 0           batch_normalization_374[0][0]
# __________________________________________________________________________________________________
# conv2d_369 (Conv2D)             (None, 128, 128, 256 590080      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_371 (Conv2D)             (None, 128, 128, 256 590080      activation_185[0][0]
# __________________________________________________________________________________________________
# conv2d_373 (Conv2D)             (None, 128, 128, 256 590080      activation_186[0][0]
# __________________________________________________________________________________________________
# conv2d_375 (Conv2D)             (None, 128, 128, 256 590080      activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_369 (BatchN (None, 128, 128, 256 1024        conv2d_369[0][0]
# __________________________________________________________________________________________________
# batch_normalization_371 (BatchN (None, 128, 128, 256 1024        conv2d_371[0][0]
# __________________________________________________________________________________________________
# batch_normalization_373 (BatchN (None, 128, 128, 256 1024        conv2d_373[0][0]
# __________________________________________________________________________________________________
# batch_normalization_375 (BatchN (None, 128, 128, 256 1024        conv2d_375[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_59 (Conv2DTran (None, 256, 256, 128 131200      batch_normalization_369[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_60 (Conv2DTran (None, 256, 256, 128 131200      batch_normalization_371[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_61 (Conv2DTran (None, 256, 256, 128 131200      batch_normalization_373[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_62 (Conv2DTran (None, 256, 256, 128 131200      batch_normalization_375[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 256, 256, 256 0           conv2d_transpose_59[0][0]
#                                                                  batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 256, 256, 256 0           conv2d_transpose_60[0][0]
#                                                                  batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 256, 256, 256 0           conv2d_transpose_61[0][0]
#                                                                  batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 256, 256, 256 0           conv2d_transpose_62[0][0]
#                                                                  batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# conv2d_376 (Conv2D)             (None, 256, 256, 128 295040      concatenate_58[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 256, 256, 128 295040      concatenate_59[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, 256, 256, 128 295040      concatenate_60[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, 256, 256, 128 295040      concatenate_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_376 (BatchN (None, 256, 256, 128 512         conv2d_376[0][0]
# __________________________________________________________________________________________________
# batch_normalization_378 (BatchN (None, 256, 256, 128 512         conv2d_378[0][0]
# __________________________________________________________________________________________________
# batch_normalization_380 (BatchN (None, 256, 256, 128 512         conv2d_380[0][0]
# __________________________________________________________________________________________________
# batch_normalization_382 (BatchN (None, 256, 256, 128 512         conv2d_382[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 256, 256, 128 0           batch_normalization_376[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 256, 256, 128 0           batch_normalization_378[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 256, 256, 128 0           batch_normalization_380[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 256, 256, 128 0           batch_normalization_382[0][0]
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, 256, 256, 128 147584      activation_188[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, 256, 256, 128 147584      activation_189[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, 256, 256, 128 147584      activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, 256, 256, 128 147584      activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_377 (BatchN (None, 256, 256, 128 512         conv2d_377[0][0]
# __________________________________________________________________________________________________
# batch_normalization_379 (BatchN (None, 256, 256, 128 512         conv2d_379[0][0]
# __________________________________________________________________________________________________
# batch_normalization_381 (BatchN (None, 256, 256, 128 512         conv2d_381[0][0]
# __________________________________________________________________________________________________
# batch_normalization_383 (BatchN (None, 256, 256, 128 512         conv2d_383[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_63 (Conv2DTran (None, 512, 512, 64) 32832       batch_normalization_377[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_64 (Conv2DTran (None, 512, 512, 64) 32832       batch_normalization_379[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_65 (Conv2DTran (None, 512, 512, 64) 32832       batch_normalization_381[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_66 (Conv2DTran (None, 512, 512, 64) 32832       batch_normalization_383[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 512, 512, 128 0           conv2d_transpose_63[0][0]
#                                                                  batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 512, 512, 128 0           conv2d_transpose_64[0][0]
#                                                                  batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 512, 512, 128 0           conv2d_transpose_65[0][0]
#                                                                  batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 512, 512, 128 0           conv2d_transpose_66[0][0]
#                                                                  batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_62[0][0]
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_63[0][0]
# __________________________________________________________________________________________________
# conv2d_388 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_64[0][0]
# __________________________________________________________________________________________________
# conv2d_390 (Conv2D)             (None, 512, 512, 64) 73792       concatenate_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_384 (BatchN (None, 512, 512, 64) 256         conv2d_384[0][0]
# __________________________________________________________________________________________________
# batch_normalization_386 (BatchN (None, 512, 512, 64) 256         conv2d_386[0][0]
# __________________________________________________________________________________________________
# batch_normalization_388 (BatchN (None, 512, 512, 64) 256         conv2d_388[0][0]
# __________________________________________________________________________________________________
# batch_normalization_390 (BatchN (None, 512, 512, 64) 256         conv2d_390[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 512, 512, 64) 0           batch_normalization_384[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 512, 512, 64) 0           batch_normalization_386[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 512, 512, 64) 0           batch_normalization_388[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 512, 512, 64) 0           batch_normalization_390[0][0]
# __________________________________________________________________________________________________
# conv2d_385 (Conv2D)             (None, 512, 512, 64) 36928       activation_192[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, 512, 512, 64) 36928       activation_193[0][0]
# __________________________________________________________________________________________________
# conv2d_389 (Conv2D)             (None, 512, 512, 64) 36928       activation_194[0][0]
# __________________________________________________________________________________________________
# conv2d_391 (Conv2D)             (None, 512, 512, 64) 36928       activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_385 (BatchN (None, 512, 512, 64) 256         conv2d_385[0][0]
# __________________________________________________________________________________________________
# batch_normalization_387 (BatchN (None, 512, 512, 64) 256         conv2d_387[0][0]
# __________________________________________________________________________________________________
# batch_normalization_389 (BatchN (None, 512, 512, 64) 256         conv2d_389[0][0]
# __________________________________________________________________________________________________
# batch_normalization_391 (BatchN (None, 512, 512, 64) 256         conv2d_391[0][0]
# __________________________________________________________________________________________________
# output_ex (Conv2D)              (None, 512, 512, 1)  65          batch_normalization_385[0][0]
# __________________________________________________________________________________________________
# output_he (Conv2D)              (None, 512, 512, 1)  65          batch_normalization_387[0][0]
# __________________________________________________________________________________________________
# output_me (Conv2D)              (None, 512, 512, 1)  65          batch_normalization_389[0][0]
# __________________________________________________________________________________________________
# output_se (Conv2D)              (None, 512, 512, 1)  65          batch_normalization_391[0][0]
# ==================================================================================================
# Total params: 197,712,452
# Trainable params: 197,672,772
# Non-trainable params: 39,680
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model)
