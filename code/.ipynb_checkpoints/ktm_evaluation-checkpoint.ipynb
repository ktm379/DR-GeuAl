# %%
import tensorflow as tf
import os

from assets.one_mask.data_generator import DR_Generator
from assets.one_mask.models import SMD_Unet 
from assets.one_mask.trainer_withCE import Trainer

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/FGADR/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/FGADR/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':[3.0, [8, 8]]
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1108), is_train=True, **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1108, 1660), is_train=False, **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1660, 1840), is_train=False, **generator_args)

# tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), is_train=True, **generator_args)
# val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), is_train=False, **generator_args)
# ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), is_train=False, **generator_args)

# tr_fgadr_gen = DR_Generator(start_end_index=(0, 30000), is_train=True, **generator_args)
# val_fgadr_gen = DR_Generator(start_end_index=(30000, 31000), is_train=False, **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
#model.load_weights("../models/one_mask/New/3_3channel_CE_1_alpha01_lr0001/23")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':False,   # pretraining을 할지 말지 (true = recons만 학습 한다.)
    'alpha':0.1,           # loss를 구할때 mask_loss는 알파 * recons_loss + (1 - 알파 * mask_loss)
    'beta':None,
    'first_epoch':1,
    'file_name':"history/one_mask/New/3_3channel_CE_1_CLAHE_alpha01_lr0001.txt",
    'save_model_path':"../models/one_mask/New/3_3channel_CE_1_CLAHE_alpha01_lr0001",
    'add_noise':False,
    'bce_weight':1
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen
             )
# Out:
# Epoch 24/50
# 1108/1108 [==============================] - 455s 411ms/step - train_loss: 0.6311 - mask_loss: 0.7008 - loss_recons: 0.0035 - dice_loss: 0.6107 - bce_loss: 0.0896
# 552/552 [==============================] - 127s 231ms/step - val_loss: 0.7272 - mask_loss: 0.8077 - loss_recons: 0.0022 - dice_loss: 0.7143 - bce_loss: 0.0934
#
# Epoch 25/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.6129 - mask_loss: 0.6806 - loss_recons: 0.0035 - dice_loss: 0.5916 - bce_loss: 0.0885
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.7782 - mask_loss: 0.8643 - loss_recons: 0.0036 - dice_loss: 0.7600 - bce_loss: 0.1043
#
# Epoch 26/50
# 1108/1108 [==============================] - 439s 397ms/step - train_loss: 0.6097 - mask_loss: 0.6771 - loss_recons: 0.0036 - dice_loss: 0.5864 - bce_loss: 0.0900
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.7167 - mask_loss: 0.7959 - loss_recons: 0.0037 - dice_loss: 0.6980 - bce_loss: 0.0979
#
# Epoch 27/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5906 - mask_loss: 0.6558 - loss_recons: 0.0033 - dice_loss: 0.5664 - bce_loss: 0.0886
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.6715 - mask_loss: 0.7458 - loss_recons: 0.0028 - dice_loss: 0.6489 - bce_loss: 0.0969
#
# Epoch 28/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5758 - mask_loss: 0.6395 - loss_recons: 0.0032 - dice_loss: 0.5502 - bce_loss: 0.0886
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6850 - mask_loss: 0.7607 - loss_recons: 0.0038 - dice_loss: 0.6621 - bce_loss: 0.0986
#
# Epoch 29/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5709 - mask_loss: 0.6340 - loss_recons: 0.0032 - dice_loss: 0.5440 - bce_loss: 0.0892
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7301 - mask_loss: 0.8106 - loss_recons: 0.0049 - dice_loss: 0.7073 - bce_loss: 0.1033
#
# Epoch 30/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5581 - mask_loss: 0.6197 - loss_recons: 0.0034 - dice_loss: 0.5306 - bce_loss: 0.0883
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6908 - mask_loss: 0.7669 - loss_recons: 0.0060 - dice_loss: 0.6660 - bce_loss: 0.1009
#
# Epoch 31/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5512 - mask_loss: 0.6120 - loss_recons: 0.0033 - dice_loss: 0.5228 - bce_loss: 0.0884
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.7115 - mask_loss: 0.7902 - loss_recons: 0.0034 - dice_loss: 0.6844 - bce_loss: 0.1059
#
# Epoch 32/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5427 - mask_loss: 0.6026 - loss_recons: 0.0031 - dice_loss: 0.5130 - bce_loss: 0.0888
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7645 - mask_loss: 0.8491 - loss_recons: 0.0031 - dice_loss: 0.7364 - bce_loss: 0.1126
#
# Epoch 33/50
# 1108/1108 [==============================] - 438s 396ms/step - train_loss: 0.5331 - mask_loss: 0.5920 - loss_recons: 0.0032 - dice_loss: 0.5030 - bce_loss: 0.0881
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7436 - mask_loss: 0.8257 - loss_recons: 0.0049 - dice_loss: 0.7116 - bce_loss: 0.1140
#
# Epoch 34/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5408 - mask_loss: 0.6005 - loss_recons: 0.0033 - dice_loss: 0.5098 - bce_loss: 0.0899
# 552/552 [==============================] - 127s 229ms/step - val_loss: 0.6752 - mask_loss: 0.7499 - loss_recons: 0.0025 - dice_loss: 0.6464 - bce_loss: 0.1035
#
# Epoch 35/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5286 - mask_loss: 0.5870 - loss_recons: 0.0030 - dice_loss: 0.4971 - bce_loss: 0.0890
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7290 - mask_loss: 0.8097 - loss_recons: 0.0023 - dice_loss: 0.6987 - bce_loss: 0.1110
#
# Epoch 36/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5100 - mask_loss: 0.5664 - loss_recons: 0.0029 - dice_loss: 0.4783 - bce_loss: 0.0871
# 552/552 [==============================] - 127s 229ms/step - val_loss: 0.7837 - mask_loss: 0.8705 - loss_recons: 0.0023 - dice_loss: 0.7505 - bce_loss: 0.1201
#
# Epoch 37/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.5065 - mask_loss: 0.5625 - loss_recons: 0.0028 - dice_loss: 0.4745 - bce_loss: 0.0870
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7003 - mask_loss: 0.7779 - loss_recons: 0.0023 - dice_loss: 0.6683 - bce_loss: 0.1096
#
# Epoch 38/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.4992 - mask_loss: 0.5544 - loss_recons: 0.0028 - dice_loss: 0.4668 - bce_loss: 0.0865
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.7056 - mask_loss: 0.7837 - loss_recons: 0.0029 - dice_loss: 0.6684 - bce_loss: 0.1153
#
# Epoch 39/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.
50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.4416 - mask_loss: 0.4904 - loss_recons: 0.0023 - dice_loss: 0.4115 - bce_loss: 0.0782
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6089 - mask_loss: 0.6764 - loss_recons: 0.0019 - dice_loss: 0.5761 - bce_loss: 0.1002
#
# Epoch 51/50
# 1108/1108 [==============================] - 438s 396ms/step - train_loss: 0.4320 - mask_loss: 0.4798 - loss_recons: 0.0024 - dice_loss: 0.4022 - bce_loss: 0.0767
# 552/552 [==============================] - 126s 227ms/step - val_loss: 0.6373 - mask_loss: 0.7078 - loss_recons: 0.0026 - dice_loss: 0.5933 - bce_loss: 0.1145
#
# Epoch 52/50
# 1108/1108 [==============================] - 439s 396ms/step - train_loss: 0.4249 - mask_loss: 0.4719 - loss_recons: 0.0023 - dice_loss: 0.3958 - bce_loss: 0.0752
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.6620 - mask_loss: 0.7352 - loss_recons: 0.0035 - dice_loss: 0.6215 - bce_loss: 0.1137
#
# Epoch 53/50
#  256/1108 [=====>........................] - ETA: 5:36 - train_loss: 0.4746 - mask_loss: 0.5272 - loss_recons: 0.0018 - dice_loss: 0.3809 - bce_loss: 0.0609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2042/1974268525.py in <module>
#      16 trainer = Trainer(**trainer_args)
#      17
# ---> 18 trainer.train(train_dataset=tr_fgadr_gen,
#      19               val_dataset=val_fgadr_gen
#      20              )
#
# ~/aiffel/Visuworks/code/assets/one_mask/trainer_withCE.py in train(self, train_dataset, val_dataset)
#     153             bce_batch_loss = []
#     154
# --> 155             for step_train, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#     156                 if not self.for_recons:
#     157                     loss_recons, train_loss, mask_loss, dice_loss, bce_loss = self.train_on_batch(x_batch_train, y_batch_train)
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in __iter__(self)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/data_utils.py in <genexpr>(.0)
#     481   def __iter__(self):
#     482     """Create a generator that iterate over the Sequence."""
# --> 483     for item in (self[i] for i in range(len(self))):
#     484       yield item
#     485
#
# ~/aiffel/Visuworks/code/assets/one_mask/data_generator.py in __getitem__(self, index)
#     205                 return [tf.cast(inputs, dtype=tf.float32), tf.cast(noisy_inputs, dtype=tf.float32)], tf.cast(mask, dtype=tf.float32)
#     206
# --> 207             return [tf.cast(inputs, dtype=tf.float32)], tf.cast(mask, dtype=tf.float32)
#     208
#     209     def on_epoch_end(self):
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     986       # allows some conversions that cast() can't do, e.g. casting numbers to
#     987       # strings.
# --> 988       x = ops.convert_to_tensor(x, name="x")
#     989       if x.dtype.base_dtype != base_type:
#     990         x = gen_math_ops.cast(x, base_type, name=name)
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# KeyboardInterrupt:

# %% [markdown]
# # 모델 결과 시각화

# %%
from assets.one_mask.utils import parse_history_text
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
history = parse_history_text('history/one_mask/New/3_3channel_CE_1_alpha01_lr0001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='train_mask_loss')
plt.plot(history['epoch'], history['val_mask_loss'], label='val_mask_loss')

plt.title('3_3channel_CE_1_alpha01_lr0001')
plt.legend()
plt.show()

# %%
history = parse_history_text('history/one_mask/5_1_pretraining_3channel_addnoise_alpha01_lr00001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='lr0.001')
plt.plot(history['epoch'], history['val_mask_loss'], label='lr0.001')


history = parse_history_text('history/one_mask/withoutCLAHE_withoutRecons_alpha00_lr00001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='lr0.0001', linestyle='--')
plt.plot(history['epoch'], history['val_mask_loss'], label='lr0.0001', linestyle='--')

plt.title('lr')
plt.legend()
plt.show()

# %% [markdown]
# # 평가지표

# %%
from assets.evaluation.evaluate_result import evaluate_main

generator_type = 'validation'  # 원하는 generator 타입 선택: 'train', 'validation', 또는 'test'
input_channel = 3         # 3channel은 3, 1channel은 1
use_3channel = True     # 3channel은 True, 1channel은 False
model_path = "../models/one_mask/New/3_1_3channel_alpha01_lr00001/8"  # 모델 경로 지정
result_df = evaluate_main(generator_type, model_path, input_channel, use_3channel)
# Out:
# 100%|██████████| 138/138 [03:07<00:00,  1.36s/it]
# CSV 파일 저장 완료: assets/evaluation/evaluation_results_csv/3_1_3channel_alpha01_lr00001_validation_evaluation_result.csv

# %%
import pandas as pd

result_df = pd.read_csv("assets/evaluation/evaluation_results_csv/3_1_3channel_alpha01_lr00001_validation_evaluation_result.csv")
#result_df = result_df["file_name"]
#result_df = result_df.iloc[:10]
#result_df

# %%
b_df = pd.read_csv("../data/FGADR/average_brightness.csv")

# %%
result_df.set_index("file_name", inplace=True)
b_df.set_index("file_name", inplace=True)

# join 메서드를 사용하여 두 데이터프레임을 합침
merged_df = result_df.join(b_df, how="inner")

merged_df.to_csv("merged_data.csv")

# %%
merged_df
# Out:
#                     dice       iou    pr_auc       mae  brightness
# file_name
# 1221_3.png  8.816630e-01  0.788033  0.917700  0.000797   93.805126
# 1350_2.png  8.424954e-01  0.728034  0.872050  0.039518   88.514426
# 1452_3.png  8.419399e-01  0.727372  0.885659  0.020924  109.055558
# 1608_3.png  8.351476e-01  0.717199  0.881053  0.098473  115.429267
# 1134_1.png  8.229367e-01  0.699133  0.821815  0.029391   80.361255
# ...                  ...       ...       ...       ...         ...
# 1128_1.png  7.145567e-11  0.000000       NaN  0.005339   72.240638
# 1340_1.png  6.647828e-11  0.000000       NaN  0.005738   67.015753
# 1373_3.png  5.832771e-11  0.000000       NaN  0.006540  108.141068
# 1300_1.png  2.657285e-11  0.000000       NaN  0.014356   74.857615
# 1528_3.png  1.906155e-11  0.000000       NaN  0.020013   97.380513
#
# [552 rows x 5 columns]

# %%
merged_df = merged_df.iloc[420:520]

count_b = len(merged_df[merged_df["brightness"] >= 80])
mean_b = merged_df["brightness"].mean()
print(count_b)
print(mean_b)
# Out:
# 47
# 81.84554670410157

# %% [markdown]
# # Prediction 결과 시각화

# %%
from assets.evaluation.evaluation_visual import visualize_segmentation_results

image_filenames = ["1222_1.png"]  # 원하는 이미지 파일명으로 수정
#image_filenames = result_df

mask_dir = '../data/FGADR/Seg-set'
image_dir = '../data/FGADR/Seg-set/Original_Images/'
#image_dir = '../data/FGADR/'

model_path = "../models/one_mask/New/3_3channel_CE_alpha01_lr0001/49"
visualize_segmentation_results(image_filenames, model_path, mask_dir, image_dir)
# Out:
# ============================================================================================================================
