# %%
import tensorflow as tf
import os

from assets.one_mask.data_generator import DR_Generator
from assets.one_mask.models import SMD_Unet 
from assets.one_mask.trainer_withCE import Trainer

# %%
masks = ['HardExudate_Masks', 'Hemohedge_Masks', 'Microaneurysms_Masks', 'SoftExudate_Masks']
mask_dir = '../data/FGADR/Seg-set'
mask_paths = [os.path.join(mask_dir, mask) for mask in masks]

generator_args = {
    'dir_path':'../data/FGADR/Seg-set/Original_Images/',
    'mask_path':mask_paths,
    'use_mask':True,
    'img_size':(512, 512),  
    'batch_size':4, # 8로 하면 바로 OOM 뜸
    'dataset':'FGADR', # FGADR or EyePacks
    'use_3channel':True,
    'CLAHE_args':None
}

tr_fgadr_gen = DR_Generator(start_end_index=(0, 1108), is_train=True, **generator_args)
val_fgadr_gen = DR_Generator(start_end_index=(1108, 1660), is_train=False, **generator_args)
ts_fgadr_gen = DR_Generator(start_end_index=(1660, 1840), is_train=False, **generator_args)

# tr_fgadr_gen = DR_Generator(start_end_index=(0, 1292), is_train=True, **generator_args)
# val_fgadr_gen = DR_Generator(start_end_index=(1292, 1476), is_train=False, **generator_args)
# ts_fgadr_gen = DR_Generator(start_end_index=(1476, 1842), is_train=False, **generator_args)

# tr_fgadr_gen = DR_Generator(start_end_index=(0, 30000), is_train=True, **generator_args)
# val_fgadr_gen = DR_Generator(start_end_index=(30000, 31000), is_train=False, **generator_args)

# %%
model = SMD_Unet(enc_filters=[64, 128, 256, 512, 1024], dec_filters=[512, 256, 64, 32], input_channel=3)
#model.load_weights("../models/one_mask/New/6_pretraining_1channel_alpha01_lr0001/20")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 

trainer_args = {
    'model':model,
    'epochs':50,
    'optimizer':optimizer,
    'for_recons':False,   # pretraining을 할지 말지 (true = recons만 학습 한다.)
    'alpha':0.1,           # loss를 구할때 mask_loss는 알파 * recons_loss + (1 - 알파 * mask_loss)
    'beta':None,
    'first_epoch':1,
    'file_name':"history/one_mask/New/3_3channel_CE_alpha01_lr0001.txt",
    'save_model_path':"../models/one_mask/New/3_3channel_CE_alpha01_lr0001",
    'add_noise':False,
    'bce_weight':0.5
}
trainer = Trainer(**trainer_args)

trainer.train(train_dataset=tr_fgadr_gen,
              val_dataset=val_fgadr_gen
             )
# Out:
# Epoch 1/50
# 1108/1108 [==============================] - 455s 410ms/step - train_loss: 1.1252 - mask_loss: 1.2478 - loss_recons: 0.0223 - dice_loss: 0.9532 - bce_loss: 0.5901
# 552/552 [==============================] - 127s 229ms/step - val_loss: 1.1133 - mask_loss: 1.2336 - loss_recons: 0.0301 - dice_loss: 0.9560 - bce_loss: 0.5554
#
# Epoch 2/50
# 1108/1108 [==============================] - 436s 394ms/step - train_loss: 1.0257 - mask_loss: 1.1389 - loss_recons: 0.0067 - dice_loss: 0.9500 - bce_loss: 0.3787
# 552/552 [==============================] - 126s 229ms/step - val_loss: 1.0641 - mask_loss: 1.1812 - loss_recons: 0.0103 - dice_loss: 0.9567 - bce_loss: 0.4491
#
# Epoch 3/50
# 1108/1108 [==============================] - 436s 393ms/step - train_loss: 0.9626 - mask_loss: 1.0689 - loss_recons: 0.0063 - dice_loss: 0.9453 - bce_loss: 0.2482
# 552/552 [==============================] - 126s 228ms/step - val_loss: 0.9789 - mask_loss: 1.0865 - loss_recons: 0.0098 - dice_loss: 0.9429 - bce_loss: 0.2873
#
# Epoch 4/50
# 1108/1108 [==============================] - 436s 394ms/step - train_loss: 0.9037 - mask_loss: 1.0035 - loss_recons: 0.0054 - dice_loss: 0.9132 - bce_loss: 0.1815
# 552/552 [==============================] - 127s 230ms/step - val_loss: 1.6049 - mask_loss: 1.7823 - loss_recons: 0.0090 - dice_loss: 0.9207 - bce_loss: 1.7231
#
# Epoch 5/50
# 1108/1108 [==============================] - 437s 394ms/step - train_loss: 0.8214 - mask_loss: 0.9121 - loss_recons: 0.0049 - dice_loss: 0.8445 - bce_loss: 0.1358
# 552/552 [==============================] - 128s 232ms/step - val_loss: 0.8383 - mask_loss: 0.9308 - loss_recons: 0.0054 - dice_loss: 0.8086 - bce_loss: 0.2444
#
# Epoch 6/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.7215 - mask_loss: 0.8011 - loss_recons: 0.0045 - dice_loss: 0.7433 - bce_loss: 0.1155
# 552/552 [==============================] - 128s 232ms/step - val_loss: 0.7303 - mask_loss: 0.8107 - loss_recons: 0.0065 - dice_loss: 0.7357 - bce_loss: 0.1499
#
# Epoch 7/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.6561 - mask_loss: 0.7286 - loss_recons: 0.0044 - dice_loss: 0.6727 - bce_loss: 0.1114
# 552/552 [==============================] - 128s 232ms/step - val_loss: 0.6798 - mask_loss: 0.7546 - loss_recons: 0.0067 - dice_loss: 0.6958 - bce_loss: 0.1175
#
# Epoch 8/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.6144 - mask_loss: 0.6822 - loss_recons: 0.0041 - dice_loss: 0.6259 - bce_loss: 0.1120
# 552/552 [==============================] - 127s 229ms/step - val_loss: 0.6640 - mask_loss: 0.7374 - loss_recons: 0.0030 - dice_loss: 0.6841 - bce_loss: 0.1067
#
# Epoch 9/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.5926 - mask_loss: 0.6580 - loss_recons: 0.0038 - dice_loss: 0.6005 - bce_loss: 0.1142
# 552/552 [==============================] - 130s 235ms/step - val_loss: 0.6763 - mask_loss: 0.7512 - loss_recons: 0.0026 - dice_loss: 0.6959 - bce_loss: 0.1105
#
# Epoch 10/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5781 - mask_loss: 0.6419 - loss_recons: 0.0036 - dice_loss: 0.5837 - bce_loss: 0.1155
# 552/552 [==============================] - 128s 231ms/step - val_loss: 0.6328 - mask_loss: 0.7029 - loss_recons: 0.0025 - dice_loss: 0.6496 - bce_loss: 0.1065
#
# Epoch 11/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5663 - mask_loss: 0.6288 - loss_recons: 0.0036 - dice_loss: 0.5705 - bce_loss: 0.1154
# 552/552 [==============================] - 127s 231ms/step - val_loss: 0.6304 - mask_loss: 0.7002 - loss_recons: 0.0022 - dice_loss: 0.6364 - bce_loss: 0.1277
#
# Epoch 12/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.5588 - mask_loss: 0.6205 - loss_recons: 0.0034 - dice_loss: 0.5617 - bce_loss: 0.1163
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6920 - mask_loss: 0.7687 - loss_recons: 0.0023 - dice_loss: 0.7053 - bce_loss: 0.1269
#
# Epoch 13/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5520 - mask_loss: 0.6129 - loss_recons: 0.0033 - dice_loss: 0.5547 - bce_loss: 0.1152
# 552/552 [==============================] - 127s 231ms/step - val_loss: 0.6799 - mask_loss: 0.7552 - loss_recons: 0.0020 - dice_loss: 0.6956 - bce_loss: 0.1193
#
# Epoch 14/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.5403 - mask_loss: 0.6000 - loss_recons: 0.0032 - dice_loss: 0.5423 - bce_loss: 0.1141
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6639 - mask_loss: 0.7374 - loss_recons: 0.0018 - dice_loss: 0.6766 - bce_loss: 0.1217
#
# Epoch 15/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.5378 - mask_loss: 0.5972 - loss_recons: 0.0032 - dice_loss: 0.5394 - bce_loss: 0.1146
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7592 - mask_loss: 0.8431 - loss_recons: 0.0039 - dice_loss: 0.7709 - bce_loss: 0.1446
#
# Epoch 16/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.5270 - mask_loss: 0.5852 - loss_recons: 0.0032 - dice_loss: 0.5281 - bce_loss: 0.1127
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6692 - mask_loss: 0.7434 - loss_recons: 0.0019 - dice_loss: 0.6862 - bce_loss: 0.1144
#
# Epoch 17/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5220 - mask_loss: 0.5797 - loss_recons: 0.0032 - dice_loss: 0.5233 - bce_loss: 0.1115
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.7071 - mask_loss: 0.7854 - loss_recons: 0.0017 - dice_loss: 0.7124 - bce_loss: 0.1460
#
# Epoch 18/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5194 - mask_loss: 0.5768 - loss_recons: 0.0031 - dice_loss: 0.5197 - bce_loss: 0.1123
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6691 - mask_loss: 0.7432 - loss_recons: 0.0023 - dice_loss: 0.6848 - bce_loss: 0.1168
#
# Epoch 19/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5109 - mask_loss: 0.5674 - loss_recons: 0.0030 - dice_loss: 0.5117 - bce_loss: 0.1102
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6415 - mask_loss: 0.7125 - loss_recons: 0.0031 - dice_loss: 0.6464 - bce_loss: 0.1322
#
# Epoch 20/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5114 - mask_loss: 0.5679 - loss_recons: 0.0030 - dice_loss: 0.5120 - bce_loss: 0.1108
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.7641 - mask_loss: 0.8488 - loss_recons: 0.0019 - dice_loss: 0.7792 - bce_loss: 0.1392
#
# Epoch 21/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.5054 - mask_loss: 0.5612 - loss_recons: 0.0030 - dice_loss: 0.5064 - bce_loss: 0.1086
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.7131 - mask_loss: 0.7920 - loss_recons: 0.0030 - dice_loss: 0.7172 - bce_loss: 0.1496
#
# Epoch 22/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.4953 - mask_loss: 0.5500 - loss_recons: 0.0030 - dice_loss: 0.4957 - bce_loss: 0.1075
# 552/552 [==============================] - 127s 229ms/step - val_loss: 0.5928 - mask_loss: 0.6585 - loss_recons: 0.0020 - dice_loss: 0.5977 - bce_loss: 0.1216
#
# Epoch 23/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4847 - mask_loss: 0.5382 - loss_recons: 0.0028 - dice_loss: 0.4848 - bce_loss: 0.1057
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6230 - mask_loss: 0.6920 - loss_recons: 0.0016 - dice_loss: 0.6290 - bce_loss: 0.1260
#
# Epoch 24/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4837 - mask_loss: 0.5371 - loss_recons: 0.0028 - dice_loss: 0.4841 - bce_loss: 0.1048
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6376 - mask_loss: 0.7081 - loss_recons: 0.0030 - dice_loss: 0.6403 - bce_loss: 0.1358
#
# Epoch 25/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4773 - mask_loss: 0.5300 - loss_recons: 0.0028 - dice_loss: 0.4765 - bce_loss: 0.1058
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6094 - mask_loss: 0.6767 - loss_recons: 0.0033 - dice_loss: 0.6106 - bce_loss: 0.1323
#
# Epoch 26/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4708 - mask_loss: 0.5228 - loss_recons: 0.0028 - dice_loss: 0.4705 - bce_loss: 0.1035
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6083 - mask_loss: 0.6757 - loss_recons: 0.0018 - dice_loss: 0.6137 - bce_loss: 0.1240
#
# Epoch 27/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4597 - mask_loss: 0.5105 - loss_recons: 0.0027 - dice_loss: 0.4594 - bce_loss: 0.1010
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6016 - mask_loss: 0.6683 - loss_recons: 0.0018 - dice_loss: 0.6037 - bce_loss: 0.1291
#
# Epoch 28/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4581 - mask_loss: 0.5087 - loss_recons: 0.0027 - dice_loss: 0.4572 - bce_loss: 0.1017
# 552/552 [==============================] - 129s 234ms/step - val_loss: 0.6503 - mask_loss: 0.7224 - loss_recons: 0.0017 - dice_loss: 0.6558 - bce_loss: 0.1333
#
# Epoch 29/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4536 - mask_loss: 0.5038 - loss_recons: 0.0026 - dice_loss: 0.4530 - bce_loss: 0.1004
# 552/552 [==============================] - 129s 234ms/step - val_loss: 0.5852 - mask_loss: 0.6501 - loss_recons: 0.0014 - dice_loss: 0.5877 - bce_loss: 0.1247
#
# Epoch 30/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4493 - mask_loss: 0.4990 - loss_recons: 0.0026 - dice_loss: 0.4491 - bce_loss: 0.0989
# 552/552 [==============================] - 126s 229ms/step - val_loss: 0.6095 - mask_loss: 0.6770 - loss_recons: 0.0019 - dice_loss: 0.6124 - bce_loss: 0.1292
#
# Epoch 31/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4543 - mask_loss: 0.5045 - loss_recons: 0.0026 - dice_loss: 0.4541 - bce_loss: 0.0996
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6565 - mask_loss: 0.7293 - loss_recons: 0.0019 - dice_loss: 0.6535 - bce_loss: 0.1515
#
# Epoch 32/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4431 - mask_loss: 0.4921 - loss_recons: 0.0025 - dice_loss: 0.4425 - bce_loss: 0.0978
# 552/552 [==============================] - 128s 231ms/step - val_loss: 0.6211 - mask_loss: 0.6899 - loss_recons: 0.0017 - dice_loss: 0.6195 - bce_loss: 0.1408
#
# Epoch 33/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4367 - mask_loss: 0.4849 - loss_recons: 0.0025 - dice_loss: 0.4359 - bce_loss: 0.0966
# 552/552 [==============================] - 129s 233ms/step - val_loss: 0.6501 - mask_loss: 0.7221 - loss_recons: 0.0019 - dice_loss: 0.6491 - bce_loss: 0.1460
#
# Epoch 34/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.4349 - mask_loss: 0.4830 - loss_recons: 0.0025 - dice_loss: 0.4337 - bce_loss: 0.0965
# 552/552 [==============================] - 130s 235ms/step - val_loss: 0.5870 - mask_loss: 0.6520 - loss_recons: 0.0019 - dice_loss: 0.5907 - bce_loss: 0.1227
#
# Epoch 35/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.4421 - mask_loss: 0.4909 - loss_recons: 0.0026 - dice_loss: 0.4417 - bce_loss: 0.0971
# 552/552 [==============================] - 135s 244ms/step - val_loss: 0.6357 - mask_loss: 0.7061 - loss_recons: 0.0021 - dice_loss: 0.6389 - bce_loss: 0.1345
#
# Epoch 36/50
# 1108/1108 [==============================] - 437s 395ms/step - train_loss: 0.4352 - mask_loss: 0.4833 - loss_recons: 0.0025 - dice_loss: 0.4347 - bce_loss: 0.0957
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.7329 - mask_loss: 0.8142 - loss_recons: 0.0015 - dice_loss: 0.7323 - bce_loss: 0.1638
#
# Epoch 37/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4257 - mask_loss: 0.4727 - loss_recons: 0.0026 - dice_loss: 0.4247 - bce_loss: 0.0950
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6462 - mask_loss: 0.7178 - loss_recons: 0.0014 - dice_loss: 0.6461 - bce_loss: 0.1434
#
# Epoch 38/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4208 - mask_loss: 0.4673 - loss_recons: 0.0025 - dice_loss: 0.4197 - bce_loss: 0.0940
# 552/552 [==============================] - 127s 230ms/step - val_loss: 0.6534 - mask_loss: 0.7259 - loss_recons: 0.0015 - dice_loss: 0.6531 - bce_loss: 0.1455
#
# Epoch 39/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4134 - mask_loss: 0.4590 - loss_recons: 0.0025 - dice_loss: 0.4121 - bce_loss: 0.0926
# 552/552 [==============================] - 127s 229ms/step - val_loss: 0.6356 - mask_loss: 0.7060 - loss_recons: 0.0020 - dice_loss: 0.6334 - bce_loss: 0.1453
#
# Epoch 40/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4127 - mask_loss: 0.4583 - loss_recons: 0.0026 - dice_loss: 0.4115 - bce_loss: 0.0918
# 552/552 [==============================] - 127s 231ms/step - val_loss: 0.6977 - mask_loss: 0.7749 - loss_recons: 0.0024 - dice_loss: 0.6880 - bce_loss: 0.1738
#
# Epoch 41/50
# 1108/1108 [==============================] - 438s 396ms/step - train_loss: 0.4053 - mask_loss: 0.4501 - loss_recons: 0.0025 - dice_loss: 0.4041 - bce_loss: 0.0905
# 552/552 [==============================] - 131s 238ms/step - val_loss: 0.5890 - mask_loss: 0.6543 - loss_recons: 0.0013 - dice_loss: 0.5909 - bce_loss: 0.1269
#
# Epoch 42/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3980 - mask_loss: 0.4419 - loss_recons: 0.0025 - dice_loss: 0.3968 - bce_loss: 0.0888
# 552/552 [==============================] - 131s 237ms/step - val_loss: 0.6369 - mask_loss: 0.7075 - loss_recons: 0.0019 - dice_loss: 0.6342 - bce_loss: 0.1466
#
# Epoch 43/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3967 - mask_loss: 0.4405 - loss_recons: 0.0023 - dice_loss: 0.3952 - bce_loss: 0.0890
# 552/552 [==============================] - 131s 238ms/step - val_loss: 0.5853 - mask_loss: 0.6502 - loss_recons: 0.0014 - dice_loss: 0.5843 - bce_loss: 0.1318
#
# Epoch 44/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3994 - mask_loss: 0.4435 - loss_recons: 0.0023 - dice_loss: 0.3985 - bce_loss: 0.0885
# 552/552 [==============================] - 131s 237ms/step - val_loss: 0.6363 - mask_loss: 0.7068 - loss_recons: 0.0021 - dice_loss: 0.6291 - bce_loss: 0.1553
#
# Epoch 45/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.4157 - mask_loss: 0.4616 - loss_recons: 0.0025 - dice_loss: 0.4144 - bce_loss: 0.0934
# 552/552 [==============================] - 131s 238ms/step - val_loss: 0.6400 - mask_loss: 0.7108 - loss_recons: 0.0025 - dice_loss: 0.6346 - bce_loss: 0.1525
#
# Epoch 46/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3947 - mask_loss: 0.4383 - loss_recons: 0.0023 - dice_loss: 0.3939 - bce_loss: 0.0872
# 552/552 [==============================] - 132s 239ms/step - val_loss: 0.6405 - mask_loss: 0.7115 - loss_recons: 0.0018 - dice_loss: 0.6336 - bce_loss: 0.1557
#
# Epoch 47/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3834 - mask_loss: 0.4258 - loss_recons: 0.0023 - dice_loss: 0.3825 - bce_loss: 0.0848
# 552/552 [==============================] - 133s 241ms/step - val_loss: 0.6052 - mask_loss: 0.6723 - loss_recons: 0.0017 - dice_loss: 0.6061 - bce_loss: 0.1324
#
# Epoch 48/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3720 - mask_loss: 0.4130 - loss_recons: 0.0022 - dice_loss: 0.3711 - bce_loss: 0.0826
# 552/552 [==============================] - 133s 242ms/step - val_loss: 0.6464 - mask_loss: 0.7180 - loss_recons: 0.0013 - dice_loss: 0.6428 - bce_loss: 0.1504
#
# Epoch 49/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3687 - mask_loss: 0.4094 - loss_recons: 0.0022 - dice_loss: 0.3677 - bce_loss: 0.0821
# 552/552 [==============================] - 131s 238ms/step - val_loss: 0.5621 - mask_loss: 0.6244 - loss_recons: 0.0013 - dice_loss: 0.5592 - bce_loss: 0.1305
#
# Epoch 50/50
# 1108/1108 [==============================] - 438s 395ms/step - train_loss: 0.3619 - mask_loss: 0.4019 - loss_recons: 0.0022 - dice_loss: 0.3614 - bce_loss: 0.0797
# 552/552 [==============================] - 131s 238ms/step - val_loss: 0.5962 - mask_loss: 0.6623 - loss_recons: 0.0014 - dice_loss: 0.5944 - bce_loss: 0.1357

# %% [markdown]
# # 모델 결과 시각화

# %%
from assets.one_mask.utils import parse_history_text
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
history = parse_history_text('history/one_mask/New/3_3channel_CE_alpha01_lr0001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='train_mask_loss')
plt.plot(history['epoch'], history['val_mask_loss'], label='val_mask_loss')

plt.title('3_3channel_CE_alpha01_lr0001')
plt.legend()
plt.show()

# %%
history = parse_history_text('history/one_mask/5_1_pretraining_3channel_addnoise_alpha01_lr00001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='lr0.001')
plt.plot(history['epoch'], history['val_mask_loss'], label='lr0.001')


history = parse_history_text('history/one_mask/withoutCLAHE_withoutRecons_alpha00_lr00001.txt')

plt.plot(history['epoch'], history['train_mask_loss'], label='lr0.0001', linestyle='--')
plt.plot(history['epoch'], history['val_mask_loss'], label='lr0.0001', linestyle='--')

plt.title('lr')
plt.legend()
plt.show()

# %% [markdown]
# # 평가지표

# %%
from assets.evaluation.evaluate_result import evaluate_main

generator_type = 'validation'  # 원하는 generator 타입 선택: 'train', 'validation', 또는 'test'
input_channel = 3         # 3channel은 3, 1channel은 1
use_3channel = True     # 3channel은 True, 1channel은 False
model_path = "../models/one_mask/New/3_1_3channel_alpha01_lr00001/8"  # 모델 경로 지정
result_df = evaluate_main(generator_type, model_path, input_channel, use_3channel)
# Out:
# 100%|██████████| 138/138 [03:07<00:00,  1.36s/it]
# CSV 파일 저장 완료: assets/evaluation/evaluation_results_csv/3_1_3channel_alpha01_lr00001_validation_evaluation_result.csv

# %%
import pandas as pd

result_df = pd.read_csv("assets/evaluation/evaluation_results_csv/3_1_3channel_alpha01_lr00001_validation_evaluation_result.csv")
#result_df = result_df["file_name"]
#result_df = result_df.iloc[:10]
#result_df

# %%
b_df = pd.read_csv("../data/FGADR/average_brightness.csv")

# %%
result_df.set_index("file_name", inplace=True)
b_df.set_index("file_name", inplace=True)

# join 메서드를 사용하여 두 데이터프레임을 합침
merged_df = result_df.join(b_df, how="inner")

merged_df.to_csv("merged_data.csv")

# %%
merged_df
# Out:
#                     dice       iou    pr_auc       mae  brightness
# file_name
# 1221_3.png  8.816630e-01  0.788033  0.917700  0.000797   93.805126
# 1350_2.png  8.424954e-01  0.728034  0.872050  0.039518   88.514426
# 1452_3.png  8.419399e-01  0.727372  0.885659  0.020924  109.055558
# 1608_3.png  8.351476e-01  0.717199  0.881053  0.098473  115.429267
# 1134_1.png  8.229367e-01  0.699133  0.821815  0.029391   80.361255
# ...                  ...       ...       ...       ...         ...
# 1128_1.png  7.145567e-11  0.000000       NaN  0.005339   72.240638
# 1340_1.png  6.647828e-11  0.000000       NaN  0.005738   67.015753
# 1373_3.png  5.832771e-11  0.000000       NaN  0.006540  108.141068
# 1300_1.png  2.657285e-11  0.000000       NaN  0.014356   74.857615
# 1528_3.png  1.906155e-11  0.000000       NaN  0.020013   97.380513
#
# [552 rows x 5 columns]

# %%
merged_df = merged_df.iloc[420:520]

count_b = len(merged_df[merged_df["brightness"] >= 80])
mean_b = merged_df["brightness"].mean()
print(count_b)
print(mean_b)
# Out:
# 47
# 81.84554670410157

# %% [markdown]
# # Prediction 결과 시각화

# %%
from assets.evaluation.evaluation_visual import visualize_segmentation_results

image_filenames = ["1479_1.png", "1604_1.png", "1622_1.png", "1222_1.png"]  # 원하는 이미지 파일명으로 수정
#image_filenames = result_df

mask_dir = '../data/FGADR/Seg-set'
image_dir = '../data/FGADR/Seg-set/Original_Images/'

model_path = "../models/one_mask/New/3_3channel_CE_alpha01_lr0001/49"
visualize_segmentation_results(image_filenames, model_path, mask_dir, image_dir)
# Out:
# ============================================================================================================================
# ============================================================================================================================
# ============================================================================================================================
# ============================================================================================================================
